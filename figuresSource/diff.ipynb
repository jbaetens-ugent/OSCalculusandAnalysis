# %% [markdown]
# # Hoofdstuk 9 Afgeleiden en hun toepassingen

# %%
from mpl_toolkits.axisartist.axislines import SubplotZero
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import matplotlib
import numpy as np
matplotlib.rcParams["font.family"] = "monospace"
matplotlib.rcParams['font.style'] = "italic"
plt.rcParams.update({'mathtext.default':  'regular' })

# %% [markdown]
# ## Gemiddelde en ogenblikkelijke snelheid

# %% [markdown]
# ### fig_diff_1a

# %%
fig1a = plt.figure(figsize=(4,4))
ax1a = fig1a.add_axes([0,0,1,1])

ax1a.set_xlim(0, 4)
ax1a.set_ylim(0, 150)
ax1a.set_yticks([50, 100])
ax1a.set_xticks([0, 1, 2, 3])

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax1a.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax1a.spines[direction].set_position('zero')

ax1a.arrow(0, 0, 4.1, 0., fc='k', ec='k', lw = .5, head_width=5, head_length=0.1, overhang = 0.3, length_includes_head= False, clip_on = False)
ax1a.arrow(0, 0, 0, 150.1, fc='k', ec='k', lw = .5, head_width=0.1, head_length=5, overhang = 0.3, length_includes_head= False, clip_on = False)

x = np.linspace(0, 4, 100)
ax1a.plot(x, -16*x**2+150, color='black')
ax1a.plot(x, -80*x + 246, color='grey')
ax1a.scatter([2, 3], [-16*4+150, -16*9+150], color='black', zorder=10)

ax1a.text(4.5, -1, 'x', color="black", size=15)
ax1a.text(0.2, 150.1, 'y', color="black", size=15)
fig1a.savefig("fig_diff_1a.pdf", bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_diff_1b

# %%
fig1b = plt.figure(figsize=(4,4))
ax1b = fig1b.add_axes([0,0,1,1])

ax1b.set_xlim(0, 4)
ax1b.set_ylim(0, 150)
ax1b.set_yticks([50, 100])
ax1b.set_xticks([0, 1, 2, 3])

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax1b.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax1b.spines[direction].set_position('zero')

ax1b.arrow(0, 0, 4.1, 0., fc='k', ec='k', lw = .5, head_width=5, head_length=0.1, overhang = 0.3, length_includes_head= False, clip_on = False)
ax1b.arrow(0, 0, 0, 150.1, fc='k', ec='k', lw = .5, head_width=0.1, head_length=5, overhang = 0.3, length_includes_head= False, clip_on = False)

x = np.linspace(0, 4, 100)
ax1b.plot(x, -16*x**2+150, color='black')
ax1b.plot(x, -64*x + 214, color='grey')
ax1b.scatter([2], [-16*4+150], color='black', zorder=10)

ax1b.text(4.5, -1, 'x', color="black", size=15)
ax1b.text(0.2, 150.1, 'y', color="black", size=15)
fig1b.savefig("fig_diff_1b.pdf", bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_diff_2

# %%
fig2 = plt.figure(figsize=(4,4))
ax2 = fig2.add_axes([0,0,1,1])

ax2.set_xlim(0, 4)
ax2.set_ylim(-10, 30)
ax2.set_yticks([20])
ax2.set_xticks([1, 2, 3])
ax2.text(-0.2, -0.5, '0', color="black", size=10)

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax2.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax2.spines[direction].set_position('zero')

ax2.arrow(0, 0, 4.1, 0., fc='k', ec='k', lw = .5, head_width=1, head_length=0.1, overhang = 0.3, length_includes_head= False, clip_on = False)
ax2.arrow(0, -10, 0, 40.1, fc='k', ec='k', lw = .5, head_width=0.1, head_length=1, overhang = 0.3, length_includes_head= False, clip_on = False)

x = np.linspace(0, 4, 100)
ax2.plot(x, 3*x**2 + 5*x - 7, color='black')
ax2.plot(x, 11*x - 10, color='black', ls='--')
ax2.plot(x, -x/11 + 12/11, color='black', ls=':')
ax2.scatter([1], [3+5-7], color='black')

ax2.text(4.5, -1, 'x', color="black", size=15)
ax2.text(0.2, 30.1, 'y', color="black", size=15)
fig2.savefig("fig_diff_2.pdf", bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_diff_3a

# %%
fig3a = plt.figure(figsize=(5,4))
ax3a = fig3a.add_axes([0,0,1,1])

ax3a.set_xlim(-1, 1)
ax3a.set_ylim(0, 1.5)
ax3a.set_yticks([1])
ax3a.set_xticks([-1, 0, 1])

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax3a.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax3a.spines[direction].set_position('zero')

ax3a.arrow(-1, 0, 2.1, 0., fc='k', ec='k', lw = .5, head_width=0.05, head_length=0.05, overhang = 0.3, length_includes_head= False, clip_on = False)
ax3a.arrow(0, 0, 0, 1.6, fc='k', ec='k', lw = .5, head_width=0.05, head_length=0.05, overhang = 0.3, length_includes_head= False, clip_on = False)

x = np.linspace(-1, 1, 100)
ax3a.plot(x, np.abs(x), color='black')

ax3a.text(1.2, -0.1, 'x', color="black", size=15)
ax3a.text(0.1, 1.7, 'y', color="black", size=15)

fig3a.savefig("fig_diff_3a.pdf", bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_diff_3b

# %%
fig3b = plt.figure(figsize=(5,4))
ax3b = fig3b.add_axes([0,0,1,1])

ax3b.set_xlim(-1, 1)
ax3b.set_ylim(-1.5, 1.5)
ax3b.set_yticks([-1, 1])
ax3b.set_xticks([-1, -0.5, 0.5, 1])
ax3b.text(-0.2, -0.2, '0', color="black", size=10)

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax3b.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax3b.spines[direction].set_position('zero')

ax3b.arrow(-1, 0, 2.1, 0., fc='k', ec='k', lw = .5, head_width=0.1, head_length=0.05, overhang = 0.3, length_includes_head= False, clip_on = False)
ax3b.arrow(0, -1.5, 0, 3.1, fc='k', ec='k', lw = .5, head_width=0.05, head_length=0.1, overhang = 0.3, length_includes_head= False, clip_on = False)

x = np.linspace(-1, 1, 1000)
ax3b.plot(x, np.abs(x)/x, color='black')
ax3b.scatter([0, 0], [-1, 1], color='black', facecolors='white', marker='o', zorder=10)

ax3b.text(1.2, -0.2, 'x', color="black", size=15)
ax3b.text(0.1, 1.7, 'y', color="black", size=15)

fig3b.savefig("fig_diff_3b.pdf", bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_diff_4a

# %%
fig4a = plt.figure(figsize=(5,4))
ax4a = fig4a.add_axes([0,0,1,1])

ax4a.set_xlim(-0.5, 3)
ax4a.set_ylim(-0.5, 1.5)
ax4a.set_yticks([0.5, 1])
ax4a.set_xticks([np.pi/2])
labels_x = [item.get_text() for item in ax4a.get_xticklabels()]
labels_x[0] = '\u03C0/2'
ax4a.set_xticklabels(labels_x)
ax4a.text(-0.1, -0.1, '0', color="black", size=10)

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax4a.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax4a.spines[direction].set_position('zero')

ax4a.arrow(-0.5, 0, 3.6, 0., fc='k', ec='k', lw = .5, head_width=0.1, head_length=0.1, overhang = 0.3, length_includes_head= False, clip_on = False)
ax4a.arrow(0, -0.5, 0, 2.1, fc='k', ec='k', lw = .5, head_width=0.1, head_length=0.1, overhang = 0.3, length_includes_head= False, clip_on = False)

x = np.linspace(-0.3, np.pi/2, 100)
ax4a.plot(x, np.sin(x), color='black')
ax4a.plot([np.pi/2, 4], [1, 1], color='black')
ax4a.scatter([0], [0], color='black')

ax4a.text(3.2, -0.1, 'x', color="black", size=15)
ax4a.text(0.1, 1.7, 'y', color="black", size=15)

fig4a.savefig("fig_diff_4a.pdf", bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_diff_4b

# %%
fig4b = plt.figure(figsize=(5,4))
ax4b = fig4b.add_axes([0,0,1,1])

ax4b.set_xlim(-0.5, 3)
ax4b.set_ylim(-0.5, 1.5)
ax4b.set_yticks([0.5, 1])
ax4b.set_xticks([np.pi/2])
labels_x = [item.get_text() for item in ax4b.get_xticklabels()]
labels_x[0] = '\u03C0/2'
ax4b.set_xticklabels(labels_x)
ax4b.text(-0.1, -0.1, '0', color="black", size=10)

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax4b.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax4b.spines[direction].set_position('zero')

ax4b.arrow(-0.5, 0, 3.6, 0., fc='k', ec='k', lw = .5, head_width=0.1, head_length=0.1, overhang = 0.3, length_includes_head= False, clip_on = False)
ax4b.arrow(0, -0.5, 0, 2.1, fc='k', ec='k', lw = .5, head_width=0.1, head_length=0.1, overhang = 0.3, length_includes_head= False, clip_on = False)

x = np.linspace(-0.3, np.pi/2, 100)
ax4b.plot(x, np.cos(x), color='black', lw=2.5)
ax4b.plot([np.pi/2, 4], [0, 0], color='black', lw=2.5)

ax4b.text(3.2, -0.1, 'x', color="black", size=15)
ax4b.text(0.1, 1.7, 'y', color="black", size=15)

fig4b.savefig("fig_diff_4b.pdf", bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_diff_5

# %%
fig5 = plt.figure(figsize=(4,4))
ax5 = fig5.add_axes([0,0,1,1])

ax5.set_xlim(-0.1, 1.1)
ax5.set_ylim(-0.1, 1.1)
ax5.set_yticks([1])
ax5.set_xticks([1])
ax5.text(-0.05, -0.05, '0', color="black", size=10)

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax5.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax5.spines[direction].set_position('zero')

ax5.arrow(-0.1, 0, 1.2, 0., fc='k', ec='k', lw = .5, head_width=0.05, head_length=0.05, overhang = 0.3, length_includes_head= False, clip_on = False)
ax5.arrow(0, -0.1, 0, 1.2, fc='k', ec='k', lw = .5, head_width=0.05, head_length=0.05, overhang = 0.3, length_includes_head= False, clip_on = False)

x = np.linspace(0, 1, 100)
ax5.plot(x, x**(1/2), color='grey')
ax5.plot(x, x**(3/2), color='black')
ax5.scatter([0], [0], color='black', zorder=10)

ax5.text(0.1, 0.5, 'y=x$^{1/2}$', color="black", size=15)
ax5.text(0.4, 0.2, 'y=x$^{3/2}$', color="black", size=15)

ax5.text(1.15, -0.1, 'x', color="black", size=15)
ax5.text(0.05, 1.15, 'y', color="black", size=15)

fig5.savefig("fig_diff_5.pdf", bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_diff_6

# %%
fig6 = plt.figure(figsize=(4,4))
ax6 = fig6.add_axes([0,0,1,1])

ax6.set_xlim(-2.1, 2.1)
ax6.set_ylim(-4.1, 4.1)
ax6.set_yticks([-4, -2, 2, 4])
ax6.set_xticks([-2, -1, 1, 2])
ax6.text(-0.05, -0.05, '0', color="black", size=10)

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax6.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax6.spines[direction].set_position('zero')

ax6.arrow(-2.1, 0, 4.3, 0., fc='k', ec='k', lw = .5, head_width=0.2, head_length=0.1, overhang = 0.3, length_includes_head= False, clip_on = False)
ax6.arrow(0, -4.1, 0, 8.3, fc='k', ec='k', lw = .5, head_width=0.1, head_length=0.2, overhang = 0.3, length_includes_head= False, clip_on = False)

x = np.linspace(-2, 2, 100)
ax6.plot(x, 3*x**2, color='grey')
ax6.plot(x, x**3, color='black')
ax6.plot(x, 3*x+2, color='black', ls='--')
ax6.scatter([-1, -1], [3, -1], color='black', zorder=10)

ax6.text(2.4, -0.1, 'x', color="black", size=15)
ax6.text(0.2, 4.2, 'y', color="black", size=15)

fig6.savefig("fig_diff_6.pdf", bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_diff_6(tbc)

# %%
fig6tbc = plt.figure(figsize=(4,4))
ax6tbc = fig6tbc.add_axes([0,0,1,1])

ax6tbc.set_xlim(0, 4)
ax6tbc.set_ylim(-1, 16)
ax6tbc.set_yticks([5, 10, 15])
ax6tbc.set_xticks([1, 2, 3])
ax6tbc.text(-0.15, -0.1, '0', color="black", size=10)

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax6tbc.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax6tbc.spines[direction].set_position('zero')

ax6tbc.arrow(0, 0, 4.1, 0., fc='k', ec='k', lw = .5, head_width=0.5, head_length=0.1, overhang = 0.3, length_includes_head= False, clip_on = False)
ax6tbc.arrow(0, -1, 0, 17.1, fc='k', ec='k', lw = .5, head_width=0.1, head_length=0.5, overhang = 0.3, length_includes_head= False, clip_on = False)

x = np.linspace(0, 4, 100)
ax6tbc.plot(x, x**2, color='black')
ax6tbc.plot(x, 6*x-9, color='grey')
ax6tbc.plot(x, 2*x-1, color='grey')

ax6tbc.text(4.3, -0.1, 'x', color="black", size=15)
ax6tbc.text(0.2, 16.2, 'y', color="black", size=15)

fig6tbc.savefig("fig_diff_6.pdf", bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Impliciete afgleiden

# %% [markdown]
# ### fig_diff_7

# %%
fig7 = plt.figure(figsize=(4,4))
ax7 = fig7.add_axes([0,0,1,1])

ax7.set_xlim(-3, 3)
ax7.set_ylim(-2, 2)
ax7.set_yticks([-2, -1, 1, 2])
ax7.set_xticks([-2, 2])
ax7.text(-0.15, -0.1, '0', color="black", size=10)

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax7.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax7.spines[direction].set_position('zero')

ax7.arrow(-3, 0, 6.1, 0., fc='k', ec='k', lw = .5, head_width=0.15, head_length=0.15, overhang = 0.3, length_includes_head= False, clip_on = False)
ax7.arrow(0, -2, 0, 4.1, fc='k', ec='k', lw = .5, head_width=0.15, head_length=0.15, overhang = 0.3, length_includes_head= False, clip_on = False)

x, y = np.meshgrid(np.linspace(-3, 3, 100), np.linspace(-3, 3, 100))
F = np.sin(y) + y**3 + x**3 - 6
ax7.contour(x, y, F, [0], colors='black')

x = np.linspace(0, 3, 100)
ax7.plot(x, -9.91*x+18, color='black', ls='--')

ax7.text(3.3, -0.1, 'x', color="black", size=15)
ax7.text(0.2, 2.2, 'y', color="black", size=15)

fig7.savefig("fig_diff_7.pdf", bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_diff_8

# %%
fig8 = plt.figure(figsize=(4,4))
ax8 = fig8.add_axes([0,0,1,1])

ax8.set_xlim(-2, 1.8)
ax8.set_ylim(-2, 2)
ax8.set_yticks([-1, 1])
ax8.set_xticks([-1, 1])
ax8.text(-0.15, -0.1, '0', color="black", size=10)

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax8.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax8.spines[direction].set_position('zero')

ax8.arrow(-2, 0, 3.9, 0., fc='k', ec='k', lw = .5, head_width=0.15, head_length=0.15, overhang = 0.3, length_includes_head= False, clip_on = False)
ax8.arrow(0, -2, 0, 4.1, fc='k', ec='k', lw = .5, head_width=0.15, head_length=0.15, overhang = 0.3, length_includes_head= False, clip_on = False)

x, y = np.meshgrid(np.linspace(-3, 3, 100), np.linspace(-3, 3, 100))
F = np.sin(x**2 * y**2) + y**3 - x - y
ax8.contour(x, y, F, [0], colors='black')

x = np.linspace(-1, 1, 100)
ax8.plot(x, x/2 - 1, color='black', ls='--')
ax8.plot(x, x/2 + 1, color='black', ls='--')

ax8.text(2.1, -0.1, 'x', color="black", size=15)
ax8.text(0.1, 2.2, 'y', color="black", size=15)

fig8.savefig("fig_diff_8.pdf", bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_diff_9

# %%
fig9 = plt.figure(figsize=(4,4))
ax9 = fig9.add_axes([0,0,1,1])

ax9.set_xlim(0, 2)
ax9.set_ylim(0, 4)
ax9.set_yticks([1, 2, 3, 4])
ax9.set_xticks([0, 1, 2])

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax9.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax9.spines[direction].set_position('zero')

ax9.arrow(0, 0, 2.1, 0., fc='k', ec='k', lw = .5, head_width=0.1, head_length=0.05, overhang = 0.3, length_includes_head= False, clip_on = False)
ax9.arrow(0, 0, 0, 4.1, fc='k', ec='k', lw = .5, head_width=0.05, head_length=0.1, overhang = 0.3, length_includes_head= False, clip_on = False)

x = np.linspace(0, 2, 100)
ax9.plot(x, x**x, color='black')

ax9.text(2.25, 0, 'x', color="black", size=15)
ax9.text(0.1, 4.2, 'y', color="black", size=15)
fig9.savefig("fig_diff_9.pdf", bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Afgeleiden van inverse functies

# %% [markdown]
# ### fig_diff_10

# %%
fig10 = plt.figure(figsize=(4,4))
ax10 = fig10.add_axes([0,0,1,1])

ax10.set_xlim(-2, 2)
ax10.set_ylim(-2, 2)
ax10.set_yticks([-2, -1, 1, 2])
ax10.set_xticks([-2, -1, 1, 2])

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax10.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax10.spines[direction].set_position('zero')

ax10.arrow(-2, 0, 4.1, 0., fc='k', ec='k', lw = .5, head_width=0.1, head_length=0.1, overhang = 0.3, length_includes_head= False, clip_on = False)
ax10.arrow(0, -2, 0, 4.1, fc='k', ec='k', lw = .5, head_width=0.1, head_length=0.1, overhang = 0.3, length_includes_head= False, clip_on = False)

ax10.plot([-1.5, 1.5], [-1.5, 1.5], color='black', ls=':')

x = np.linspace(-1, 1.05)
ax10.plot(x, x**3+0.5, color='grey')

x = np.linspace(-1, 1.05)
ax10.plot(x**3+0.5, x, color='black')

x = np.linspace(-0.95, -0.05)
ax10.plot(x, 3*x/4+3/4, color='black', ls='--')
ax10.plot(3*x/4+3/4, x, color='black', ls='--')

ax10.scatter([3/8, -1/2], [-1/2, 3/8], color='black', zorder=10)

ax10.text(0.5, -0.6, '(a,b)', color="black", size=15)
ax10.text(-0.7, 0.6, '(b,a)', color="black", size=15)

ax10.text(2.3, 0, 'x', color="black", size=15)
ax10.text(0.1, 2.2, 'y', color="black", size=15)
fig10.savefig("fig_diff_10.pdf", bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_diff_11

# %%
fig11 = plt.figure(figsize=(4,4))
ax11 = fig11.add_axes([0,0,1,1])
ax11.set_xlim(-0.1, 1.1)
ax11.set_ylim(-0.1, 1)

ax11.set_yticks([])
ax11.set_xticks([])
for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax11.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax11.spines[direction].set_position('zero')

ax11.plot([0, 1, 1, 0], [0, 0, np.tan(0.2*np.pi), 0], color="black")

ax11.text(0.4, 0.4, '1', color="black", size=15)
ax11.text(0.15, 0.05, 'y', color="black", size=15)
ax11.text(1.05, 0.3, 'x', color="black", size=15)
ax11.text(0.4, -0.15, '$\sqrt{1-x^2}$', color="black", size=15)

fig11.savefig("fig_diff_11.pdf",bbox_inches='tight')
plt.show()

# %% [markdown]
# ## De methode van Newton

# %% [markdown]
# ### fig_diff_12a

# %%
fig12a = plt.figure(figsize=(5,4))
ax12a = fig12a.add_axes([0,0,1,1])

ax12a.set_xlim(-0.5, 2.75)
ax12a.set_ylim(-1.5, 1.5)
ax12a.set_yticks([-1, -0.5, 0.5, 1])
ax12a.set_xticks([0.5, 2.33049])
labels_x = [item.get_text() for item in ax12a.get_xticklabels()]
labels_x[0] = 'x$_0$'
labels_x[1] = 'x$_1$'
ax12a.set_xticklabels(labels_x)
ax12a.text(-0.1, -0.1, '0', color="black", size=10)

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax12a.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax12a.spines[direction].set_position('zero')

ax12a.arrow(-0.5, 0, 3.25, 0., fc='k', ec='k', lw = .5, head_width=0.1, head_length=0.1, overhang = 0.3, length_includes_head= False, clip_on = False)
ax12a.arrow(0, -1.5, 0, 3.1, fc='k', ec='k', lw = .5, head_width=0.1, head_length=0.1, overhang = 0.3, length_includes_head= False, clip_on = False)

x = np.linspace(-0.5, 2.75, 100)
ax12a.plot(x, np.cos(x), color='black', lw=2.5)
x = np.linspace(0.3, 2.33049, 100)
ax12a.plot(x, -np.sin(0.5) * (x-0.5) + np.cos(0.5), color='grey')
ax12a.plot([0.5, 0.5], [0, np.cos(0.5)], color='black', ls='--')
ax12a.scatter([0.5], [np.cos(0.5)], color='black', zorder=10)

ax12a.text(2.9, -0.1, 'x', color="black", size=15)
ax12a.text(0.1, 1.7, 'y', color="black", size=15)

fig12a.savefig("fig_diff_12a.pdf", bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_diff_12b

# %%
fig12b = plt.figure(figsize=(5,4))
ax12b = fig12b.add_axes([0,0,1,1])

ax12b.set_xlim(-0.5, 2.75)
ax12b.set_ylim(-1.5, 1.5)
ax12b.set_yticks([-1, -0.5, 0.5, 1])
ax12b.set_xticks([0.5, 2.33049, 1.38062])
labels_x = [item.get_text() for item in ax12b.get_xticklabels()]
labels_x[0] = 'x$_0$'
labels_x[1] = 'x$_1$'
labels_x[2] = 'x$_2$'
ax12b.set_xticklabels(labels_x)
ax12b.text(-0.1, -0.1, '0', color="black", size=10)

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax12b.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax12b.spines[direction].set_position('zero')

ax12b.arrow(-0.5, 0, 3.25, 0., fc='k', ec='k', lw = .5, head_width=0.1, head_length=0.1, overhang = 0.3, length_includes_head= False, clip_on = False)
ax12b.arrow(0, -1.5, 0, 3.1, fc='k', ec='k', lw = .5, head_width=0.1, head_length=0.1, overhang = 0.3, length_includes_head= False, clip_on = False)

x = np.linspace(-0.5, 2.75, 100)
ax12b.plot(x, np.cos(x), color='black', lw=2.5)
x = np.linspace(1.38062, 2.53049, 100)
ax12b.plot(x, -np.sin(2.33049) * (x-2.33049) + np.cos(2.33049), color='grey')
ax12b.plot([2.33049, 2.33049], [0, np.cos(2.33049)], color='black', ls='--')
ax12b.scatter([2.33049], [np.cos(2.33049)], color='black', zorder=10)

ax12b.text(2.9, -0.1, 'x', color="black", size=15)
ax12b.text(0.1, 1.7, 'y', color="black", size=15)

fig12b.savefig("fig_diff_12b.pdf", bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_diff_12c

# %%
fig12c = plt.figure(figsize=(5,4))
ax12c = fig12c.add_axes([0,0,1,1])

ax12c.set_xlim(-0.5, 2.75)
ax12c.set_ylim(-1.5, 1.5)
ax12c.set_yticks([-1, -0.5, 0.5, 1])
ax12c.set_xticks([0.5, 2.33049, 1.38062, 1.57312])
labels_x = [item.get_text() for item in ax12c.get_xticklabels()]
labels_x[0] = 'x$_0$'
labels_x[1] = 'x$_1$'
labels_x[2] = 'x$_2$'
labels_x[3] = 'x$_3$'
ax12c.set_xticklabels(labels_x)
ax12c.text(-0.1, -0.1, '0', color="black", size=10)

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax12c.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax12c.spines[direction].set_position('zero')

ax12c.arrow(-0.5, 0, 3.25, 0., fc='k', ec='k', lw = .5, head_width=0.1, head_length=0.1, overhang = 0.3, length_includes_head= False, clip_on = False)
ax12c.arrow(0, -1.5, 0, 3.1, fc='k', ec='k', lw = .5, head_width=0.1, head_length=0.1, overhang = 0.3, length_includes_head= False, clip_on = False)

x = np.linspace(-0.5, 2.75, 100)
ax12c.plot(x, np.cos(x), color='black', lw=2.5)
x = np.linspace(1.18062, 1.57312, 10)
ax12c.plot(x, -np.sin(1.57312) * (x-1.57312) + np.cos(1.57312), color='grey')
ax12c.plot([1.38062, 1.38062], [0, np.cos(1.38062)], color='black', ls='--')
ax12c.scatter([1.38062], [np.cos(1.38062)], color='black', zorder=10)

ax12c.text(2.9, -0.1, 'x', color="black", size=15)
ax12c.text(0.1, 1.7, 'y', color="black", size=15)

fig12c.savefig("fig_diff_12c.pdf", bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_diff_13

# %%
fig13 = plt.figure(figsize=(4,4))
ax13 = fig13.add_axes([0,0,1,1])

ax13.set_xlim(0, 1.7)
ax13.set_ylim(-1.5, 0.5)
ax13.set_yticks([-1, -0.5])
ax13.set_xticks([0.5, 1, 1.5])
ax13.text(-0.05, 0, '0', color="black", size=10)

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax13.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax13.spines[direction].set_position('zero')

ax13.arrow(0, 0, 1.8, 0., fc='k', ec='k', lw = .5, head_width=0.1, head_length=0.05, overhang = 0.3, length_includes_head= False, clip_on = False)
ax13.arrow(0, -1.5, 0, 2.1, fc='k', ec='k', lw = .5, head_width=0.05, head_length=0.1, overhang = 0.3, length_includes_head= False, clip_on = False)

x = np.linspace(0, 1.7, 100)
ax13.plot(x, x**3-x**2-1, color='black')

ax13.text(1.9, 0, 'x', color="black", size=15)
ax13.text(0.1, 0.7, 'y', color="black", size=15)
fig13.savefig("fig_diff_13.pdf", bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_diff_14

# %%
fig14 = plt.figure(figsize=(4,4))
ax14 = fig14.add_axes([0,0,1,1])

ax14.set_xlim(-0.5, 1.7)
ax14.set_ylim(-1.5, 0.5)
ax14.set_yticks([-1, -0.5])
ax14.set_xticks([-0.5, 0.5, 1, 1.5])
ax14.text(-0.05, 0, '0', color="black", size=10)

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax14.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax14.spines[direction].set_position('zero')

ax14.arrow(-0.5, 0, 2.3, 0., fc='k', ec='k', lw = .5, head_width=0.05, head_length=0.05, overhang = 0.3, length_includes_head= False, clip_on = False)
ax14.arrow(0, -1.5, 0, 2.1, fc='k', ec='k', lw = .5, head_width=0.05, head_length=0.05, overhang = 0.3, length_includes_head= False, clip_on = False)

x = np.linspace(-0.5, 1.7, 100)
ax14.plot(x, x**3-x**2-1, color='black')
ax14.plot([-0.5, 1.7], [-1, -1], color='grey')

ax14.text(1.9, 0, 'x', color="black", size=15)
ax14.text(0.1, 0.7, 'y', color="black", size=15)
fig14.savefig("fig_diff_14.pdf", bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_diff_15a

# %%
fig15a = plt.figure(figsize=(5,4))
ax15a = fig15a.add_axes([0,0,1,1])

ax15a.set_xlim(-1, 1)
ax15a.set_ylim(-1, 1)
ax15a.set_yticks([-1, -0.5, 0.5, 1])
ax15a.set_xticks([0.1, -0.2])
labels_x = [item.get_text() for item in ax15a.get_xticklabels()]
labels_x[0] = 'x$_0$'
labels_x[1] = 'x$_1$'
ax15a.set_xticklabels(labels_x)
ax15a.text(-0.1, -0.1, '0', color="black", size=10)

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax15a.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax15a.spines[direction].set_position('zero')

ax15a.arrow(-1, 0, 2.1, 0., fc='k', ec='k', lw = .5, head_width=0.05, head_length=0.05, overhang = 0.3, length_includes_head= False, clip_on = False)
ax15a.arrow(0, -1, 0, 2.1, fc='k', ec='k', lw = .5, head_width=0.05, head_length=0.05, overhang = 0.3, length_includes_head= False, clip_on = False)

x = np.linspace(-1, 1, 100)
ax15a.plot(x, np.cbrt(x), color='black', lw=2.5)

x = np.linspace(0.3, -0.2, 100)
ax15a.plot(x, 1/(3*np.cbrt(0.1)**2) * (x - 0.1) + np.cbrt(0.1), color='grey')
ax15a.plot([0.1, 0.1], [0, np.cbrt(0.1)], color='black', ls='--')
ax15a.scatter([0.1], [np.cbrt(0.1)], color='black', zorder=10)

ax15a.text(1.1, -0.1, 'x', color="black", size=15)
ax15a.text(0.05, 1.1, 'y', color="black", size=15)

fig15a.savefig("fig_diff_15a.pdf", bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_diff_15b

# %%
fig15b = plt.figure(figsize=(5,4))
ax15b = fig15b.add_axes([0,0,1,1])

ax15b.set_xlim(-1, 1)
ax15b.set_ylim(-1, 1)
ax15b.set_yticks([-1, -0.5, 0.5, 1])
ax15b.set_xticks([0.1, -0.2, 0.4])
labels_x = [item.get_text() for item in ax15b.get_xticklabels()]
labels_x[0] = 'x$_0$'
labels_x[1] = 'x$_1$'
labels_x[2] = 'x$_2$'
ax15b.set_xticklabels(labels_x)
ax15b.text(-0.1, -0.1, '0', color="black", size=10)

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax15b.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax15b.spines[direction].set_position('zero')

ax15b.arrow(-1, 0, 2.1, 0., fc='k', ec='k', lw = .5, head_width=0.05, head_length=0.05, overhang = 0.3, length_includes_head= False, clip_on = False)
ax15b.arrow(0, -1, 0, 2.1, fc='k', ec='k', lw = .5, head_width=0.05, head_length=0.05, overhang = 0.3, length_includes_head= False, clip_on = False)

x = np.linspace(-1, 1, 100)
ax15b.plot(x, np.cbrt(x), color='black', lw=2.5)

x = np.linspace(-0.2, 0.4, 100)
ax15b.plot(x, 1/(3*np.cbrt(-0.2)**2) * (x + 0.2) + np.cbrt(-0.2), color='grey')
ax15b.plot([-0.2, -0.2], [0, np.cbrt(-0.2)], color='black', ls='--')
ax15b.scatter([-0.2], [np.cbrt(-0.2)], color='black', zorder=10)

ax15b.text(1.1, -0.1, 'x', color="black", size=15)
ax15b.text(0.05, 1.1, 'y', color="black", size=15)

fig15b.savefig("fig_diff_15b.pdf", bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_diff_15c

# %%
fig15c = plt.figure(figsize=(5,4))
ax15c = fig15c.add_axes([0,0,1,1])

ax15c.set_xlim(-1, 1)
ax15c.set_ylim(-1, 1)
ax15c.set_yticks([-1, -0.5, 0.5, 1])
ax15c.set_xticks([0.1, -0.2, 0.4, -0.8])
labels_x = [item.get_text() for item in ax15c.get_xticklabels()]
labels_x[0] = 'x$_0$'
labels_x[1] = 'x$_1$'
labels_x[2] = 'x$_2$'
labels_x[3] = 'x$_3$'
ax15c.set_xticklabels(labels_x)
ax15c.text(-0.1, -0.1, '0', color="black", size=10)

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax15c.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax15c.spines[direction].set_position('zero')

ax15c.arrow(-1, 0, 2.1, 0., fc='k', ec='k', lw = .5, head_width=0.05, head_length=0.05, overhang = 0.3, length_includes_head= False, clip_on = False)
ax15c.arrow(0, -1, 0, 2.1, fc='k', ec='k', lw = .5, head_width=0.05, head_length=0.05, overhang = 0.3, length_includes_head= False, clip_on = False)

x = np.linspace(-1, 1, 100)
ax15c.plot(x, np.cbrt(x), color='black', lw=2.5)

x = np.linspace(0.4, -0.8, 100)
ax15c.plot(x, 1/(3*np.cbrt(0.4)**2) * (x - 0.4) + np.cbrt(0.4), color='grey')
ax15c.plot([0.4, 0.4], [0, np.cbrt(0.4)], color='black', ls='--')
ax15c.scatter([0.4], [np.cbrt(0.4)], color='black', zorder=10)

ax15c.text(1.2, -0.1, 'x', color="black", size=15)
ax15c.text(0.1, 1.2, 'y', color="black", size=15)

fig15c.savefig("fig_diff_15c.pdf", bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_diff_16

# %%
fig16 = plt.figure(figsize=(5,4))
ax16 = fig16.add_axes([0,0,1,1])

ax16.set_yticks([])
ax16.set_xticks([])

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax16.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax16.spines[direction].set_position('zero')

ax16.arrow(-0.02, -0.55, 0, 0.1, fc='k', ec='k', lw = .5, head_width=0.02, head_length=0.02, overhang = 0.3, length_includes_head= False, clip_on = False)
ax16.arrow(0.45, 0.05, 0.1, 0, fc='k', ec='k', lw = .5, head_width=0.02, head_length=0.02, overhang = 0.3, length_includes_head= False, clip_on = False)

ax16.plot([-0.1, 0.6], [0, 0], color='black')
ax16.plot([0, 0], [0.1, -0.6], color='black')
ax16.plot([0, 0.5], [-0.5, 0], color='grey')
ax16.scatter([0, 0.5], [-0.5, 0], color=['grey', 'black'], zorder=10)

ax16.text(0, -0.55, 'Officer', color="black", size=15)
ax16.text(0.5, -0.05, 'Car', color="black", size=15)
ax16.text(0.3, -0.25, 'c', color="black", size=15)
ax16.text(-0.04, -0.3, 'A = 1/2', color="black", size=15, rotation=90)
ax16.text(0.2, 0.01, 'B = 1/2', color="black", size=15)

ax16.text(0.62, -0.01, 'E', color="black", size=15)
ax16.text(-0.01, 0.15, 'N', color="black", size=15)

fig16.savefig("fig_diff_16.pdf", bbox_inches='tight')
plt.show()
