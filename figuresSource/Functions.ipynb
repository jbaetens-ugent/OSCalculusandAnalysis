# %% [markdown]
# # Hoofdstuk 3 Functies

# %%
from mpl_toolkits.axisartist.axislines import SubplotZero
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
matplotlib.rcParams["font.family"] = "monospace"
matplotlib.rcParams['font.style'] = "italic"
plt.rcParams.update({'mathtext.default':  'regular' })

# %% [markdown]
# ## 1.1 Het cartesisch coördinatenstelsel

# %% [markdown]
# ### fig_functions_1

# %%
fig1 = plt.figure(figsize=(6,4))
ax1 = fig1.add_axes([0, 0, 1, 1])
ax1.axhline(linewidth=0, color="black")
ax1.axvline(linewidth=0, color="black")
ax1.set_yticks([-4, -2, 2, 4])
ax1.set_xticks([-4, -2, 2, 4])
ax1.text(-0.3, -0.5, '0', color="black", size=10)

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax1.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax1.spines[direction].set_position('zero')

ax1.arrow(-5, 0, 10.1, 0., fc='k', ec='k', lw = .5, head_width=0.4, head_length=0.4, overhang = 0.3, length_includes_head= False, clip_on = False)
ax1.arrow(0, -5, 0, 10.1, fc='k', ec='k', lw = .5, head_width=0.3, head_length=0.5, overhang = 0.3, length_includes_head= False, clip_on = False)

ax1.set_xlim(-5, 5)
ax1.set_ylim(-5, 5)
ax1.plot([0, 2], [-4, -4], color="black", linestyle='--')
ax1.plot([2, 2], [0, -4],  color="black", linestyle='--')
ax1.plot([2], [-4],  color="black", marker='o', markersize=10)
ax1.text(2.7, -4, 'P(2,-4)', size=15)
ax1.text(5.1, -1, 'x', color="black", size=15)
ax1.text(0.2, 5.1, 'y', color="black", size=15)
fig1.savefig("fig_functions_1.png",bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_functions_1(tbc)

# %%
fig1tbc = plt.figure(figsize=(6,4))
ax1tbc = fig1tbc.add_axes([0, 0, 1, 1])
ax1tbc.axhline(linewidth=0, color="black")
ax1tbc.axvline(linewidth=0, color="black")
ax1tbc.set_yticks([-4, -2, 2, 4])
ax1tbc.set_xticks([-4, -2, 2, 4])
ax1tbc.text(-0.3, -0.5, '0', color="black", size=10)

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax1tbc.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax1tbc.spines[direction].set_position('zero')

ax1tbc.arrow(-5, 0, 10.1, 0., fc='k', ec='k', lw = .5, head_width=0.4, head_length=0.4, overhang = 0.3, length_includes_head= False, clip_on = False)
ax1tbc.arrow(0, -5, 0, 10.1, fc='k', ec='k', lw = .5, head_width=0.3, head_length=0.5, overhang = 0.3, length_includes_head= False, clip_on = False)

ax1tbc.set_xlim(-5, 5)
ax1tbc.set_ylim(-5, 5)
ax1tbc.text(5.1, -1, 'x', color="black", size=15)
ax1tbc.text(0.2, 5.1, 'y', color="black", size=15)
fig1tbc.savefig("fig_functions_1(tbc).pdf",bbox_inches='tight')
plt.show()

# %% [markdown]
# ## 1.2 Functies

# %% [markdown]
# ### fig_functions_2

# %%
# fig2 = plt.figure(figsize=(6,4))
# ax2 = fig2.add_axes([0, 0, 1, 1])
# ax2.set_yticks([-4, -2, 2, 4])
# ax2.set_xticks([-4, -2, 2, 4])
# ax2.text(-0.3, -0.5, '0', color="black", size=10)

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax2.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax2.spines[direction].set_position('zero')

ax2.arrow(-5, 0, 10.1, 0., fc='k', ec='k', lw = .5, head_width=0.5, head_length=0.3, overhang = 0.3, length_includes_head= False, clip_on = False)
ax2.arrow(0, -5, 0, 10.1, fc='k', ec='k', lw = .5, head_width=0.3, head_length=0.5, overhang = 0.3, length_includes_head= False, clip_on = False)

ax2.set_xlim(-5, 5)
ax2.set_ylim(-5, 5)
ax2.text(2, 2, 'Quadrant I \n x>0 and y>0', size=15)
ax2.text(-4, 2, 'Quadrant II \n x<0 and y>0', size=15)
ax2.text(-4, -4, 'Quadrant III \n x<0 and y<0', size=15)
ax2.text(2, -4, 'Quadrant IV \n x>0 and y<0', size=15)

ax2.text(5.1, -1, 'x', color="black", size=15)
ax2.text(0.2, 5.1, 'y', color="black", size=15)
fig2.savefig("fig_functions_2.png",bbox_inches='tight')
plt.show()

# %%
fig2 = plt.figure(figsize=(6,4))
ax2 = fig2.add_axes([0, 0, 1, 1])
ax2.set_yticks([-4, -2, 2, 4])
ax2.set_xticks([-4, -2, 2, 4])
ax2.text(-0.3, -0.5, '0', color="black", size=10)

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax2.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax2.spines[direction].set_position('zero')

ax2.arrow(-5, 0, 10.1, 0., fc='k', ec='k', lw = .5, head_width=0.5, head_length=0.3, overhang = 0.3, length_includes_head= False, clip_on = False)
ax2.arrow(0, -5, 0, 10.1, fc='k', ec='k', lw = .5, head_width=0.3, head_length=0.5, overhang = 0.3, length_includes_head= False, clip_on = False)

ax2.set_xlim(-5, 5)
ax2.set_ylim(-5, 5)
ax2.scatter([4, 4, -4, -4], [4, -4, 4, -4], color="black", marker="o")
ax2.text(2, 1.75, 'Quadrant I \n x>0 and y>0', size=14)
ax2.text(-4, 1.75, 'Quadrant II \n x<0 and y>0', size=14)
ax2.text(-4, -2.75, 'Quadrant III \n x<0 and y<0', size=14)
ax2.text(2, -2.75, 'Quadrant IV \n x>0 and y<0', size=14)

ax2.text(4.2, 3.8, 'P(x,y)', color="black", size=15)
ax2.text(-3.8, 3.8, 'Q(-x,y)', color="black", size=15)
ax2.text(-3.8, -4.2, 'R(-x,-y)', color="black", size=15)
ax2.text(4.2, -4.2, 'S(x,-y)', color="black", size=15)

ax2.text(5.1, -1, 'x', color="black", size=15)
ax2.text(0.2, 5.1, 'y', color="black", size=15)
fig2.savefig("fig_functions_2.pdf",bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_functions_3a

# %%
fig3a = plt.figure(figsize=(6,4))
ax3a = fig3a.add_axes([0, 0, 1, 1])
ax3a.set_yticks([-1, 1, 2, 3, 4, 5])
ax3a.set_xticks([-4, -2, 2, 4])
ax3a.text(-0.3, -0.3, '0', color="black", size=10)

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax3a.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax3a.spines[direction].set_position('zero')

ax3a.arrow(-5, 0, 10.1, 0., fc='k', ec='k', lw = .5, head_width=0.3, head_length=0.3, overhang = 0.3, length_includes_head= False, clip_on = False)
ax3a.arrow(0, -1, 0, 6.1, fc='k', ec='k', lw = .5, head_width=0.3, head_length=0.3, overhang = 0.3, length_includes_head= False, clip_on = False)

ax3a.set_xlim(-5, 5)
ax3a.set_ylim(-1, 5)
ax3a.scatter([0, -3, 4, -3], [0, 1, 2, 2], color="black", marker="o")
ax3a.text(5.1, -0.5, 'x', color="black", size=15)
ax3a.text(0.2, 5.1, 'y', color="black", size=15)
fig3a.savefig("fig_functions_3a.pdf",bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_functions_3b

# %%
fig3b = plt.figure(figsize=(6,4))
ax3b = fig3b.add_axes([0,0,1,1])
ax3b.set_yticks([-4, -2, 2, 4])
ax3b.set_xticks([-4, -2, 2, 4])
ax3b.text(-0.3, -0.5, '0', color="black", size=10)

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax3b.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax3b.spines[direction].set_position('zero')

ax3b.arrow(-5, 0, 10.1, 0., fc='k', ec='k', lw = .5, head_width=0.4, head_length=0.4, overhang = 0.3, length_includes_head= False, clip_on = False)
ax3b.arrow(0, -5, 0, 10.1, fc='k', ec='k', lw = .5, head_width=0.3, head_length=0.5, overhang = 0.3, length_includes_head= False, clip_on = False)

ax3b.set_xlim(-5, 5)
ax3b.set_ylim(-5, 5)
ax3b.plot([-2, 4], [3, 3], color="black", marker="o")
ax3b.text(5.1, -1, 'x', color="black", size=15)
ax3b.text(0.2, 5.1, 'y', color="black", size=15)
fig3b.savefig("fig_functions_3b.pdf",bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_functions_3c

# %%
fig3c = plt.figure(figsize=(6,4))
ax3c = fig3c.add_axes([0,0,1,1])
ax3c.set_yticks([-4, -2, 2, 4])
ax3c.set_xticks([-1, 1, 2, 3, 4, 5])
ax3c.text(-0.2, -0.5, '0', color="black", size=10)

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax3c.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax3c.spines[direction].set_position('zero')

ax3c.arrow(-1, 0, 6.1, 0., fc='k', ec='k', lw = .5, head_width=0.5, head_length=0.2, overhang = 0.3, length_includes_head= False, clip_on = False)
ax3c.arrow(0, -5, 0, 10.1, fc='k', ec='k', lw = .5, head_width=0.2, head_length=0.5, overhang = 0.3, length_includes_head= False, clip_on = False)

ax3c.set_xlim(-1, 5)
ax3c.set_ylim(-5, 5)
ax3c.plot([3, 3], [-6, 6], color="black")
ax3c.text(5.1, -1, 'x', color="black", size=15)
ax3c.text(0.2, 5.1, 'y', color="black", size=15)
fig3c.savefig("fig_functions_3c.pdf",bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_functions_4

# %%
fig4 = plt.figure(figsize=(6,4))
ax4 = fig4.add_axes([0,0,1,1])
ax4.set_yticks([-4, -2, 2, 4])
ax4.set_xticks([-4, -2, 2, 4])
ax4.text(-0.3, -0.5, '0', color="black", size=10)

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax4.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax4.spines[direction].set_position('zero')

ax4.arrow(-5, 0, 10.1, 0., fc='k', ec='k', lw = .5, head_width=0.4, head_length=0.3, overhang = 0.3, length_includes_head= False, clip_on = False)
ax4.arrow(0, -5, 0, 10.1, fc='k', ec='k', lw = .5, head_width=0.3, head_length=0.5, overhang = 0.3, length_includes_head= False, clip_on = False)

ax4.set_xlim(-5, 5)
ax4.set_ylim(-5, 5)
ax4.scatter([-3, -2, -1, 0, 1, 2, 3], [-2, -3**(1/3), 0, 1, 0, -3**(1/3), -2], color="black")
ax4.text(5.1, -1, 'x', color="black", size=15)
ax4.text(0.2, 5.1, 'y', color="black", size=15)
fig4.savefig("fig_functions_4.pdf", bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_functions_4(tbc)

# %%
fig4tbc = plt.figure(figsize=(6,4))
ax4tbc = fig4tbc.add_axes([0,0,1,1])
ax4tbc.set_yticks([-4, -2, 2, 4])
ax4tbc.set_xticks([-4, -2, 2, 4])
ax4tbc.text(-0.3, -0.5, '0', color="black", size=10)

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax4tbc.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax4tbc.spines[direction].set_position('zero')

ax4tbc.arrow(-5, 0, 10.1, 0., fc='k', ec='k', lw = .5, head_width=0.4, head_length=0.3, overhang = 0.3, length_includes_head= False, clip_on = False)
ax4tbc.arrow(0, -5, 0, 10.1, fc='k', ec='k', lw = .5, head_width=0.3, head_length=0.5, overhang = 0.3, length_includes_head= False, clip_on = False)

ax4tbc.set_xlim(-5, 5)
ax4tbc.set_ylim(-5, 5)
x=2.5
y=2.5
ax4tbc.scatter([x, -x, x, -x], [y, y, -y, -y], color="black")

ax4tbc.text(2, 3, 'P(x,y)', color="black", size=15)
ax4tbc.text(-3, 3, 'Q(-x,y)', color="black", size=15)
ax4tbc.text(1.8, -3.2, 'S(x,-y)', color="black", size=15)
ax4tbc.text(-3.2, -3.2, 'R(-x,-y)', color="black", size=15)

ax4tbc.text(5.1, -1, 'x', color="black", size=15)
ax4tbc.text(0.2, 5.1, 'y', color="black", size=15)
fig4tbc.savefig("fig_functions_4(tbc).pdf", bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_functions_5

# %%
fig5 = plt.figure(figsize=(6,4))
ax5 = fig5.add_axes([0,0,1,1])
ax5.set_yticks([-4, -2, 2, 4])
ax5.set_xticks([-4, -2, 2, 4])
ax5.text(-0.3, -0.5, '0', color="black", size=10)

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax5.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax5.spines[direction].set_position('zero')

ax5.arrow(-5, 0, 10.1, 0., fc='k', ec='k', lw = .5, head_width=0.4, head_length=0.3, overhang = 0.3, length_includes_head= False, clip_on = False)
ax5.arrow(0, -5, 0, 10.1, fc='k', ec='k', lw = .5, head_width=0.3, head_length=0.5, overhang = 0.3, length_includes_head= False, clip_on = False)

ax5.set_xlim(-5, 5)
ax5.set_ylim(-5, 5)
y=np.linspace(-3, 1, 100)
ax5.plot(np.sqrt(1-y**3), y, color='black')
ax5.plot(-np.sqrt(1-y**3), y, color='black')

ax5.text(5.1, -1, 'x', color="black", size=15)
ax5.text(0.2, 5.1, 'y', color="black", size=15)
fig5.savefig("fig_functions_5.pdf", bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_functions_6_Python

# %%
from sympy import plot_implicit, symbols, Eq
x, y = symbols('x y')
graph6 = plot_implicit(Eq(x**2 + y**3, 1), show=False)

graph6.save('fig_functions_6_Python.pdf')

# %% [markdown]
# ### fig_functions_7

# %%
fig7 = plt.figure(figsize=(6,4))
ax7 = fig7.add_axes([0,0,1,1])
ax7.set_yticks([-1, 1])
ax7.set_xticks([-1, 1, 2, 3, 4])
ax7.text(-0.15, -0.2, '0', color="black", size=10)

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax7.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax7.spines[direction].set_position('zero')

ax7.arrow(-1, 0, 5.1, 0., fc='k', ec='k', lw = .5, head_width=0.2, head_length=0.2, overhang = 0.3, length_includes_head= False, clip_on = False)
ax7.arrow(0, -2, 0, 4.1, fc='k', ec='k', lw = .5, head_width=0.15, head_length=0.2, overhang = 0.3, length_includes_head= False, clip_on = False)

ax7.set_xlim(-1, 4)
ax7.set_ylim(-2, 2)
ax7.scatter([1, 3, 2, 2, 1.5, 1.5, 2.5, 2.5], [0, 0, 1, -1, np.sqrt(1-0.5**2), -np.sqrt(1-0.5**2), -np.sqrt(1-0.5**2), np.sqrt(1-0.5**2)], color="black")
ax7.text(4.3, -0.3, 'x', color="black", size=15)
ax7.text(0.1, 2.1, 'y', color="black", size=15)
fig7.savefig("fig_functions_7.pdf", bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_functions_9a

# %%
fig9a = plt.figure(figsize=(6,4))
ax9a = SubplotZero(fig9a, 111)
fig9a.add_subplot(ax9a)

ax9a.set_xlim(-5, 5)
ax9a.set_ylim(-5, 5)
ax9a.set_xlabel("x")
ax9a.set_ylabel("y")
x, y = np.meshgrid(np.linspace(-5, 5, 100), np.linspace(-5, 5, 100))

# F is one side of the equation, G is the other
F = x**2 + y**3
G = 1

ax9a.contour(x, y, (G - F), [0], colors='black')
fig9a.savefig("fig_functions_9a.pdf", bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_functions_9b

# %%
fig9b = plt.figure(figsize=(6,4))
ax9b = SubplotZero(fig9b, 111)
fig9b.add_subplot(ax9b)

ax9b.set_xlim(-5, 5)
ax9b.set_ylim(-5, 5)
ax9b.set_xlabel("x")
ax9b.set_ylabel("y", rotation=90)
x, y = np.meshgrid(np.linspace(-5, 5, 100), np.linspace(-5, 5, 100))

# F is one side of the equation, G is the other
F = (x-2)**2 + y**2
G = 1

ax9b.contour(x, y, (G - F), [0], colors='black')
fig9b.savefig("fig_functions_9b.pdf", bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_functions_9c

# %%
fig9c = plt.figure(figsize=(4,6))
ax9c = fig9c.add_axes([0,0,1,1])

ax9c.set_xlim(-1, 3)
ax9c.set_ylim(-5, 5)
ax9c.set_yticks([-4, -2, 2, 4])
ax9c.set_xticks([-1, 1, 2, 3])
ax9c.text(-0.2, -0.4, '0', color="black", size=10)

x = np.linspace(-1, 3, 100)
y = (x-1)**2-2

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax9c.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax9c.spines[direction].set_position('zero')

ax9c.arrow(-1, 0, 4.1, 0., fc='k', ec='k', lw = .5, head_width=0.3, head_length=0.2, overhang = 0.3, length_includes_head= False, clip_on = False)
ax9c.arrow(0, -5, 0, 10.1, fc='k', ec='k', lw = .5, head_width=0.2, head_length=0.3, overhang = 0.3, length_includes_head= False, clip_on = False)

ax9c.plot(x, y, color='black')
ax9c.plot([2], [1], color='black', marker='o')
ax9c.text(3.1, -1, 'x', color="black", size=15)
ax9c.text(0.2, 5.1, 'y', color="black", size=15)
fig9c.savefig("fig_functions_9c.pdf", bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_functions_9d

# %%
fig9d = plt.figure(figsize=(4,6))
ax9d = fig9d.add_axes([0,0,1,1])

ax9d.set_xlim(-1, 3)
ax9d.set_ylim(-5, 5)
ax9d.set_yticks([-4, -2, 2, 4])
ax9d.set_xticks([-1, 1, 2, 3])
ax9d.text(-0.2, -0.4, '0', color="black", size=10)
x = np.linspace(-1, 3, 100)
y = (x-1)**2-2

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax9d.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax9d.spines[direction].set_position('zero')

ax9d.arrow(-1, 0, 4.1, 0., fc='k', ec='k', lw = .5, head_width=0.3, head_length=0.2, overhang = 0.3, length_includes_head= False, clip_on = False)
ax9d.arrow(0, -5, 0, 10.1, fc='k', ec='k', lw = .5, head_width=0.2, head_length=0.3, overhang = 0.3, length_includes_head= False, clip_on = False)

ax9d.plot(x, y, color='black')
ax9d.scatter([2], [1], color='black', marker='o')
ax9d.plot([2], [-1], color='black', markerfacecolor='white', marker='o')
ax9d.text(3.1, -1, 'x', color="black", size=15)
ax9d.text(0.2, 5.1, 'y', color="black", size=15)
fig9d.savefig("fig_functions_9d.pdf", bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_functions_10bis

# %%
fig10bis = plt.figure(figsize=(4,6))
ax10bis = fig10bis.add_axes([0,0,1,1])

ax10bis.set_xlim(-3, 4)
ax10bis.set_ylim(-5, 5)
ax10bis.set_yticks([-4, -2, 2, 4])
ax10bis.set_xticks([-1, 1, 2, 3])
ax10bis.text(-0.2, -0.4, '0', color="black", size=10)

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax10bis.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax10bis.spines[direction].set_position('zero')

ax10bis.arrow(-3, 0, 7.1, 0., fc='k', ec='k', lw = .5, head_width=0.3, head_length=0.2, overhang = 0.3, length_includes_head= False, clip_on = False)
ax10bis.arrow(0, -5, 0, 10.1, fc='k', ec='k', lw = .5, head_width=0.2, head_length=0.3, overhang = 0.3, length_includes_head= False, clip_on = False)

x = np.linspace(-3, 1, 100)
ax10bis.plot(x, 4-x**2, color='black')
x = np.linspace(1, 4, 100)
ax10bis.plot(x, x-3, color='black')
ax10bis.scatter([1], [-2], color='black', marker='o')
ax10bis.plot([1], [3], color='black', markerfacecolor='white', marker='o')
ax10bis.text(3.1, -1, 'x', color="black", size=15)
ax10bis.text(0.2, 5.1, 'y', color="black", size=15)
fig10bis.savefig("fig_functions_10bis.pdf", bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_functions_11

# %%
fig11 = plt.figure(figsize=(4,6))
ax11 = fig11.add_axes([0,0,1,1])

ax11.set_xlim(-1, 3)
ax11.set_ylim(-5, 5)
ax11.set_yticks([-4, -2, 2, 4])
ax11.set_xticks([-1, 1, 2, 3])
ax11.text(-0.2, -0.4, '0', color="black", size=10)
x = np.linspace(-1, 2, 100)
y = (x-1)**2-2

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax11.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax11.spines[direction].set_position('zero')

ax11.arrow(-1, 0, 4.1, 0., fc='k', ec='k', lw = .5, head_width=0.3, head_length=0.2, overhang = 0.3, length_includes_head= False, clip_on = False)
ax11.arrow(0, -5, 0, 10.1, fc='k', ec='k', lw = .5, head_width=0.2, head_length=0.3, overhang = 0.3, length_includes_head= False, clip_on = False)

ax11.plot(x, y, color='black')
ax11.plot([2], [-1], color='black', markerfacecolor='white', marker='o')
ax11.text(3.1, -1, 'x', color="black", size=15)
ax11.text(0.2, 5.1, 'y', color="black", size=15)
fig11.savefig("fig_functions_11.pdf", bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_functions_12a

# %%
fig12a = plt.figure(figsize=(4,5))
ax12a = fig12a.add_axes([0,0,1,1])

ax12a.set_xlim(-3, 3)
ax12a.set_ylim(0, 9)
ax12a.set_yticks([1, 2, 3, 4, 5, 6, 7, 8, 9])
ax12a.set_xticks([-3, -2, -1, 0, 1, 2, 3])
x = np.linspace(-3, 3, 100)
y = x**2

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax12a.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax12a.spines[direction].set_position('zero')

ax12a.arrow(-3, 0, 6.1, 0., fc='k', ec='k', lw = .5, head_width=0.4, head_length=0.3, overhang = 0.3, length_includes_head= False, clip_on = False)
ax12a.arrow(0, 0, 0, 9.1, fc='k', ec='k', lw = .5, head_width=0.3, head_length=0.4, overhang = 0.2, length_includes_head= False, clip_on = False)

ax12a.plot(x, y, color='black')
ax12a.text(3.3, -0.5, 'x', color="black", size=15)
ax12a.text(0.3, 9.1, 'y', color="black", size=15)
fig12a.savefig("fig_functions_12a.pdf", bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_functions_12b

# %%
fig12b = plt.figure(figsize=(4,5))
ax12b = fig12b.add_axes([0,0,1,1])
ax12b.set_yticks([0.5, 1, 1.5, 2])

ax12b.set_xlim(0, 3)
ax12b.set_ylim(0, 2)
x = np.linspace(0, 3, 100)
y = x**(1/2)

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax12b.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax12b.spines[direction].set_position('zero')

ax12b.arrow(0, 0, 3.1, 0., fc='k', ec='k', lw = .5, head_width=0.075, head_length=0.15, overhang = 0.3, length_includes_head= False, clip_on = False)
ax12b.arrow(0, 0, 0, 2.1, fc='k', ec='k', lw = .5, head_width=0.15, head_length=0.075, overhang = 0.3, length_includes_head= False, clip_on = False)

ax12b.plot(x, y, color='black')
ax12b.text(3.3, -0.1, 'x', color="black", size=15)
ax12b.text(0.2, 2.1, 'y', color="black", size=15)
fig12b.savefig("fig_functions_12b.pdf", bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_function_13b

# %%
fig13b = plt.figure(figsize=(4,5))
ax13b = fig13b.add_axes([0,0,1,1])

ax13b.set_xlim(-4, 4.2)
ax13b.set_ylim(-4.2, 8)
ax13b.set_yticks([-4, -2, 2, 4, 6, 8])
ax13b.set_xticks([-4, -2, 2, 4])
ax13b.text(-0.3, -0.5, '0', color="black", size=10)

f_x = np.linspace(-4, 4, 100)
g_x = np.linspace(-3, 4, 100)

f = f_x**2 - 4*f_x
g = 2 - np.sqrt(g_x + 3)
gof = f_x-1

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax13b.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax13b.spines[direction].set_position('zero')

ax13b.arrow(-4, 0, 8.3, 0., fc='k', ec='k', lw = .5, head_width=0.4, head_length=0.5, overhang = 0.3, length_includes_head= False, clip_on = False)
ax13b.arrow(0, -4.2, 0, 12.3, fc='k', ec='k', lw = .5, head_width=0.3, head_length=0.5, overhang = 0.3, length_includes_head= False, clip_on = False)

ax13b.plot(f_x, f, color='black', linestyle='--', label="f(x)")
ax13b.plot(g_x, g, color='black', linestyle=':', label="g(x)")
ax13b.plot(f_x, gof, color='black', label="(f$\circ$g)(x)")

ax13b.text(4.3, -0.7, 'x', color="black", size=15)
ax13b.text(0.5, 8.1, 'y', color="black", size=15)
plt.legend(loc="upper right")
fig13b.savefig("fig_functions_13b.pdf", bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_functions_14

# %%
fig14 = plt.figure(figsize=(4,5))
ax14 = fig14.add_axes([0,0,1,1])

ax14.set_xlim(-4, 4.2)
ax14.set_ylim(-4.2, 8)
ax14.set_yticks([-4, -2, 2, 4, 6, 8])
ax14.set_xticks([-4, -2, 2, 4])
ax14.text(-0.3, -0.5, '0', color="black", size=10)

f_x = np.linspace(-4, 4, 100)
g_x = np.linspace(-3, 4, 100)

f = f_x**2 - 4*f_x
g = 2 - np.sqrt(g_x + 3)
gof = 2 - np.sqrt(f_x**2 - 4*f_x + 3)

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax14.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax14.spines[direction].set_position('zero')

ax14.arrow(-4, 0, 8.3, 0., fc='k', ec='k', lw = .5, head_width=0.4, head_length=0.5, overhang = 0.3, length_includes_head= False, clip_on = False)
ax14.arrow(0, -4.2, 0, 12.3, fc='k', ec='k', lw = .5, head_width=0.3, head_length=0.5, overhang = 0.3, length_includes_head= False, clip_on = False)

ax14.plot(f_x, f, color='black', linestyle='--', label="f(x)")
ax14.plot(g_x, g, color='black', linestyle=':', label="g(x)")
ax14.plot(f_x, gof, color='black', label="(g$\circ$f)(x)")

ax14.text(4.3, -0.7, 'x', color="black", size=15)
ax14.text(0.5, 8.1, 'y', color="black", size=15)
plt.legend(loc="upper right")
fig14.savefig("fig_functions_14.pdf", bbox_inches='tight')
plt.show()
# Out:
# <ipython-input-22-f4d013f08151>:15: RuntimeWarning: invalid value encountered in sqrt
#   gof = 2 - np.sqrt(f_x**2 - 4*f_x + 3)

# %% [markdown]
# ### fig_functions_16a

# %%
fig16a = plt.figure(figsize=(6,4))
ax16a = fig16a.add_axes([0,0,1,1])

ax16a.set_xlim(-3, 3)
ax16a.set_ylim(0, 2)
ax16a.set_yticks([0.5, 1, 1.5])
ax16a.set_xticks([-3, -2, -1, 1, 2, 3])
ax16a.text(-0.2, -0.2, '0', color="black", size=10)

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax16a.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax16a.spines[direction].set_position('zero')

ax16a.arrow(-3, 0, 6.1, 0., fc='k', ec='k', lw = .5, head_width=0.1, head_length=0.2, overhang = 0.3, length_includes_head= False, clip_on = False)
ax16a.arrow(0, 0, 0, 2, fc='k', ec='k', lw = .5, head_width=0.2, head_length=0.1, overhang = 0.3, length_includes_head= False, clip_on = False)

x = np.linspace(0, 3, 100)
ax16a.plot(x, np.sqrt(x), color='black')

ax16a.text(3.1, -0.2, 'x', color="black", size=15)
ax16a.text(-0.2, 2.1, 'y', color="black", size=15)
fig16a.savefig("fig_functions_16a.pdf", bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_functions_16b

# %%
fig16b = plt.figure(figsize=(6,4))
ax16b = fig16b.add_axes([0,0,1,1])

ax16b.set_xlim(-3, 3)
ax16b.set_ylim(-0.1, 8)
ax16b.set_yticks([2, 4, 6, 8])
ax16b.set_xticks([-3, -2, -1, 0, 1, 2, 3])

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax16b.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax16b.spines[direction].set_position('zero')

ax16b.arrow(-3, 0, 6.1, 0., fc='k', ec='k', lw = .5, head_width=0.3, head_length=0.2, overhang = 0.3, length_includes_head= False, clip_on = False)
ax16b.arrow(0, 0, 0, 8, fc='k', ec='k', lw = .5, head_width=0.2, head_length=0.4, overhang = 0.3, length_includes_head= False, clip_on = False)

x = np.linspace(-3, 3, 100)
ax16b.plot(x, x**2, color='black')

ax16b.text(3.1, -0.5, 'x', color="black", size=15)
ax16b.text(-0.2, 8.5, 'y', color="black", size=15)
fig16b.savefig("fig_functions_16b.pdf", bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_functions_16c

# %%
fig16c = plt.figure(figsize=(6,4))
ax16c = fig16c.add_axes([0,0,1,1])

ax16c.set_xlim(-3, 3)
ax16c.set_ylim(-30, 30)
ax16c.set_yticks([-30, -20, -10, 10, 20, 30])
ax16c.set_xticks([-3, -2, -1, 1, 2, 3])
ax16c.text(-0.2, -4, '0', color="black", size=10)

x = np.linspace(-3, 3, 100)

y = x**3

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax16c.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax16c.spines[direction].set_position('zero')

ax16c.arrow(-3, 0, 6.1, 0., fc='k', ec='k', lw = .5, head_width=3, head_length=0.2, overhang = 0.3, length_includes_head= False, clip_on = False)
ax16c.arrow(0, -30, 0, 61, fc='k', ec='k', lw = .5, head_width=0.2, head_length=3, overhang = 0.3, length_includes_head= False, clip_on = False)

ax16c.plot(x, y, color='black')

ax16c.text(3.1, -5, 'x', color="black", size=15)
ax16c.text(-0.4, 30.1, 'y', color="black", size=15)
fig16c.savefig("fig_functions_16c.pdf", bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_functions_17_Python

# %%
fig17 = plt.figure(figsize=(6,4))
ax17 = fig17.add_axes([0,0,1,1])

ax17.set_xlim(-3, 3)
ax17.set_ylim(-30, 30)
ax17.set_yticks([-30, -20, -10, 10, 20, 30])
ax17.set_xticks([-3, -2, -1, 1, 2, 3])
ax17.text(-0.2, -4, '0', color="black", size=10)

x1 = np.linspace(-3, -np.sqrt(2)-0.0001, 100)
x2 = np.linspace(-np.sqrt(2)+0.0001, np.sqrt(2)-0.0001, 100)
x3 = np.linspace(np.sqrt(2)+0.0001, 3, 100)

y1 = 5/(2-x1**2)
y2 = 5/(2-x2**2)
y3 = 5/(2-x3**2)

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax17.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax17.spines[direction].set_position('zero')

ax17.arrow(-3, 0, 6.1, 0., fc='k', ec='k', lw = .5, head_width=3, head_length=0.2, overhang = 0.3, length_includes_head= False, clip_on = False)
ax17.arrow(0, -30, 0, 61, fc='k', ec='k', lw = .5, head_width=0.2, head_length=3, overhang = 0.3, length_includes_head= False, clip_on = False)

ax17.plot(x1, y1, color='black')
ax17.plot(x2, y2, color='black')
ax17.plot(x3, y3, color='black')

ax17.text(3.1, -5, 'x', color="black", size=15)
ax17.text(-0.4, 30.1, 'y', color="black", size=15)
fig17.savefig("fig_functions_17_Python.pdf", bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_functions_18_Python

# %%
fig18 = plt.figure(figsize=(6,4))
ax18 = fig18.add_axes([0,0,1,1])

ax18.set_xlim(-3, 3)
ax18.set_ylim(-30, 30)
ax18.set_yticks([-30, -20, -10, 10, 20, 30])
ax18.set_xticks([-3, -2, -1, 1, 2, 3])
ax18.text(-0.2, -4, '0', color="black", size=10)

x1 = np.linspace(-3, -np.sqrt(2)-0.0001, 100)
x2 = np.linspace(-np.sqrt(2)+0.0001, np.sqrt(2)-0.0001, 100)
x3 = np.linspace(np.sqrt(2)+0.0001, 3, 100)

y1 = 5*x1/(2-x1**2)
y2 = 5*x2/(2-x2**2)
y3 = 5*x3/(2-x3**2)

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax18.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax18.spines[direction].set_position('zero')


ax18.arrow(-3, 0, 6.1, 0, fc='k', ec='k', lw = .5, head_width=3, head_length=0.2, overhang = 0.3, length_includes_head= False, clip_on = False)
ax18.arrow(0, -30, 0, 61, fc='k', ec='k', lw = .5, head_width=0.2, head_length=3, overhang = 0.3, length_includes_head= False, clip_on = False)

ax18.plot(x1, y1, color='black')
ax18.plot(x2, y2, color='black')
ax18.plot(x3, y3, color='black')

ax18.text(3.1, -5, 'x', color="black", size=15)
ax18.text(-0.1, 35.1, 'y', color="black", size=15)
fig18.savefig("fig_functions_18_Python.pdf", bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_functions_19

# %%
fig19 = plt.figure(figsize=(6,4))
ax19 = fig19.add_axes([0,0,1,1])

ax19.set_xlim(-4.2, 6.5)
ax19.set_ylim(-8.2, 6)
ax19.set_yticks([-8, -6, -4, -2, 2, 4, 6])
ax19.set_xticks([-4, -2, 2, 4, 6])
ax19.text(-0.3, -0.7, '0', color="black", size=10)

x1 = np.linspace(-4, 4.1, 100)
x3 = np.linspace(5, 6, 100)

y1 = (2*(x1**3) - 3*(x1**2) - 36*x1 + 1)/10
y3 = (2*(x3**3) - 3*(x3**2) - 36*x3 + 1)/10 - 5.51

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax19.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax19.spines[direction].set_position('zero')


ax19.arrow(-4.2, 0, 10.8, 0., fc='k', ec='k', lw = .5, head_width=0.5, head_length=0.4, overhang = 0.3, length_includes_head= False, clip_on = False)
ax19.arrow(0, -8.2, 0, 14.3, fc='k', ec='k', lw = .5, head_width=0.3, head_length=0.6, overhang = 0.3, length_includes_head= False, clip_on = False)

ax19.plot(x1, y1, color='black')
ax19.plot([4.1, 5], [-6, -6], color='black', marker="o")
ax19.plot(x3, y3, color='black')
ax19.scatter([-4, -2, 3, 6], [-3, 4.5, -8, 5.5], color='black')

ax19.text(6.5, -1, 'x', color="black", size=15)
ax19.text(-0.5, 6.1, 'y', color="black", size=15)
fig19.savefig("fig_functions_19.pdf", bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_functions_21

# %%
fig21 = plt.figure(figsize=(6,4))
ax21 = fig21.add_axes([0,0,1,1])

ax21.set_xlim(-4.2, 4.2)
ax21.set_ylim(-3.5, 3.5)
ax21.set_yticks([-3, -2, -1, 1, 2, 3])
ax21.set_xticks([-4, -3, -2, -1, 1, 2, 3, 4])
ax21.text(-0.3, -0.4, '0', color="black", size=10)

x = np.linspace(-4, 4, 100)
y = 3*np.cos(np.pi*x/4)

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax21.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax21.spines[direction].set_position('zero')

ax21.arrow(-4.2, 0, 8.5, 0., fc='k', ec='k', lw = .5, head_width=0.3, head_length=0.3, overhang = 0.3, length_includes_head= False, clip_on = False)
ax21.arrow(0, -3.5, 0, 7.1, fc='k', ec='k', lw = .5, head_width=0.3, head_length=0.3, overhang = 0.3, length_includes_head= False, clip_on = False)

ax21.plot(x, y, color='black')
ax21.scatter([-4, -2, 0, 2, 4], [-3, 0, 3, 0, -3], color='black')

ax21.text(4.5, -0.5, 'x', color="black", size=15)
ax21.text(0.2, 3.8, 'y', color="black", size=15)
fig21.savefig("fig_functions_21.pdf", bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_functions_22

# %%
fig22 = plt.figure(figsize=(6,4))
ax22 = fig22.add_axes([0,0,1,1])

ax22.set_xlim(-0.5, 5.5)
ax22.set_ylim(-0.5, 5.5)
ax22.set_yticks([1, 2, 3, 4, 5])
ax22.set_xticks([1, 2, 3, 4, 5])
ax22.text(-0.2, -0.3, '0', color="black", size=10)

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax22.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax22.spines[direction].set_position('zero')

ax22.arrow(-0.5, 0, 6.1, 0., fc='k', ec='k', lw = .5, head_width=0.2, head_length=0.2, overhang = 0.3, length_includes_head= False, clip_on = False)
ax22.arrow(0, -0.5, 0, 6.1, fc='k', ec='k', lw = .5, head_width=0.2, head_length=0.25, overhang = 0.3, length_includes_head= False, clip_on = False)

ax22.plot([0, 2, 4, 5], [1, 3, 3, 5], color='black', marker="o")

ax22.text(5.6, -0.5, 'x', color="black", size=15)
ax22.text(0.2, 5.8, 'y', color="black", size=15)
ax22.text(-0.8, 1, '(0,1)', color="black", size=15)
ax22.text(1.8, 3.2, '(2,3)', color="black", size=15)
ax22.text(4.2, 3, '(4,3)', color="black", size=15)
ax22.text(4.7, 5.2, '(5,5)', color="black", size=15)

fig22.savefig("fig_functions_22.pdf", bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_functions_23a

# %%
fig23a = plt.figure(figsize=(5,4))
ax23a = fig23a.add_axes([0,0,1,1])

ax23a.set_xlim(-0.5, 5.5)
ax23a.set_ylim(-0.5, 7.5)
ax23a.set_yticks([1, 2, 3, 4, 5, 6, 7])
ax23a.set_xticks([1, 2, 3, 4, 5])
ax23a.text(-0.2, -0.3, '0', color="black", size=10)

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax23a.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax23a.spines[direction].set_position('zero')

ax23a.arrow(-0.5, 0, 6.1, 0., fc='k', ec='k', lw = .5, head_width=0.2, head_length=0.2, overhang = 0.3, length_includes_head= False, clip_on = False)
ax23a.arrow(0, -0.5, 0, 8.1, fc='k', ec='k', lw = .5, head_width=0.2, head_length=0.25, overhang = 0.3, length_includes_head= False, clip_on = False)

ax23a.plot([0, 2, 4, 5], [1, 3, 3, 5], color='grey', marker="o")
ax23a.plot([0, 2, 4, 5], [3, 5, 5, 7], color='black', marker="o")

ax23a.text(5.6, -0.5, 'x', color="black", size=15)
ax23a.text(0.2, 7.8, 'y', color="black", size=15)

ax23a.text(5, 4, 'y=f(x)', color="grey", size=15)
ax23a.text(5, 6, 'y=g$_1$(x)=f(x)+2', color="black", size=15)

ax23a.text(-0.8, 3, '(0,3)', color="black", size=15)
ax23a.text(1.8, 5.2, '(2,5)', color="black", size=15)
ax23a.text(4.2, 5, '(4,5)', color="black", size=15)
ax23a.text(4.7, 7.2, '(5,7)', color="black", size=15)

fig23a.savefig("fig_functions_23a.pdf", bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_functions_23b

# %%
fig23b = plt.figure(figsize=(5,4))
ax23b = fig23b.add_axes([0,0,1,1])

ax23b.set_xlim(-0.5, 5.5)
ax23b.set_ylim(-2.5, 5.5)
ax23b.set_yticks([-1, -2, 1, 2, 3, 4, 5])
ax23b.set_xticks([1, 2, 3, 4, 5])
ax23b.text(-0.2, -0.3, '0', color="black", size=10)

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax23b.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax23b.spines[direction].set_position('zero')


ax23b.arrow(-0.5, 0, 6.1, 0., fc='k', ec='k', lw = .5, head_width=0.2, head_length=0.2, overhang = 0.3, length_includes_head= False, clip_on = False)
ax23b.arrow(0, -2.5, 0, 8.1, fc='k', ec='k', lw = .5, head_width=0.2, head_length=0.25, overhang = 0.3, length_includes_head= False, clip_on = False)

ax23b.plot([0, 2, 4, 5], [1, 3, 3, 5], color='grey', marker="o")
ax23b.plot([0, 2, 4, 5], [-1, 1, 1, 3], color='black', marker="o")

ax23b.text(5.6, -0.5, 'x', color="black", size=15)
ax23b.text(0.2, 5.8, 'y', color="black", size=15)

ax23b.text(5, 4, 'y=f(x)', color="grey", size=15)
ax23b.text(5, 2, 'y=j$_1$(x)=f(x)-2', color="black", size=15)

ax23b.text(-1, -1, '(0,-1)', color="black", size=15)
ax23b.text(1.8, 1.2, '(2,1)', color="black", size=15)
ax23b.text(4.2, 1, '(4,1)', color="black", size=15)
ax23b.text(4.7, 3.2, '(5,3)', color="black", size=15)

fig23b.savefig("fig_functions_23b.pdf", bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_functions_24a

# %%
fig24a = plt.figure(figsize=(5,4))
ax24a = fig24a.add_axes([0,0,1,1])

ax24a.set_xlim(-2.5, 5.5)
ax24a.set_ylim(-0.5, 5.5)
ax24a.set_yticks([1, 2, 3, 4, 5])
ax24a.set_xticks([-2, -1, 1, 2, 3, 4, 5])
ax24a.text(-0.2, -0.3, '0', color="black", size=10)

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax24a.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax24a.spines[direction].set_position('zero')

ax24a.arrow(-2.5, 0, 8.1, 0., fc='k', ec='k', lw = .5, head_width=0.2, head_length=0.2, overhang = 0.3, length_includes_head= False, clip_on = False)
ax24a.arrow(0, -0.5, 0, 6.1, fc='k', ec='k', lw = .5, head_width=0.2, head_length=0.25, overhang = 0.3, length_includes_head= False, clip_on = False)

ax24a.plot([0, 2, 4, 5], [1, 3, 3, 5], color='grey', marker="o")
ax24a.plot([-2, 0, 2, 3], [1, 3, 3, 5], color='black', marker="o")

ax24a.text(5.6, -0.5, 'x', color="black", size=15)
ax24a.text(0.2, 5.8, 'y', color="black", size=15)

ax24a.text(5, 4, 'y=f(x)', color="grey", size=15)
ax24a.text(0.2, 4.5, 'y=g$_2$(x)=f(x+2)', color="black", size=13)

ax24a.text(-3.5, 1, '(-2,1)', color="black", size=15)
ax24a.text(-1.1, 3.2, '(0,3)', color="black", size=15)
ax24a.text(1, 3.2, '(2,3)', color="black", size=15)
ax24a.text(2.7, 5.2, '(3,5)', color="black", size=15)

fig24a.savefig("fig_functions_24a.pdf", bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_functions_24b

# %%
fig24b = plt.figure(figsize=(5,4))
ax24b = fig24b.add_axes([0,0,1,1])

ax24b.set_xlim(-0.5, 7.5)
ax24b.set_ylim(-0.5, 5.5)
ax24b.set_yticks([1, 2, 3, 4, 5])
ax24b.set_xticks([1, 2, 3, 4, 5, 6, 7])
ax24b.text(-0.2, -0.3, '0', color="black", size=10)

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax24b.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax24b.spines[direction].set_position('zero')

ax24b.arrow(-0.5, 0, 8.1, 0., fc='k', ec='k', lw = .5, head_width=0.2, head_length=0.2, overhang = 0.3, length_includes_head= False, clip_on = False)
ax24b.arrow(0, -0.5, 0, 6.1, fc='k', ec='k', lw = .5, head_width=0.2, head_length=0.25, overhang = 0.3, length_includes_head= False, clip_on = False)

ax24b.plot([0, 2, 4, 5], [1, 3, 3, 5], color='grey', marker="o")
ax24b.plot([2, 4, 6, 7], [1, 3, 3, 5], color='black', marker="o")

ax24b.text(7.6, -0.5, 'x', color="black", size=15)
ax24b.text(0.2, 5.8, 'y', color="black", size=15)

ax24b.text(5, 4, 'y=f(x)', color="grey", size=15)
ax24b.text(7, 4, 'y=j$_2$(x)=f(x-2)', color="black", size=15)

ax24b.text(0.8, 1, '(2,1)', color="black", size=15)
ax24b.text(3, 3.2, '(4,3)', color="black", size=15)
ax24b.text(5, 3.2, '(6,3)', color="black", size=15)
ax24b.text(6.7, 5.2, '(7,5)', color="black", size=15)

fig24b.savefig("fig_functions_24b.pdf", bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_functions_25a

# %%
fig25a = plt.figure(figsize=(5,4))
ax25a = fig25a.add_axes([0,0,1,1])

ax25a.set_xlim(-0.5, 7.5)
ax25a.set_ylim(-5.5, 5.5)
ax25a.set_yticks([-4, -2, 2, 4])
ax25a.set_xticks([1, 2, 3, 4, 5, 6, 7])
ax25a.text(-0.2, -0.4, '0', color="black", size=10)

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax25a.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax25a.spines[direction].set_position('zero')

ax25a.arrow(-0.5, 0, 8.1, 0., fc='k', ec='k', lw = .5, head_width=0.3, head_length=0.2, overhang = 0.3, length_includes_head= False, clip_on = False)
ax25a.arrow(0, -5.5, 0, 11.1, fc='k', ec='k', lw = .5, head_width=0.2, head_length=0.3, overhang = 0.3, length_includes_head= False, clip_on = False)

ax25a.plot([0, 2, 4, 5], [1, 3, 3, 5], color='grey', marker="o")
ax25a.plot([0, 2, 4, 5], [-1, -3, -3, -5], color='black', marker="o")

ax25a.text(7.6, -0.5, 'x', color="black", size=15)
ax25a.text(0.2, 5.8, 'y', color="black", size=15)

ax25a.text(5, 4, 'y=f(x)', color="grey", size=15)
ax25a.text(5, -4, 'y=g$_3$(x)=-f(x)', color="black", size=15)

ax25a.text(-1.4, -1, '(0,-1)', color="black", size=15)
ax25a.text(1.5, -3.7, '(2,-3)', color="black", size=15)
ax25a.text(4.2, -3, '(4,-3)', color="black", size=15)
ax25a.text(4.7, -5.7, '(5,-5)', color="black", size=15)

fig25a.savefig("fig_functions_25a.pdf", bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_functions_25b

# %%
fig25b = plt.figure(figsize=(5,4))
ax25b = fig25b.add_axes([0,0,1,1])

ax25b.set_xlim(-7.5, 7.5)
ax25b.set_ylim(-0.5, 5.5)
ax25b.set_yticks([1, 2, 3, 4, 5])
ax25b.set_xticks([-6, -4, -2, 2, 4, 6])
ax25b.text(-0.4, -0.3, '0', color="black", size=10)

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax25b.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax25b.spines[direction].set_position('zero')

ax25b.arrow(-7.5, 0, 15.1, 0., fc='k', ec='k', lw = .5, head_width=0.2, head_length=0.4, overhang = 0.3, length_includes_head= False, clip_on = False)
ax25b.arrow(0, -0.5, 0, 6.1, fc='k', ec='k', lw = .5, head_width=0.4, head_length=0.25, overhang = 0.3, length_includes_head= False, clip_on = False)

ax25b.plot([0, 2, 4, 5], [1, 3, 3, 5], color='grey', marker="o")
ax25b.plot([0, -2, -4, -5], [1, 3, 3, 5], color='black', marker="o")

ax25b.text(7.6, -0.5, 'x', color="black", size=15)
ax25b.text(0.2, 5.8, 'y', color="black", size=15)

ax25b.text(5, 4, 'y=f(x)', color="grey", size=15)
ax25b.text(-10, 4, 'y=j$_3$(x)=f(-x)', color="black", size=15)

ax25b.text(0.7, 1, '(0,1)', color="black", size=15)
ax25b.text(-3, 3.3, '(-2,3)', color="black", size=15)
ax25b.text(-6.5, 2.7, '(-4,3)', color="black", size=15)
ax25b.text(-6, 5.2, '(-5,5)', color="black", size=15)

fig25b.savefig("fig_functions_25b.pdf", bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_functions_26a

# %%
fig26a = plt.figure(figsize=(5,4))
ax26a = fig26a.add_axes([0,0,1,1])

ax26a.set_xlim(-0.5, 7.5)
ax26a.set_ylim(-0.5, 11)
ax26a.set_yticks([2, 4, 6, 8, 10])
ax26a.set_xticks([1, 2, 3, 4, 5, 6, 7])
ax26a.text(-0.2, -0.4, '0', color="black", size=10)

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax26a.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax26a.spines[direction].set_position('zero')

ax26a.arrow(-0.5, 0, 8.1, 0., fc='k', ec='k', lw = .5, head_width=0.4, head_length=0.2, overhang = 0.3, length_includes_head= False, clip_on = False)
ax26a.arrow(0, -0.5, 0, 11.6, fc='k', ec='k', lw = .5, head_width=0.2, head_length=0.4, overhang = 0.3, length_includes_head= False, clip_on = False)

ax26a.plot([0, 2, 4, 5], [1, 3, 3, 5], color='grey', marker="o")
ax26a.plot([0, 2, 4, 5], [2, 6, 6, 10], color='black', marker="o")

ax26a.text(7.8, -0.5, 'x', color="black", size=15)
ax26a.text(0.2, 11.6, 'y', color="black", size=15)

ax26a.text(5, 4, 'y=f(x)', color="grey", size=15)
ax26a.text(5, 8, 'y=g$_4$(x)=2f(x)', color="black", size=15)

ax26a.text(-1, 2, '(0,2)', color="black", size=15)
ax26a.text(1, 6.3, '(2,6)', color="black", size=15)
ax26a.text(4.2, 6, '(4,6)', color="black", size=15)
ax26a.text(4, 10.3, '(5,10)', color="black", size=15)

fig26a.savefig("fig_functions_26a.pdf", bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_functions_26b

# %%
fig26b = plt.figure(figsize=(5,4))
ax26b = fig26b.add_axes([0,0,1,1])

ax26b.set_xlim(-0.5, 7.5)
ax26b.set_ylim(-0.5, 5.5)
ax26b.set_yticks([1, 2, 3, 4, 5])
ax26b.set_xticks([1, 2, 3, 4, 5, 6, 7])
ax26b.text(-0.2, -0.2, '0', color="black", size=10)

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax26b.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax26b.spines[direction].set_position('zero')

ax26b.arrow(-0.5, 0, 8.1, 0., fc='k', ec='k', lw = .5, head_width=0.2, head_length=0.2, overhang = 0.3, length_includes_head= False, clip_on = False)
ax26b.arrow(0, -0.5, 0, 6.1, fc='k', ec='k', lw = .5, head_width=0.2, head_length=0.25, overhang = 0.3, length_includes_head= False, clip_on = False)

ax26b.plot([0, 2, 4, 5], [1, 3, 3, 5], color='grey', marker="o")
ax26b.plot([0, 2, 4, 5], [0.5, 1.5, 1.5, 2.5], color='black', marker="o")

ax26b.text(7.6, -0.5, 'x', color="black", size=15)
ax26b.text(0.2, 5.8, 'y', color="black", size=15)

ax26b.text(5, 4, 'y=f(x)', color="grey", size=15)
ax26b.text(5, 2, 'y=j$_4$(x)=f(x)/2', color="black", size=15)

ax26b.text(-1.7, 0.5, '(0,0.5)', color="black", size=15)
ax26b.text(1.5, 1.8, '(2,1.5)', color="black", size=15)
ax26b.text(4.2, 1.5, '(4,1.5)', color="black", size=15)
ax26b.text(4.5, 2.7, '(5,2.5)', color="black", size=15)

fig26b.savefig("fig_functions_26b.pdf", bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_functions_27a

# %%
fig27a = plt.figure(figsize=(5,4))
ax27a = fig27a.add_axes([0,0,1,1])

ax27a.set_xlim(-0.5, 7.5)
ax27a.set_ylim(-0.5, 5.5)
ax27a.set_yticks([1, 2, 3, 4, 5])
ax27a.set_xticks([1, 2, 3, 4, 5, 6, 7])
ax27a.text(-0.2, -0.2, '0', color="black", size=10)

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax27a.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax27a.spines[direction].set_position('zero')

ax27a.arrow(-0.5, 0, 8.1, 0., fc='k', ec='k', lw = .5, head_width=0.2, head_length=0.2, overhang = 0.3, length_includes_head= False, clip_on = False)
ax27a.arrow(0, -0.5, 0, 6.1, fc='k', ec='k', lw = .5, head_width=0.2, head_length=0.25, overhang = 0.3, length_includes_head= False, clip_on = False)

ax27a.plot([0, 2, 4, 5], [1, 3, 3, 5], color='grey', marker="o")
ax27a.plot([0, 1, 2, 2.5], [1, 3, 3, 5], color='black', marker="o")

ax27a.text(7.6, -0.5, 'x', color="black", size=15)
ax27a.text(0.2, 5.8, 'y', color="black", size=15)

ax27a.text(5, 4, 'y=f(x)', color="grey", size=15)
ax27a.text(0.02, 4.5, 'y=g$_5$(x)=f(2x)', color="black", size=13)

ax27a.text(-1.2, 1, '(0,1)', color="black", size=15)
ax27a.text(0.5, 3.2, '(1,3)', color="black", size=15)
ax27a.text(2.2, 3.2, '(2,3)', color="black", size=15)
ax27a.text(2, 5.2, '(2.5,5)', color="black", size=15)

fig27a.savefig("fig_functions_27a.pdf", bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_functions_27b

# %%
fig27b = plt.figure(figsize=(5,4))
ax27b = fig27b.add_axes([0,0,1,1])

ax27b.set_xlim(-0.5, 12)
ax27b.set_ylim(-0.5, 5.5)
ax27b.set_yticks([1, 2, 3, 4, 5])
ax27b.set_xticks([2, 4, 6, 8, 10, 12])
ax27b.text(-0.3, -0.3, '0', color="black", size=10)

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax27b.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax27b.spines[direction].set_position('zero')

ax27b.arrow(-0.5, 0, 12.6, 0., fc='k', ec='k', lw = .5, head_width=0.2, head_length=0.4, overhang = 0.3, length_includes_head= False, clip_on = False)
ax27b.arrow(0, -0.5, 0, 6.1, fc='k', ec='k', lw = .5, head_width=0.4, head_length=0.25, overhang = 0.3, length_includes_head= False, clip_on = False)

ax27b.plot([0, 2, 4, 5], [1, 3, 3, 5], color='grey', marker="o")
ax27b.plot([0, 4, 8, 10], [1, 3, 3, 5], color='black', marker="o")

ax27b.text(12.6, -0.5, 'x', color="black", size=15)
ax27b.text(0.2, 5.8, 'y', color="black", size=15)

ax27b.text(5, 4, 'y=f(x)', color="grey", size=15)
ax27b.text(10, 4, 'y=j$_5$(x)=f(x/2)', color="black", size=15)

ax27b.text(-2, 1, '(0,1)', color="black", size=15)
ax27b.text(4.2, 3.2, '(4,3)', color="black", size=15)
ax27b.text(8.1, 2.8, '(8,3)', color="black", size=15)
ax27b.text(9.2, 5.2, '(10,5)', color="black", size=15)

fig27b.savefig("fig_functions_27b.pdf", bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_functions_28

# %%
fig28 = plt.figure(figsize=(5,4))
ax28 = fig28.add_axes([0,0,1,1])

ax28.set_xlim(-4.2, 4.2)
ax28.set_ylim(-3.5, 3.5)
ax28.set_yticks([-3, -2, -1, 1, 2, 3])
ax28.set_xticks([-4, -3, -2, -1, 1, 2, 3, 4])
ax28.text(-0.2, -0.3, '0', color="black", size=10)

x = np.linspace(-4, 4, 100)
y = 3*np.cos(np.pi*x/4)

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax28.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax28.spines[direction].set_position('zero')

ax28.arrow(-4.2, 0, 8.5, 0., fc='k', ec='k', lw = .5, head_width=0.2, head_length=0.2, overhang = 0.3, length_includes_head= False, clip_on = False)
ax28.arrow(0, -3.5, 0, 7.1, fc='k', ec='k', lw = .5, head_width=0.2, head_length=0.25, overhang = 0.3, length_includes_head= False, clip_on = False)

ax28.plot(x, y, color='black')
ax28.scatter([-4, -2, 0, 2, 4], [-3, 0, 3, 0, -3], color='black')

ax28.text(4.6, -0.5, 'x', color="black", size=15)
ax28.text(0.2, 3.8, 'y', color="black", size=15)

ax28.text(-4.5, -3.5, '(-4,-3)', color="black", size=15)
ax28.text(-3.5, 0.2, '(-2,0)', color="black", size=15)
ax28.text(0.2, 3.3, '(0,3)', color="black", size=15)
ax28.text(2.2, 0.2, '(2,0)', color="black", size=15)
ax28.text(3.5, -3.5, '(4,-3)', color="black", size=15)

fig28.savefig("fig_functions_28.pdf", bbox_inches='tight')
fig28.savefig("fig_functions_29a.pdf", bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_functions_29b

# %%
fig29b = plt.figure(figsize=(5,4))
ax29b = fig29b.add_axes([0,0,1,1])

ax29b.set_xlim(-2, 3)
ax29b.set_ylim(-3, 7)
ax29b.set_yticks([-2, 2, 4, 6])
ax29b.set_xticks([-2, -1, 1, 2, 3])
ax29b.text(-0.15, -0.4, '0', color="black", size=10)

x = np.linspace(-1.5, 2.5, 100)
y = 2 - 4.5*np.cos(np.pi*(1 - 2*x)/4)

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax29b.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax29b.spines[direction].set_position('zero')

ax29b.arrow(-2, 0, 5.1, 0., fc='k', ec='k', lw = .5, head_width=0.2, head_length=0.15, overhang = 0.3, length_includes_head= False, clip_on = False)
ax29b.arrow(0, -3, 0, 10.1, fc='k', ec='k', lw = .5, head_width=0.15, head_length=0.25, overhang = 0.3, length_includes_head= False, clip_on = False)

ax29b.plot(x, y, color='black')
ax29b.scatter([-1.5, -0.5, 0.5, 1.5, 2.5], [6.5, 2, -2.5, 2, 6.5], color='black')

ax29b.text(3.2, -0.5, 'x', color="black", size=15)
ax29b.text(0.2, 6.8, 'y', color="black", size=15)

ax29b.text(-3, 6.5, '(-3/2,13/2)', color="black", size=15)
ax29b.text(-1.7, 2, '(-1/2,2)', color="black", size=15)
ax29b.text(0.7, -2.5, '(1/2,-5/2)', color="black", size=15)
ax29b.text(1.6, 2, '(3/2,2)', color="black", size=15)
ax29b.text(2.6, 6.5, '(5/2,13/2)', color="black", size=15)

fig29b.savefig("fig_functions_29b.pdf", bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_functions_30

# %%
fig30 = plt.figure(figsize=(5,4))
ax30 = fig30.add_axes([0,0,1,1])

ax30.set_xlim(-4, 4)
ax30.set_ylim(-2, 2)
ax30.set_yticks([-2, -1, 1, 2])
ax30.set_xticks([-4, -3, -2, -1, 1, 2, 3, 4])
ax30.text(-0.2, -0.2, '0', color="black", size=10)

x1 = np.linspace(-4, -1, 100)
x2 = np.linspace(-1, 1, 100)
x3 = np.linspace(1, 4, 100)

y1 = (x1+1)**2
y2 = -x2
y3 = np.sqrt(x3-1)

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax30.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax30.spines[direction].set_position('zero')
        
ax30.arrow(-4, 0, 8.1, 0., fc='k', ec='k', lw = .5, head_width=0.15, head_length=0.2, overhang = 0.3, length_includes_head= False, clip_on = False)
ax30.arrow(0, -2, 0, 4.1, fc='k', ec='k', lw = .5, head_width=0.2, head_length=0.15, overhang = 0.3, length_includes_head= False, clip_on = False)

ax30.plot(x1, y1, color='black')
ax30.plot(x2, y2, color='black')
ax30.plot(x3, y3, color='black')

ax30.scatter([-1, 1], [1, 0], color='black', marker='o')
ax30.scatter([-1, 1], [0, -1], edgecolors='black', facecolors='white', marker='o', zorder=10)

ax30.text(4.2, -0.2, 'x', color="black", size=15)
ax30.text(0.2, 2.2, 'y', color="black", size=15)

fig30.savefig("fig_functions_30.pdf", bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Absolutewaardefuncties

# %% [markdown]
# ### fig_functions_31

# %%
fig31 = plt.figure(figsize=(5,4))
ax31 = fig31.add_axes([0,0,1,1])

ax31.set_xlim(-2, 2)
ax31.set_ylim(-0.5, 3)
ax31.set_yticks([1, 2, 3])
ax31.set_xticks([-2, -1, 1, 2])
ax31.text(-0.1, -0.2, '0', color="black", size=10)

x = np.linspace(-2, 2, 100)
y = np.abs(x)

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax31.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax31.spines[direction].set_position('zero')

ax31.arrow(-2, 0, 4.1, 0., fc='k', ec='k', lw = .5, head_width=0.15, head_length=0.15, overhang = 0.3, length_includes_head= False, clip_on = False)
ax31.arrow(0, -0.5, 0, 3.6, fc='k', ec='k', lw = .5, head_width=0.15, head_length=0.15, overhang = 0.3, length_includes_head= False, clip_on = False)

ax31.plot(x, y, color='black')

ax31.text(2.2, -0.2, 'x', color="black", size=15)
ax31.text(0.2, 3.2, 'y', color="black", size=15)

fig31.savefig("fig_functions_31.pdf", bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_functions_32

# %%
fig32 = plt.figure(figsize=(5,4))
ax32 = fig32.add_axes([0,0,1,1])

ax32.set_xlim(0, 6)
ax32.set_ylim(-0.5, 3)
ax32.set_yticks([1, 2, 3])
ax32.set_xticks([1, 2, 3, 4, 5, 6])
ax32.text(-0.2, 0, '0', color="black", size=10)

x = np.linspace(0, 6, 1000)
y = np.abs(x-3)

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax32.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax32.spines[direction].set_position('zero')

ax32.arrow(0, 0, 6.1, 0., fc='k', ec='k', lw = .5, head_width=0.15, head_length=0.2, overhang = 0.3, length_includes_head= False, clip_on = False)
ax32.arrow(0, -0.5, 0, 3.6, fc='k', ec='k', lw = .5, head_width=0.2, head_length=0.15, overhang = 0.3, length_includes_head= False, clip_on = False)

ax32.plot(x, y, color='black')

ax32.text(6.2, -0.2, 'x', color="black", size=15)
ax32.text(0.2, 3.2, 'y', color="black", size=15)

fig32.savefig("fig_functions_32.pdf", bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_functions_33

# %%
fig33 = plt.figure(figsize=(5,4))
ax33 = fig33.add_axes([0,0,1,1])

ax33.set_xlim(-4, 4)
ax33.set_ylim(-2, 2)
ax33.set_yticks([-2, -1, 1, 2])
ax33.set_xticks([-4, -3, -2, -1, 1, 2, 3, 4])
ax33.text(-0.2, -0.2, '0', color="black", size=10)

x = np.linspace(-4, 4, 1000)
y = np.abs(x)/x

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax33.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax33.spines[direction].set_position('zero')

ax33.arrow(-4, 0, 8.1, 0., fc='k', ec='k', lw = .5, head_width=0.2, head_length=0.25, overhang = 0.3, length_includes_head= False, clip_on = False)
ax33.arrow(0, -2, 0, 4.1, fc='k', ec='k', lw = .5, head_width=0.25, head_length=0.2, overhang = 0.3, length_includes_head= False, clip_on = False)

ax33.plot(x, y, color='black')
ax33.scatter([0, 0], [-1, 1], color='black', facecolors='white', marker='o', zorder=10)

ax33.text(4.2, -0.2, 'x', color="black", size=15)
ax33.text(0.2, 2.2, 'y', color="black", size=15)

fig33.savefig("fig_functions_33.pdf", bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_functions_34

# %%
fig34 = plt.figure(figsize=(5,4))
ax34 = fig34.add_axes([0,0,1,1])

ax34.set_xlim(-2, 2)
ax34.set_ylim(-0.5, 2)
ax34.set_xticks([])
ax34.set_yticks([])

x = np.linspace(-4, 4, 1000)
y = np.abs(x)

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax34.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax34.spines[direction].set_position('zero')

ax34.arrow(-2, 0, 4.1, 0., fc='k', ec='k', lw = .5, head_width=0.1, head_length=0.1, overhang = 0.3, length_includes_head= False, clip_on = False)
ax34.arrow(0, -0.5, 0, 2.6, fc='k', ec='k', lw = .5, head_width=0.1, head_length=0.1, overhang = 0.3, length_includes_head= False, clip_on = False)

ax34.plot(x, y, color='black')
ax34.plot([-1, 1], [0, 0], color='black', markerfacecolor='white', marker='o', lw=4, zorder=10)
ax34.plot([-2, 2], [1, 1], color='black')
ax34.scatter([-1, 1], [1, 1], color='black')

ax34.text(2.2, -0.2, 'x', color="black", size=15)
ax34.text(0.1, 2.2, 'y', color="black", size=15)

ax34.text(-1.2, -0.2, '-c', color="black", size=15)
ax34.text(1, -0.2, 'c', color="black", size=15)
ax34.text(-1.6, 0.8, '(-c,c)', color="black", size=15)
ax34.text(1, 0.8, '(c,c)', color="black", size=15)

fig34.savefig("fig_functions_34.pdf", bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_functions_35

# %%
fig35 = plt.figure(figsize=(5,4))
ax35 = fig35.add_axes([0,0,1,1])

ax35.set_xlim(-7.1, 9.5)
ax35.set_ylim(-0.5, 7)
ax35.set_yticks([1, 2, 3, 4, 5, 6, 7])
ax35.set_xticks([-6, -4, -2, 2, 4, 6, 8])
ax35.text(-0.5, -0.3, '0', color="black", size=10)

x = np.linspace(-7, 9, 1000)
y = np.abs(x-1)

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax35.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax35.spines[direction].set_position('zero')
        
ax35.arrow(-7, 0, 16.1, 0., fc='k', ec='k', lw = .5, head_width=0.2, head_length=0.5, overhang = 0.3, length_includes_head= False, clip_on = False)
ax35.arrow(0, -0.5, 0, 7.6, fc='k', ec='k', lw = .5, head_width=0.5, head_length=0.2, overhang = 0.3, length_includes_head= False, clip_on = False)

ax35.plot(x, y, color='black')
ax35.plot([-7, 9], [3, 3], color='black')
ax35.plot([-2, -7.1], [0, 0], color='black', lw=4)
ax35.plot([4, 9.5], [0, 0], color='black', lw=4)

ax35.scatter([-2, 4, -2, 4], [3, 3, 0, 0], color='black')

ax35.text(9.2, -0.5, 'x', color="black", size=15)
ax35.text(0.5, 7.2, 'y', color="black", size=15)

ax35.text(-4.5, 2.5, '(-2,3)', color="black", size=15)
ax35.text(4, 2.5, '(2,4)', color="black", size=15)

fig35.savefig("fig_functions_35.pdf", bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_functions_36

# %%
fig36 = plt.figure(figsize=(5,4))
ax36 = fig36.add_axes([0,0,1,1])

ax36.set_xlim(-7, 9)
ax36.set_ylim(-0.5, 7)
ax36.set_yticks([1, 2, 3, 4, 5, 6, 7])
ax36.set_xticks([-6, -4, -2, 2, 4, 6, 8])
ax36.text(-0.5, -0.3, '0', color="black", size=10)

x = np.linspace(-7, 9, 1000)
y = np.abs(x-1)

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax36.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax36.spines[direction].set_position('zero')

ax36.arrow(-7, 0, 16.1, 0., fc='k', ec='k', lw = .5, head_width=0.2, head_length=0.5, overhang = 0.3, length_includes_head= False, clip_on = False)
ax36.arrow(0, -0.5, 0, 7.6, fc='k', ec='k', lw = .5, head_width=0.5, head_length=0.2, overhang = 0.3, length_includes_head= False, clip_on = False)

ax36.plot(x, y, color='black')
ax36.plot([-4, -1], [0, 0], color='black', lw=4)
ax36.plot([3, 6], [0, 0], color='black', lw=4)
ax36.plot([-7, 9], [2, 2], color='black')
ax36.plot([-7, 9], [5, 5], color='black')
ax36.scatter([-1, 3], [0, 0], color='black', facecolors='white', marker='o', zorder=10)

ax36.scatter([-1, 3, -4, 6, -4, 6], [2, 2, 5, 0, 0, 5], color='black')

ax36.text(9.2, -0.5, 'x', color="black", size=15)
ax36.text(0.5, 7.2, 'y', color="black", size=15)

ax36.text(-4.2, 6, 'y=|x-1|', color="black", size=15)
ax36.text(1, 5.2, 'y=5', color="black", size=15)
ax36.text(1, 2.2, 'y=2', color="black", size=15)

fig36.savefig("fig_functions_36.pdf", bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Inverse functies

# %% [markdown]
# ### fig_functions_38

# %%
fig38 = plt.figure(figsize=(5,4))
ax38 = fig38.add_axes([0,0,1,1])

ax38.set_xlim(-3, 3)
ax38.set_ylim(-3, 3)
ax38.set_yticks([-3, -2, -1, 1, 2, 3])
ax38.set_xticks([-3, -2, -1, 1, 2, 3])
ax38.text(-0.2, -0.3, '0', color="black", size=10)

x = np.linspace(-7, 9, 1000)
y1 = 3*x + 4
y2 = (x-4)/3

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax38.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax38.spines[direction].set_position('zero')

ax38.arrow(-3, 0, 6.1, 0., fc='k', ec='k', lw = .5, head_width=0.2, head_length=0.2, overhang = 0.3, length_includes_head= False, clip_on = False)
ax38.arrow(0, -3, 0, 6.1, fc='k', ec='k', lw = .5, head_width=0.2, head_length=0.2, overhang = 0.3, length_includes_head= False, clip_on = False)

ax38.plot(x, x, color='black', ls=':')
ax38.plot(x, y1, color='grey')
ax38.plot(x, y2, color='black')

ax38.text(3.2, -0.5, 'x', color="black", size=15)
ax38.text(0.2, 3.2, 'y', color="black", size=15)

ax38.text(0.8, 1.5, 'y=x', color="black", size=15)
ax38.text(-2, 1, 'y=f(x)', color="grey", size=15)
ax38.text(1, -1.5, 'y=g(x)=f$^{-1}$(x)', color="black", size=15)

fig38.savefig("fig_functions_38.pdf", bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_functions_39a

# %%
fig39a = plt.figure(figsize=(5,4))
ax39a = fig39a.add_axes([0,0,1,1])

ax39a.set_xlim(-3, 3)
ax39a.set_ylim(0, 9)
ax39a.set_yticks([1, 2, 3, 4, 5, 6, 7, 8, 9])
ax39a.set_xticks([-3, -2, -1, 1, 2, 3])
ax39a.text(-0.05, -0.4, '0', color="black", size=10)

x = np.linspace(-7, 9, 1000)
y = x**2

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax39a.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax39a.spines[direction].set_position('zero')

ax39a.arrow(-3, 0, 6.1, 0., fc='k', ec='k', lw = .5, head_width=0.3, head_length=0.2, overhang = 0.3, length_includes_head= False, clip_on = False)
ax39a.arrow(0, 0, 0, 9.1, fc='k', ec='k', lw = .5, head_width=0.2, head_length=0.3, overhang = 0.3, length_includes_head= False, clip_on = False)

ax39a.plot(x, y, color='black')
ax39a.plot([-3, 3], [4, 4], color='black', ls=':')
ax39a.scatter([-2, 2], [4, 4], color='black')

ax39a.text(3.2, -0.5, 'x', color="black", size=15)
ax39a.text(0.2, 9.2, 'y', color="black", size=15)

ax39a.text(-3, 3.2, '(-2,4)', color="black", size=15)
ax39a.text(2, 3.2, '(2,4)', color="black", size=15)

fig39a.savefig("fig_functions_39a.pdf", bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_functions_39b

# %%
fig39b = plt.figure(figsize=(5,4))
ax39b = fig39b.add_axes([0,0,1,1])

ax39b.set_xlim(0, 9)
ax39b.set_ylim(-3, 3)
ax39b.set_yticks([-3, -2, -1, 1, 2, 3])
ax39b.set_xticks([1, 2, 3, 4, 5, 6, 7, 8, 9])
ax39b.text(-0.3, -0.05, '0', color="black", size=10)

x = np.linspace(-7, 9, 1000)
y = x**2

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax39b.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax39b.spines[direction].set_position('zero')

ax39b.arrow(0, 0, 9.1, 0., fc='k', ec='k', lw = .5, head_width=0.3, head_length=0.3, overhang = 0.3, length_includes_head= False, clip_on = False)
ax39b.arrow(0, -3, 0, 6.1, fc='k', ec='k', lw = .5, head_width=0.3, head_length=0.3, overhang = 0.3, length_includes_head= False, clip_on = False)

ax39b.plot(y, x, color='black')
ax39b.plot([4, 4], [-3, 3], color='black', ls=':')
ax39b.scatter([4, 4], [-2, 2], color='black')

ax39b.text(9.2, -0.5, 'x', color="black", size=15)
ax39b.text(0.2, 3.2, 'y', color="black", size=15)

ax39b.text(4, -1.8, '(4,-2)', color="black", size=15)
ax39b.text(4, 1.7, '(4,2)', color="black", size=15)

fig39b.savefig("fig_functions_39b.pdf", bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_functions_40

# %%
fig40 = plt.figure(figsize=(5,4))
ax40 = fig40.add_axes([0,0,1,1])
ax40.set_xlim(0, 7)
ax40.set_ylim(0, 7)
ax40.set_yticks([1, 2, 3, 4, 5, 6, 7])
ax40.set_xticks([0, 1, 2, 3, 4, 5, 6, 7])

x = np.linspace(0, 7, 1000)
y1 = x**2
y2 = np.sqrt(x)

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax40.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax40.spines[direction].set_position('zero')

ax40.arrow(0, 0, 7.1, 0., fc='k', ec='k', lw = .5, head_width=0.2, head_length=0.2, overhang = 0.3, length_includes_head= False, clip_on = False)
ax40.arrow(0, 0, 0, 7.1, fc='k', ec='k', lw = .5, head_width=0.2, head_length=0.2, overhang = 0.3, length_includes_head= False, clip_on = False)

ax40.plot(x, x, color='black', ls=':')
ax40.plot(x, y1, color='grey')
ax40.plot(x, y2, color='black')

ax40.text(7.2, -0.5, 'x', color="black", size=15)
ax40.text(0.2, 7.2, 'y', color="black", size=15)

ax40.text(4.4, 5, 'y=x', color="black", size=15)
ax40.text(0.5, 5, 'y=f(x)=x$^2$', color="grey", size=15)
ax40.text(4, 1.5, 'y=f$^{-1}$(x)=$\sqrt{x}$', color="black", size=15)

fig40.savefig("fig_functions_40.pdf", bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_functions_41

# %%
fig41 = plt.figure(figsize=(5,4))
ax41 = fig41.add_axes([0,0,1,1])

ax41.set_xlim(-1, 7)
ax41.set_ylim(-1, 7)
ax41.set_yticks([-1, 1, 2, 3, 4, 5, 6, 7])
ax41.set_xticks([-1, 1, 2, 3, 4, 5, 6, 7])
ax41.text(-0.2, -0.3, '0', color="black", size=10)

x = np.linspace(-1, 7, 1000)
x1 = np.linspace(-1, 1, 1000)
x2 = np.linspace(3, 7, 1000)
y1 = x1**2-2*x1+4
y2 = 1 - np.sqrt(x2 - 3)

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax41.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax41.spines[direction].set_position('zero')
        
ax41.arrow(-1, 0, 8.1, 0., fc='k', ec='k', lw = .5, head_width=0.2, head_length=0.2, overhang = 0.3, length_includes_head= False, clip_on = False)
ax41.arrow(0, -1, 0, 8.1, fc='k', ec='k', lw = .5, head_width=0.2, head_length=0.2, overhang = 0.3, length_includes_head= False, clip_on = False)

ax41.plot(x, x, color='black', ls=':')
ax41.scatter([1,3],[3,1], color='black')
ax41.plot(x1, y1, color='grey')
ax41.plot(x2, y2, color='black')

ax41.text(7.2, -0.5, 'x', color="black", size=15)
ax41.text(0.2, 7.2, 'y', color="black", size=15)

ax41.text(4.4, 5, 'y=x', color="black", size=15)
ax41.text(0.5, 4, 'y=f(x)=x$^2$-2x+4', color="grey", size=15)
ax41.text(4, 1, 'y=f$^{-1}$(x)=1-$\sqrt{x-3}$', color="black", size=15)

fig41.savefig("fig_functions_41.pdf", bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Oefeningen

# %% [markdown]
# ### fig_functions_42a

# %%
fig42a = plt.figure(figsize=(5,4))
ax42a = fig42a.add_axes([0,0,1,1])

ax42a.set_xlim(-1, 4)
ax42a.set_ylim(-1, 4)
ax42a.set_yticks([])
ax42a.set_xticks([])

x = np.linspace(1, 4, 1000)
y1 = np.sqrt(x-1)+2
y2 = -np.sqrt(x-1)+2


for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax42a.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax42a.spines[direction].set_position('zero')

ax42a.arrow(-1, 0, 5.1, 0., fc='k', ec='k', lw = .5, head_width=0.2, head_length=0.2, overhang = 0.3, length_includes_head= False, clip_on = False)
ax42a.arrow(0, -1, 0, 5.1, fc='k', ec='k', lw = .5, head_width=0.2, head_length=0.2, overhang = 0.3, length_includes_head= False, clip_on = False)

ax42a.plot(x, y1, color='black')
ax42a.plot(x, y2, color='black')

ax42a.text(4.2, -0.5, 'x', color="black", size=15)
ax42a.text(0.2, 4.2, 'y', color="black", size=15)

fig42a.savefig("fig_functions_42a.pdf", bbox_inches='tight')
fig42a.savefig("fp-56a(tbc).pdf", bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_functions_42b

# %%
fig42b = plt.figure(figsize=(5,4))
ax42b = fig42b.add_axes([0,0,1,1])

ax42b.set_xlim(-1, 4)
ax42b.set_ylim(-1, 4)
ax42b.set_yticks([])
ax42b.set_xticks([])

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax42b.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax42b.spines[direction].set_position('zero')
        
ax42b.arrow(-1, 0, 5.1, 0., fc='k', ec='k', lw = .5, head_width=0.2, head_length=0.2, overhang = 0.3, length_includes_head= False, clip_on = False)
ax42b.arrow(0, -1, 0, 5.1, fc='k', ec='k', lw = .5, head_width=0.2, head_length=0.2, overhang = 0.3, length_includes_head= False, clip_on = False)

ax42b.plot([0.5, 1], [1, 1], color='black')
x = np.linspace(1, 2, 1000)
y = -4*(x-1.5)**2+2
ax42b.plot(x, y, color='black')
x = np.linspace(2, 3.5, 1000)
y = 2.3*(x - 2.75)**3 + 2
ax42b.plot(x, y, color='black')


ax42b.text(4.2, -0.5, 'x', color="black", size=15)
ax42b.text(0.2, 4.2, 'y', color="black", size=15)

fig42b.savefig("fig_functions_42b.pdf", bbox_inches='tight')
fig42b.savefig("fp-56b(tbc).pdf", bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_functions_42c

# %%
fig42c = plt.figure(figsize=(5,4))
ax42c = fig42c.add_axes([0,0,1,1])

ax42c.set_xlim(-1, 4)
ax42c.set_ylim(-1, 4)
ax42c.set_yticks([])
ax42c.set_xticks([])

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax42c.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax42c.spines[direction].set_position('zero')
        
ax42c.arrow(-1, 0, 5.1, 0., fc='k', ec='k', lw = .5, head_width=0.2, head_length=0.2, overhang = 0.3, length_includes_head= False, clip_on = False)
ax42c.arrow(0, -1, 0, 5.1, fc='k', ec='k', lw = .5, head_width=0.2, head_length=0.2, overhang = 0.3, length_includes_head= False, clip_on = False)

t = np.linspace(0.85*np.pi, 2.15*np.pi, 1000)
x = np.sqrt(2) * np.cos(t)/(1 + np.sin(t)**2) + 2
y = np.sqrt(2) * np.sin(t) * np.cos(t)/(1 + np.sin(t)**2) + 2
ax42c.plot(x, y, color='black')

ax42c.text(4.2, -0.5, 'x', color="black", size=15)
ax42c.text(0.2, 4.2, 'y', color="black", size=15)

fig42c.savefig("fig_functions_42c.pdf", bbox_inches='tight')
fig42c.savefig("fp-56c(tbc).pdf", bbox_inches='tight')

plt.show()

# %% [markdown]
# ### fig_functions_42d

# %%
fig42d = plt.figure(figsize=(5,4))
ax42d = fig42d.add_axes([0,0,1,1])

ax42d.set_xlim(-1, 4)
ax42d.set_ylim(-1, 4)
ax42d.set_yticks([])
ax42d.set_xticks([])

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax42d.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax42d.spines[direction].set_position('zero')
        
ax42d.arrow(-1, 0, 5.1, 0., fc='k', ec='k', lw = .5, head_width=0.2, head_length=0.2, overhang = 0.3, length_includes_head= False, clip_on = False)
ax42d.arrow(0, -1, 0, 5.1, fc='k', ec='k', lw = .5, head_width=0.2, head_length=0.2, overhang = 0.3, length_includes_head= False, clip_on = False)

x, y = np.meshgrid(np.linspace(0, 4, 100), np.linspace(0, 4, 100))
F = (x - 2)**2 + 6*(y - 2)**2-2
ax42d.contour(x, y, F, [0], colors="black")

ax42d.text(4.2, -0.5, 'x', color="black", size=15)
ax42d.text(0.2, 4.2, 'y', color="black", size=15)

fig42d.savefig("fig_functions_42d.pdf", bbox_inches='tight')
fig42d.savefig("fp-56d(tbc).pdf", bbox_inches='tight')

plt.show()

# %% [markdown]
# ### fig_functions_43

# %%
fig43 = plt.figure(figsize=(5,4))
ax43 = fig43.add_axes([0,0,1,1])

ax43.set_xlim(-1, 3.7)
ax43.set_ylim(-0.25, 0.75)
ax43.set_xticks([2, 3.5])
ax43.set_yticks([0.5])
labels_x = [item.get_text() for item in ax43.get_xticklabels()]
labels_y = [item.get_text() for item in ax43.get_yticklabels()]
labels_x[0] = '1'
labels_x[1] = '2'
labels_y[0] = '1'
ax43.set_xticklabels(labels_x)
ax43.set_yticklabels(labels_y)


for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax43.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax43.spines[direction].set_position('zero')

ax43.arrow(-1, 0, 4.6, 0., fc='k', ec='k', lw = .5, head_width=0.05, head_length=0.2, overhang = 0.3, length_includes_head= False, clip_on = False)
ax43.arrow(0, -0.25, 0, 1.1, fc='k', ec='k', lw = .5, head_width=0.2, head_length=0.05, overhang = 0.3, length_includes_head= False, clip_on = False)

x = np.linspace(0, 4, 100)
y = np.exp(-2*(x - 2)**2)/2
ax43.plot(x, y, color="black")
ax43.scatter([0, 3.5, 2], [0, 0, 0.5], color="black")

ax43.text(3.7, -0.1, 'x', color="black", size=15)
ax43.text(0.2, 0.9, 'y', color="black", size=15)

fig43.savefig("fig_functions_43.pdf", bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_functions_44

# %%
fig44 = plt.figure(figsize=(5,4))
ax44 = fig44.add_axes([0,0,1,1])

ax44.set_xlim(-4, 4)
ax44.set_ylim(-1.5, 2.5)
ax44.set_xticks([-2, -1, 2])
ax44.set_yticks([-1, 2])
ax44.text(0.1, -0.2, '0', color="black", size=10)

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax44.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax44.spines[direction].set_position('zero')

ax44.arrow(-4, 0, 8.1, 0., fc='k', ec='k', lw = .5, head_width=0.2, head_length=0.3, overhang = 0.3, length_includes_head= False, clip_on = False)
ax44.arrow(0, -1.5, 0, 4.1, fc='k', ec='k', lw = .5, head_width=0.3, head_length=0.2, overhang = 0.3, length_includes_head= False, clip_on = False)

x = np.linspace(-3, -1, 100)
y = -(x+2)
ax44.plot(x, y, color="black")
x = np.linspace(-1, 2, 100)
y = x
ax44.plot(x, y, color="black")
ax44.plot([2, 3.5], [2, 2], color="black")
ax44.scatter([-2, -1, 2], [0, -1, 2], color="black")

ax44.text(4, -0.4, 'x', color="black", size=15)
ax44.text(0.2, 2.5, 'y', color="black", size=15)

fig44.savefig("fig_functions_44.pdf", bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_functions45a

# %%
fig45a = plt.figure(figsize=(4,5))
ax45a = fig45a.add_axes([0,0,1,1])

ax45a.set_xlim(0, 4)
ax45a.set_ylim(-4, 6)
ax45a.set_xticks([1, 2, 3])
ax45a.set_yticks([-3, -2, -1, 1, 2, 3, 4, 5])
ax45a.text(0.1, -0.3, '0', color="black", size=10)

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax45a.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax45a.spines[direction].set_position('zero')

ax45a.arrow(2, -3, 0, 8., fc='k', ec='k', lw = .5, head_width=0.2, head_length=0.3, overhang = 0.3, length_includes_head= True, clip_on = False)

ax45a.arrow(0, 0, 4, 0., fc='k', ec='k', lw = .5, head_width=0.3, head_length=0.2, overhang = 0.3, length_includes_head= False, clip_on = False)
ax45a.arrow(0, -4, 0, 10, fc='k', ec='k', lw = .5, head_width=0.2, head_length=0.3, overhang = 0.3, length_includes_head= False, clip_on = False)

ax45a.scatter([2], [-3], color="black", facecolors='white', marker='o', zorder=10)

ax45a.text(4, -0.4, 'x', color="black", size=15)
ax45a.text(0.2, 6.5, 'y', color="black", size=15)

fig45a.savefig("fig_functions_45a.pdf", bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_functions_45b

# %%
fig45b = plt.figure(figsize=(4,5))
ax45b = fig45b.add_axes([0,0,1,1])

ax45b.set_xlim(-4, 4)
ax45b.set_ylim(-4, 6)
ax45b.set_xticks([-3, -2, -1, 1, 2, 3])
ax45b.set_yticks([-3, -2, -1, 1, 2, 3, 4, 5])
ax45b.text(0.1, -0.3, '0', color="black", size=10)

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax45b.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax45b.spines[direction].set_position('zero')

ax45b.arrow(2, -3, 0, 8., fc='k', ec='k', lw = .5, head_width=0.2, head_length=0.3, overhang = 0.3, length_includes_head= True, clip_on = False)
ax45b.arrow(2, 5, 0, -8., fc='k', ec='k', lw = .5, head_width=0.2, head_length=0.3, overhang = 0.3, length_includes_head= True, clip_on = False)

ax45b.arrow(-2, 4.9, 0, 0.1, fc='k', ec='k', lw = .5, head_width=0.2, head_length=0.3, overhang = 0.3, length_includes_head= True, clip_on = False)
ax45b.arrow(-2, -2.9, 0, -0.1, fc='k', ec='k', lw = .5, head_width=0.2, head_length=0.3, overhang = 0.3, length_includes_head= True, clip_on = False)
ax45b.plot([-2, -2], [5, -3], ls='--', color='black')

ax45b.fill_between([-2, 2], [5, 5], [-3, -3], color='grey')

ax45b.arrow(-4, 0, 8, 0., fc='k', ec='k', lw = .5, head_width=0.3, head_length=0.2, overhang = 0.3, length_includes_head= False, clip_on = False)
ax45b.arrow(0, -4, 0, 10, fc='k', ec='k', lw = .5, head_width=0.2, head_length=0.3, overhang = 0.3, length_includes_head= False, clip_on = False)
ax45b.text(4, -0.4, 'x', color="black", size=15)
ax45b.text(0.2, 6.5, 'y', color="black", size=15)

fig45b.savefig("fig_functions_45b.pdf", bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_functions_45c

# %%
fig45c = plt.figure(figsize=(4,4))
ax45c = fig45c.add_axes([0,0,1,1])

ax45c.set_xlim(-1, 5)
ax45c.set_ylim(-1, 5)
ax45c.set_xticks([-1, 1, 2, 3, 4, 5])
ax45c.set_yticks([-1, 1, 2, 3, 4, 5])
ax45c.text(0.1, -0.3, '0', color="black", size=10)

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax45c.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax45c.spines[direction].set_position('zero')

ax45c.fill_between([0, 5], [5, 5], [0, 0], color='grey')

ax45c.arrow(-1, 0, 6, 0., fc='k', ec='k', lw = .5, head_width=0.3, head_length=0.3, overhang = 0.3, length_includes_head= False, clip_on = False)
ax45c.arrow(0, -1, 0, 6, fc='k', ec='k', lw = .5, head_width=0.3, head_length=0.3, overhang = 0.3, length_includes_head= False, clip_on = False)
ax45c.text(5.2, -0.4, 'x', color="black", size=15)
ax45c.text(0.2, 5.5, 'y', color="black", size=15)

fig45c.savefig("fig_functions_45c.pdf", bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_functions_45d

# %%
fig45d = plt.figure(figsize=(4,4))
ax45d = fig45d.add_axes([0,0,1,1])

ax45d.set_xlim(-4, 5)
ax45d.set_ylim(-3, 2)
ax45d.set_xticks([-4, -3, -2, -1, 1, 2, 3, 4, 5])
ax45d.set_yticks([-3, -2, -1, 1, 2])
ax45d.text(0.1, -0.3, '0', color="black", size=10)

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax45d.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax45d.spines[direction].set_position('zero')

ax45d.fill_between([-4, 5], [2, 2], [-3, -3], color='grey')
ax45d.plot([-4, 5], [2, 2], color='black', ls='--')
ax45d.plot([-4, 5], [-3, -3], color='black', ls='--')
ax45d.plot([-4, -4], [-3, 2], color='black', ls='--')
ax45d.plot([5, 5], [-3, 2], color='black', ls='--')

ax45d.arrow(-4, 0, 9, 0., fc='k', ec='k', lw = .5, head_width=0.3, head_length=0.3, overhang = 0.3, length_includes_head= False, clip_on = False)
ax45d.arrow(0, -3, 0, 5, fc='k', ec='k', lw = .5, head_width=0.3, head_length=0.3, overhang = 0.3, length_includes_head= False, clip_on = False)
ax45d.text(5.2, -0.4, 'x', color="black", size=15)
ax45d.text(0.2, 2.5, 'y', color="black", size=15)

fig45d.savefig("fig_functions_45d.pdf", bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_functions_46a

# %%
fig46a = plt.figure(figsize=(4,4))
ax46a = fig46a.add_axes([0,0,1,1])

ax46a.set_xlim(-5.1, 5.1)
ax46a.set_ylim(-5, 5)
ax46a.set_yticks([-4, -2, 2, 4])
ax46a.set_xticks([-4, -2, 0, 2, 4])

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax46a.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax46a.spines[direction].set_position('zero')

ax46a.arrow(-5.1, 0, 10.2, 0., fc='k', ec='k', lw = .5, head_width=0.3, head_length=0.3, overhang = 0.3, length_includes_head= False, clip_on = False)
ax46a.arrow(0, -5.1, 0, 10.2, fc='k', ec='k', lw = .5, head_width=0.3, head_length=0.3, overhang = 0.3, length_includes_head= False, clip_on = False)

ta = np.linspace(0, np.pi/2, 10000)
ax46a.plot(1/np.cos(ta), np.tan(ta), color="black")
tb = np.linspace(np.pi/2+0.1, np.pi, 10000)
ax46a.plot(1/np.cos(tb), np.tan(tb), color="black")
tc = np.linspace(np.pi, 3*np.pi/2, 10000)
ax46a.plot(1/np.cos(tc), np.tan(tc), color="black")
td = np.linspace(3*np.pi/2+0.1, 2*np.pi, 10000)
ax46a.plot(1/np.cos(td), np.tan(td), color="black")

ax46a.text(5.4, 0, 'x', color="black", size=15)
ax46a.text(0.2, 5.3, 'y', color="black", size=15)
fig46a.savefig("fig_functions_46a.pdf",bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_functions_46b

# %%
fig46b = plt.figure(figsize=(8,4))
ax46b = fig46b.add_axes([0,0,1,1])

ax46b.set_xlim(-5.1, 5.1)
ax46b.set_ylim(-0.1, 5)
ax46b.set_yticks([1, 2, 3, 4])
ax46b.set_xticks([-4, -3, -2, -1, 0, 1, 2, 3, 4])

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax46b.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax46b.spines[direction].set_position('zero')

ax46b.arrow(-5.1, 0, 10.2, 0., fc='k', ec='k', lw = .5, head_width=0.3, head_length=0.3, overhang = 0.3, length_includes_head= False, clip_on = False)
ax46b.arrow(0, 0, 0, 5.2, fc='k', ec='k', lw = .5, head_width=0.3, head_length=0.3, overhang = 0.3, length_includes_head= False, clip_on = False)

x = np.linspace(-5, 5, 10000)
ax46b.plot(x, 4/(x**2+1), color="black")

ax46b.text(5.4, 0, 'x', color="black", size=15)
ax46b.text(0.2, 5.3, 'y', color="black", size=15)
fig46b.savefig("fig_functions_46b.pdf",bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_functions_46c

# %%
fig46c = plt.figure(figsize=(4,4))
ax46c = fig46c.add_axes([0,0,1,1])

ax46c.set_xlim(-5.1, 5.1)
ax46c.set_ylim(-5, 5)
ax46c.set_yticks([-4, -2, 2, 4])
ax46c.set_xticks([-4, -2, 0, 2, 4])

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax46c.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax46c.spines[direction].set_position('zero')

ax46c.arrow(-5.1, 0, 10.2, 0., fc='k', ec='k', lw = .5, head_width=0.3, head_length=0.3, overhang = 0.3, length_includes_head= False, clip_on = False)
ax46c.arrow(0, -5.1, 0, 10.2, fc='k', ec='k', lw = .5, head_width=0.3, head_length=0.3, overhang = 0.3, length_includes_head= False, clip_on = False)

x = np.linspace(-5, -1, 10000)
ax46c.plot(x, -(x+3)**2+4, color="black")
ax46c.plot([-1, 3], [-2, -1], color="black")
ax46c.scatter([-5, -1], [0, 0], color="black")
ax46c.scatter([-3, -1, 3], [4, -2, -1], color="black", fc='white', zorder=10)

ax46c.text(5.4, 0, 'x', color="black", size=15)
ax46c.text(0.2, 5.3, 'y', color="black", size=15)
fig46c.savefig("fig_functions_46c.pdf",bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_functions_46d

# %%
fig46d = plt.figure(figsize=(4,4))
ax46d = fig46d.add_axes([0,0,1,1])
ax46d.set_xlim(-4.1, 4.1)
ax46d.set_ylim(-4.1, 4.1)
ax46d.set_yticks([-4, -2, 2, 4])
ax46d.set_xticks([-4, -2, 0, 2, 4])

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax46d.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax46d.spines[direction].set_position('zero')

ax46d.arrow(-4.1, 0, 8.1, 0., fc='k', ec='k', lw = .5, head_width=0.25, head_length=0.25, overhang = 0.3, length_includes_head= False, clip_on = False)
ax46d.arrow(0, -4.1, 0, 8.1, fc='k', ec='k', lw = .5, head_width=0.25, head_length=0.25, overhang = 0.3, length_includes_head= False, clip_on = False)

theta = np.linspace(0, np.pi, 10000)
r = 4*np.sin(3*theta)
ax46d.plot(r*np.cos(theta), r*np.sin(theta), color='black')

ax46d.text(4.4, 0, 'x', color="black", size=15)
ax46d.text(0.3, 4.2, 'y', color="black", size=15)
fig46d.savefig("fig_functions_46d.pdf",bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_functions_47

# %%
fig47 = plt.figure(figsize=(5,4))
ax47 = fig47.add_axes([0,0,1,1])

ax47.set_xlim(-4.2, 4.2)
ax47.set_ylim(-5.2, 5.2)
ax47.set_xticks([-4, -3, -2, -1, 1, 2, 3, 4])
ax47.set_yticks([-5, -4, -3, -2, -1, 1, 2, 3, 4, 5])

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax47.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax47.spines[direction].set_position('zero')

ax47.arrow(-4, 0, 8.5, 0., fc='k', ec='k', lw = .5, head_width=0.5, head_length=0.3, overhang = 0.3, length_includes_head= False, clip_on = False)
ax47.arrow(0, -5, 0, 10, fc='k', ec='k', lw = .5, head_width=0.3, head_length=0.5, overhang = 0.3, length_includes_head= False, clip_on = False)

x = np.linspace(-4, 4, 100)
ax47.plot(x, 5*np.sin(np.pi/4*x), color="black")
ax47.scatter([-4, -2, 0, 2, 4], [0, -5, 0, 3, 0], color="black")
ax47.scatter([2], [5], color="black", facecolors='white', marker='o', zorder=10)

ax47.text(5, -0.1, 'x', color="black", size=15)
ax47.text(0.2, 5.4, 'y', color="black", size=15)

fig47.savefig("fig_functions_47.pdf", bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_functions_48a

# %%
fig48a = plt.figure(figsize=(4,4))
ax48a = fig48a.add_axes([0,0,1,1])

ax48a.set_xlim(-0.2, 4.2)
ax48a.set_ylim(-0.2, 4.2)
ax48a.set_xticks([1, 2, 3, 4])
ax48a.set_yticks([1, 2, 3, 4])

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax48a.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax48a.spines[direction].set_position('zero')

ax48a.arrow(-0.5, 0, 5, 0., fc='k', ec='k', lw = .5, head_width=0.2, head_length=0.2, overhang = 0.3, length_includes_head= False, clip_on = False)
ax48a.arrow(0, -0.5, 0, 5, fc='k', ec='k', lw = .5, head_width=0.2, head_length=0.2, overhang = 0.3, length_includes_head= False, clip_on = False)

x = np.linspace(-4, 4, 100)
ax48a.plot([0, 1, 2, 3, 4], [4, 2, 3, 3, 0], color="black", marker='o')
ax48a.text(1, 4, 'y=f(x)', color="black", size=15)

ax48a.text(5, -0.1, 'x', color="black", size=15)
ax48a.text(0.2, 4.6, 'y', color="black", size=15)

fig48a.savefig("fig_functions_48a.pdf", bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_functions_48b

# %%
fig48b = plt.figure(figsize=(4,4))
ax48b = fig48b.add_axes([0,0,1,1])

ax48b.set_xlim(-0.2, 4.2)
ax48b.set_ylim(-0.2, 4.2)
ax48b.set_xticks([1, 2, 3, 4])
ax48b.set_yticks([1, 2, 3, 4])

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax48b.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax48b.spines[direction].set_position('zero')

ax48b.arrow(-0.5, 0, 5, 0., fc='k', ec='k', lw = .5, head_width=0.2, head_length=0.2, overhang = 0.3, length_includes_head= False, clip_on = False)
ax48b.arrow(0, -0.5, 0, 5, fc='k', ec='k', lw = .5, head_width=0.2, head_length=0.2, overhang = 0.3, length_includes_head= False, clip_on = False)

x = np.linspace(-4, 4, 100)
ax48b.plot([0, 1, 2, 3, 4], [0, 3, 3, 0, 4], color="black", marker='o')
ax48b.text(1, 4, 'y=g(x)', color="black", size=15)

ax48b.text(5, -0.1, 'x', color="black", size=15)
ax48b.text(0.2, 4.6, 'y', color="black", size=15)

fig48b.savefig("fig_functions_48b.pdf", bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_functions_49

# %%
fig49 = plt.figure(figsize=(5,4))
ax49 = fig49.add_axes([0,0,1,1])

ax49.set_xlim(-2.2, 2.2)
ax49.set_ylim(-3.5, 3.5)
ax49.set_yticks([-3, -2, -1, 1, 2, 3])
ax49.set_xticks([-2, -1, 1, 2])
ax49.text(-0.2, -0.3, '0', color="black", size=10)

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax49.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax49.spines[direction].set_position('zero')

ax49.arrow(-2.2, 0, 4.5, 0., fc='k', ec='k', lw = .5, head_width=0.3, head_length=0.2, overhang = 0.3, length_includes_head= False, clip_on = False)
ax49.arrow(0, -3.5, 0, 7.1, fc='k', ec='k', lw = .5, head_width=0.2, head_length=0.3, overhang = 0.3, length_includes_head= False, clip_on = False)

x = np.linspace(-2, 2, 100)
ax49.plot(x, 3*np.sin(np.pi*x/2), color='black')
ax49.scatter([-2, -1, 0, 1, 2], [0, -3, 0, 3, 0], color='black')

ax49.text(2.6, -0.5, 'x', color="black", size=15)
ax49.text(0.2, 3.8, 'y', color="black", size=15)

ax49.text(-1.5, -3.5, '(-1,-3)', color="black", size=15)
ax49.text(-2.5, 0.2, '(-2,0)', color="black", size=15)
ax49.text(0.2, 0.3, '(0,0)', color="black", size=15)
ax49.text(2.2, 0.2, '(2,0)', color="black", size=15)
ax49.text(0.7, 3.2, '(1,3)', color="black", size=15)

fig49.savefig("fig_functions_49.pdf", bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_functions_abs3(tbc)

# %%
figabs3tbc = plt.figure(figsize=(5,4))
axabs3tbc = figabs3tbc.add_axes([0,0,1,1])

axabs3tbc.set_xlim(-4.2, 4.2)
axabs3tbc.set_ylim(-4, 1)
axabs3tbc.set_yticks([-3, -2, -1, 1])
axabs3tbc.set_xticks([-4, -2, 2, 4])
axabs3tbc.text(-0.2, -0.3, '0', color="black", size=10)

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    axabs3tbc.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        axabs3tbc.spines[direction].set_position('zero')

axabs3tbc.arrow(-4.2, 0, 8.5, 0., fc='k', ec='k', lw = .5, head_width=0.2, head_length=0.2, overhang = 0.3, length_includes_head= False, clip_on = False)
axabs3tbc.arrow(0, -3.5, 0, 4.6, fc='k', ec='k', lw = .5, head_width=0.2, head_length=0.2, overhang = 0.3, length_includes_head= False, clip_on = False)

x = np.linspace(-4, 4, 100)
axabs3tbc.plot(x, np.abs(x)-3, color='black')

axabs3tbc.text(4.6, -0.5, 'x', color="black", size=15)
axabs3tbc.text(0.2, 1.5, 'y', color="black", size=15)

figabs3tbc.savefig("fig_functions_abs3(tbc).pdf", bbox_inches='tight')
plt.show()
