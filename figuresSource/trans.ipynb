# %% [markdown]
# # Hoofdstuk 5 Transcendente functies

# %%
from mpl_toolkits.axisartist.axislines import SubplotZero
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import matplotlib
import numpy as np
matplotlib.rcParams["font.family"] = "monospace"
matplotlib.rcParams['font.style'] = "italic"
plt.rcParams.update({'mathtext.default':  'regular' })

# %% [markdown]
# ## 5.2 Exponentiële en logaritmische functies

# %% [markdown]
# ### fig_trans_1a

# %%
fig1a = plt.figure(figsize=(6,4))
ax1a = fig1a.add_axes([0,0,1,1])
ax1a.set_xlim(-4,  4)
ax1a.set_ylim(-0.5, 9)
ax1a.set_yticks([1,2,3,4,5,6,7,8])
ax1a.set_xticks([-4, -3, -2, -1, 1, 2, 3, 4])
ax1a.text(-0.2, -0.4, '0', color="black", size=10)

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax1a.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax1a.spines[direction].set_position('zero')

ax1a.arrow(-4, 0, 8.1, 0., fc='k', ec='k', lw = .5, head_width=0.4, head_length=0.4, overhang = 0.3, length_includes_head= False, clip_on = False)
ax1a.arrow(0, -0.5, 0, 9.6, fc='k', ec='k', lw = .5, head_width=0.3, head_length=0.5, overhang = 0.3, length_includes_head= False, clip_on = False)

x = np.linspace(-4, 4, 100)
y = 2**x

ax1a.plot(x, y, color="black")
ax1a.scatter([-3, -2, -1, 0, 1, 2, 3], [0.125, 0.25, 0.5, 1, 2, 4, 8], color='black')
ax1a.text(4.1, -1, 'x', color="black", size=15)
ax1a.text(0.2, 9.1, 'y', color="black", size=15)
fig1a.savefig("fig_trans_1a.pdf",bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_trans_1b

# %%
fig1b = plt.figure(figsize=(6,4))
ax1b = fig1b.add_axes([0,0,1,1])
ax1b.set_xlim(-4,  4)
ax1b.set_ylim(-0.5, 9)
ax1b.set_yticks([1,2,3,4,5,6,7,8])
ax1b.set_xticks([-4, -3, -2, -1, 1, 2, 3, 4])
ax1b.text(-0.2, -0.4, '0', color="black", size=10)

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax1b.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax1b.spines[direction].set_position('zero')

ax1b.arrow(-4, 0, 8.1, 0., fc='k', ec='k', lw = .5, head_width=0.4, head_length=0.4, overhang = 0.3, length_includes_head= False, clip_on = False)
ax1b.arrow(0, -0.5, 0, 9.6, fc='k', ec='k', lw = .5, head_width=0.3, head_length=0.5, overhang = 0.3, length_includes_head= False, clip_on = False)

x = np.linspace(-4, 4, 100)
y = 0.5**x

ax1b.plot(x, y, color="black")
ax1b.scatter([-3, -2, -1, 0, 1, 2, 3], [8, 4, 2, 1, 0.5, 0.25, 0.125], color='black')
ax1b.text(4.1, -1, 'x', color="black", size=15)
ax1b.text(0.2, 9.1, 'y', color="black", size=15)
fig1b.savefig("fig_trans_1b.pdf",bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_trans_2a

# %%
fig2a = plt.figure(figsize=(6,4))
ax2a = fig2a.add_axes([0,0,1,1])
ax2a.set_xlim(-3,  3)
ax2a.set_ylim(-0.5, 3)
ax2a.set_yticks([1,2,3])
ax2a.set_xticks([-3, -2, -1, 1, 2, 3])
ax2a.text(-0.2, -0.2, '0', color="black", size=10)

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax2a.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax2a.spines[direction].set_position('zero')

ax2a.arrow(-3, 0, 6.1, 0., fc='k', ec='k', lw = .5, head_width=0.2, head_length=0.2, overhang = 0.3, length_includes_head= False, clip_on = False)
ax2a.arrow(0, -0.5, 0, 3.6, fc='k', ec='k', lw = .5, head_width=0.2, head_length=0.2, overhang = 0.3, length_includes_head= False, clip_on = False)

x = np.linspace(-3, 3, 100)
y = (4/5)**x

ax2a.plot(x, y, color="black")
ax2a.scatter([-1, 0, 1], [5/4, 1, 4/5], color='black')
ax2a.text(3.3, -0.25, 'x', color="black", size=15)
ax2a.text(0.2, 3.3, 'y', color="black", size=15)
fig2a.savefig("fig_trans_2a.pdf",bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_trans_2b

# %%
fig2b = plt.figure(figsize=(6,4))
ax2b = fig2b.add_axes([0,0,1,1])
ax2b.set_xlim(-0.1,  6)
ax2b.set_ylim(-0.5, 26)
ax2b.set_yticks([5,10,15,20,25])
ax2b.set_xticks([0, 1, 2, 3, 4, 5, 6])

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax2b.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax2b.spines[direction].set_position('zero')

ax2b.arrow(0, 0, 6.1, 0., fc='k', ec='k', lw = .5, head_width=1, head_length=0.2, overhang = 0.3, length_includes_head= False, clip_on = False)
ax2b.arrow(0, -0.5, 0, 26.6, fc='k', ec='k', lw = .5, head_width=0.2, head_length=1, overhang = 0.3, length_includes_head= False, clip_on = False)

x = np.linspace(0, 6, 100)
y = 25*(4/5)**x

ax2b.plot(x, y, color="black")
ax2b.scatter([0, 1], [25, 20], color='black')
ax2b.text(6.3, -1, 'x', color="black", size=15)
ax2b.text(0.2, 27, 'y', color="black", size=15)
fig2b.savefig("fig_trans_2b.pdf",bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_trans_3a

# %%
fig3a = plt.figure(figsize=(6,4))
ax3a = fig3a.add_axes([0,0,1,1])
ax3a.set_xlim(-3, 3)
ax3a.set_ylim(-0.5, 6)
ax3a.set_yticks([1,2,3,4,5,6])
ax3a.set_xticks([-3, -2, -1, 1, 2, 3])
ax3a.text(-0.2, -0.4, '0', color="black", size=10)

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax3a.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax3a.spines[direction].set_position('zero')

ax3a.arrow(-3, 0, 6.1, 0., fc='k', ec='k', lw = .5, head_width=0.3, head_length=0.2, overhang = 0.3, length_includes_head= False, clip_on = False)
ax3a.arrow(0, -0.5, 0, 6.6, fc='k', ec='k', lw = .5, head_width=0.2, head_length=0.3, overhang = 0.3, length_includes_head= False, clip_on = False)

x = np.linspace(-3, 3, 100)
y = np.exp(x)

ax3a.plot(x, y, color="black")
ax3a.scatter([-1, 0, 1], [np.exp(-1), 1, np.exp(1)], color='black')
ax3a.text(3.1, -0.7, 't', color="black", size=15)
ax3a.text(0.2, 6.4, 'y', color="black", size=15)
fig3a.savefig("fig_trans_3a.pdf",bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_trans_3b

# %%
fig3b = plt.figure(figsize=(6,4))
ax3b = fig3b.add_axes([0,0,1,1])
ax3b.set_xlim(-0.5, 45)
ax3b.set_ylim(0, 75)
ax3b.set_yticks([10,20,30,40,50,60,70])
ax3b.set_xticks([0,10,20,30,40])

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax3b.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax3b.spines[direction].set_position('zero')

ax3b.arrow(-0.5, 0, 45.6, 0., fc='k', ec='k', lw = .5, head_width=4, head_length=2, overhang = 0.3, length_includes_head= False, clip_on = False)
ax3b.arrow(0, 0, 0, 75.1, fc='k', ec='k', lw = .5, head_width=2, head_length=4, overhang = 0.3, length_includes_head= False, clip_on = False)

x = np.linspace(0, 45, 100)
y = 21+50*np.exp(-0.1*x)

ax3b.plot(x, y, color="black")
ax3b.scatter([0, 10], [71, 21+50*np.exp(-1)], color='black')
ax3b.plot([0, 45], [21, 21], color="black", ls='--')
ax3b.text(20, 16, 'y=21', color='black', size=15)
ax3b.text(47, -5, 't', color="black", size=15)
ax3b.text(2, 70.4, 'y', color="black", size=15)
fig3b.savefig("fig_trans_3b.pdf",bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_trans_4a

# %%
fig4a = plt.figure(figsize=(6,4))
ax4a = fig4a.add_axes([0,0,1,1])
ax4a.set_xlim(-4, 9)
ax4a.set_ylim(-4, 9)
ax4a.set_yticks([-4, -2, 2, 4, 6, 8])
ax4a.set_xticks([-4, -2, 2, 4, 6, 8])
ax4a.text(-0.4, -0.5, '0', color="black", size=10)

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax4a.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax4a.spines[direction].set_position('zero')

ax4a.arrow(-4, 0, 13.1, 0., fc='k', ec='k', lw = .5, head_width=0.5, head_length=0.4, overhang = 0.3, length_includes_head= False, clip_on = False)
ax4a.arrow(0, -4, 0, 13.1, fc='k', ec='k', lw = .5, head_width=0.4, head_length=0.5, overhang = 0.3, length_includes_head= False, clip_on = False)

x = np.linspace(-4, 4, 100)
ax4a.plot(x, np.exp(x), color="black")
ax4a.plot(x, 2**x, color="black", ls=':')

x = np.linspace(0.0001, 9, 100)
ax4a.plot(x, np.log(x), color="grey")
ax4a.plot(x, np.log2(x), color="grey", ls=':')

ax4a.plot([-4, 9], [-4, 9], color="black", ls=':')

ax4a.text(0.1, 7, 'y=e$^x$', color='black', size=15)
ax4a.text(3, 7, 'y=2$^x$', color='black', size=15)
ax4a.text(6, 1, 'y=ln(x)', color='grey', size=15)
ax4a.text(5, 3.5, 'y=log$_2$(x)', color='grey', size=15)
ax4a.text(9, -1, 'x', color="black", size=15)
ax4a.text(0.5, 9, 'y', color="black", size=15)
fig4a.savefig("fig_trans_4a.pdf",bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_trans_4b

# %%
fig4b = plt.figure(figsize=(6,4))
ax4b = fig4b.add_axes([0,0,1,1])
ax4b.set_xlim(-4, 9)
ax4b.set_ylim(-4, 9)
ax4b.set_yticks([-4, -2, 2, 4, 6, 8])
ax4b.set_xticks([-4, -2, 2, 4, 6, 8])
ax4b.text(-0.4, -0.5, '0', color="black", size=10)

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax4b.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax4b.spines[direction].set_position('zero')

ax4b.arrow(-4, 0, 13.1, 0., fc='k', ec='k', lw = .5, head_width=0.5, head_length=0.4, overhang = 0.3, length_includes_head= False, clip_on = False)
ax4b.arrow(0, -4, 0, 13.1, fc='k', ec='k', lw = .5, head_width=0.4, head_length=0.5, overhang = 0.3, length_includes_head= False, clip_on = False)

x = np.linspace(-4, 8, 100)
ax4b.plot(x, np.exp(-x), color="black")
ax4b.plot(x, 0.5**x, color="black", ls=':')

x = np.linspace(0.0001, 9, 100)
ax4b.plot(x, np.log(x)/np.log(np.exp(-1)), color="grey")
ax4b.plot(x, np.log(x)/np.log(0.5), color="grey", ls=':')

ax4b.plot([-4, 9], [-4, 9], color="black", ls=':')

ax4b.text(-1.6, 7, 'y=e$^{-x}$', color='black', size=13)
ax4b.text(-5, 4, 'y=(1/2)$^x$', color='black', size=13)
ax4b.text(6, -1.5, 'y=log$_{e^{-1}}$(x)', color='grey', size=13)
ax4b.text(5, -3.7, 'y=log$_{1/2}$(x)', color='grey', size=13)
ax4b.text(9, -1, 'x', color="black", size=13)
ax4b.text(0.5, 9, 'y', color="black", size=13)
fig4b.savefig("fig_trans_4b.pdf",bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_trans_5a

# %%
fig5a = plt.figure(figsize=(6,4))
ax5a = fig5a.add_axes([0,0,1,1])
ax5a.set_xlim(-3, 4)
ax5a.set_ylim(-4, 1)
ax5a.set_yticks([-4, -3, -2, -1, 1])
ax5a.set_xticks([-3, -2, -1, 1, 2, 3, 4])
ax5a.text(-0.2, -0.3, '0', color="black", size=10)

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax5a.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax5a.spines[direction].set_position('zero')

ax5a.arrow(-3, 0, 7.1, 0., fc='k', ec='k', lw = .5, head_width=0.25, head_length=0.2, overhang = 0.3, length_includes_head= False, clip_on = False)
ax5a.arrow(0, -4, 0, 5.1, fc='k', ec='k', lw = .5, head_width=0.2, head_length=0.25, overhang = 0.3, length_includes_head= False, clip_on = False)

x = np.linspace(-3, 2.99999, 1000)
y = 2*np.log10(3-x)-1
ax5a.plot(x, y, color="black")

ax5a.text(4.4, -0.5, 'x', color="black", size=15)
ax5a.text(0.3, 1.3, 'y', color="black", size=15)
fig5a.savefig("fig_trans_5a.pdf",bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_trans_5b

# %%
fig5b = plt.figure(figsize=(6,4))
ax5b = fig5b.add_axes([0,0,1,1])
ax5b.set_xlim(-3, 4)
ax5b.set_ylim(-4, 4)
ax5b.set_yticks([-4, -3, -2, -1, 1, 2, 3, 4])
ax5b.set_xticks([-3, -2, -1, 1, 2, 3, 4])
ax5b.text(-0.2, -0.4, '0', color="black", size=10)

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax5b.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax5b.spines[direction].set_position('zero')

ax5b.arrow(-3, 0, 7.1, 0., fc='k', ec='k', lw = .5, head_width=0.25, head_length=0.2, overhang = 0.3, length_includes_head= False, clip_on = False)
ax5b.arrow(0, -4, 0, 8.1, fc='k', ec='k', lw = .5, head_width=0.2, head_length=0.25, overhang = 0.3, length_includes_head= False, clip_on = False)

x1 = np.linspace(-3, -0.00001, 100)
x2 = np.linspace(1.00001, 4, 100)
y1 = np.log(x1/(x1-1))
y2 = np.log(x2/(x2-1))
ax5b.plot(x1, y1, color="black")
ax5b.plot(x2, y2, color="black")

ax5b.text(4.4, -0.5, 'x', color="black", size=15)
ax5b.text(0.3, 4.3, 'y', color="black", size=15)
fig5b.savefig("fig_trans_5b.pdf",bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Goniometrische functies

# %% [markdown]
# ### fig_trans_6a

# %%
fig6a = plt.figure(figsize=(5,4))
ax6a = fig6a.add_axes([0,0,1,1])
ax6a.set_yticks([])
ax6a.set_xticks([])
ax6a.set_ylim(-0.5, 1)

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax6a.spines[direction].set_visible(False)
    if direction in ["left", "bottom"]:
        ax6a.spines[direction].set_visible(False)

ax6a.plot([0, 1, 2], [0, 0, np.sin(np.pi/8)], color="black")
ax6a.scatter([1], [0], color='black')

ax6a.text(1, -0.2, 'P', color="black", size=15)
fig6a.savefig("fig_trans_6a.pdf",bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_trans_6b

# %%
fig6b = plt.figure(figsize=(5,4))
ax6b = fig6b.add_axes([0,0,1,1])
ax6b.set_yticks([])
ax6b.set_xticks([])
ax6b.set_ylim(-0.5, 1)

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax6b.spines[direction].set_visible(False)
    if direction in ["left", "bottom"]:
        ax6b.spines[direction].set_visible(False)

ax6b.plot([2, 1, 2], [0, 0, np.sin(np.pi/8)], color="black")
ax6b.scatter([1], [0], color='black')

ax6b.text(1, -0.2, 'Q', color="black", size=15)
fig6b.savefig("fig_trans_6b.pdf",bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_trans_7a

# %%
fig7a = plt.figure(figsize=(5,4))
ax7a = fig7a.add_axes([0,0,1,1])
ax7a.set_ylim(-1, 1)
ax7a.set_xlim(-1, 1)

ax7a.set_yticks([])
ax7a.set_xticks([])
for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax7a.spines[direction].set_visible(False)
    if direction in ["left", "bottom"]:
        ax7a.spines[direction].set_visible(False)

ax7a.plot([-1, 2], [0, 0], color="black")
ax7a.plot([0, 1], [0, np.sin(np.pi/8)], color="black")
ax7a.scatter([0], [0], color='black')

ax7a.text(0.7, 0.1, '\u03B1', color="black", size=15)
ax7a.text(0, 0.6, '\u03B2', color="black", size=15)

path1 = matplotlib.path.Path(np.array([np.array([0.5*np.cos(theta), 0.5*np.sin(theta)]) for theta in np.linspace(np.pi/8, np.pi, 100)]), codes=None, _interpolation_steps=1, closed=False, readonly=False)
path2 = matplotlib.path.Path(np.array([np.array([0.5*np.cos(theta), 0.5*np.sin(theta)]) for theta in np.linspace(0, np.pi/8-0.05, 100)]), codes=None, _interpolation_steps=1, closed=False, readonly=False)

arc1 = patches.FancyArrowPatch(path=path1, connectionstyle="arc3,rad=-0.5", arrowstyle="<|-|>, head_width=2, head_length=2", color="k")
arc2 = patches.FancyArrowPatch(path=path2, connectionstyle="arc3,rad=0.5", arrowstyle="<|-|>, head_width=2, head_length=2", color="k")

ax7a.add_patch(arc1)
ax7a.add_patch(arc2)
fig7a.savefig("fig_trans_7a.pdf",bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_trans_7b

# %%
fig7b = plt.figure(figsize=(5,4))
ax7b = fig7b.add_axes([0,0,1,1])
ax7b.set_ylim(-0.5, 1)
ax7b.set_xlim(-0.5, 1)

ax7b.set_yticks([])
ax7b.set_xticks([])
for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax7b.spines[direction].set_visible(False)
    if direction in ["left", "bottom"]:
        ax7b.spines[direction].set_visible(False)

ax7b.plot([0, 0, 1], [1, 0, 0], color="black")
ax7b.plot([0, 1], [0, np.sin(np.pi/8)], color="black")
ax7b.scatter([0], [0], color='black')

ax7b.text(.7, 0.1, '\u03B3', color="black", size=15)
ax7b.text(.5, 0.5, '\u03B4', color="black", size=15)
path1 = matplotlib.path.Path(np.array([np.array([0.5*np.cos(theta), 0.5*np.sin(theta)]) for theta in np.linspace(np.pi/8, np.pi/2, 100)]), codes=None, _interpolation_steps=1, closed=False, readonly=False)
path2 = matplotlib.path.Path(np.array([np.array([0.5*np.cos(theta), 0.5*np.sin(theta)]) for theta in np.linspace(0, np.pi/8-0.05, 100)]), codes=None, _interpolation_steps=1, closed=False, readonly=False)

arc1 = patches.FancyArrowPatch(path=path1, connectionstyle="arc3,rad=-0.5", arrowstyle="<|-|>, head_width=2, head_length=2", color="k")
arc2 = patches.FancyArrowPatch(path=path2, connectionstyle="arc3,rad=0.5", arrowstyle="<|-|>, head_width=2, head_length=2", color="k")

ax7b.add_patch(arc1)
ax7b.add_patch(arc2)
fig7b.savefig("fig_trans_7b.pdf",bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_trans_8

# %%
fig8 = plt.figure(figsize=(4,4))
ax8 = fig8.add_axes([0,0,1,1])
ax8.set_xlim(-1.25, 1.25)
ax8.set_ylim(-1.25, 1.25)

ax8.set_yticks([])
ax8.set_xticks([])
for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax8.spines[direction].set_visible(False)
    if direction in ["left", "bottom"]:
        ax8.spines[direction].set_visible(False)

ax8.plot([0, 1.5], [0,0], color="black")
ax8.plot([0, 1.5*np.cos(np.pi/8)], [0, 1.5*np.sin(np.pi/8)], color="black")
ax8.scatter([0], [0], color='black')
ax8.plot(np.array([np.cos(t) for t in np.linspace(0,np.pi/8, 100)]), np.array([np.sin(t) for t in np.linspace(0,np.pi/8, 100)]), color='black')

ax8.text(0.7, 0.1, '\u03B8', color="black", size=15)
ax8.text(0.7, -0.2, 'r', color="black", size=15)
ax8.text(0.6, 0.35, 'r', color="black", size=15)
ax8.text(1.1, 0.2, 's', color="black", size=15)

path = matplotlib.path.Path(np.array([np.array([0.5*np.cos(theta), 0.5*np.sin(theta)]) for theta in np.linspace(0, np.pi/8-0.05, 100)]), codes=None, _interpolation_steps=1, closed=False, readonly=False)
arc = patches.FancyArrowPatch(path=path, connectionstyle="arc3,rad=0.5", arrowstyle="<|-|>, head_width=2, head_length=2", color="k")

circle1 = plt.Circle((0, 0), 1, color='grey', fill=False)

ax8.add_patch(arc)
ax8.add_patch(circle1)
fig8.savefig("fig_trans_8.pdf",bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_trans_9a

# %%
fig9a = plt.figure(figsize=(4,4))
ax9a = fig9a.add_axes([0,0,1,1])
ax9a.set_xlim(-1.25, 1.25)
ax9a.set_ylim(-1.25, 1.25)

ax9a.set_xticks([])
ax9a.set_yticks([])

ax9a.set_yticks([])
ax9a.set_xticks([])
for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax9a.spines[direction].set_visible(False)
    if direction in ["left", "bottom"]:
        ax9a.spines[direction].set_visible(False)

ax9a.arrow(-1.25, 0, 2.6, 0., fc='k', ec='k', lw = .5, head_width=0.1, head_length=0.1, overhang = 0.3, length_includes_head= False, clip_on = False)
ax9a.arrow(0, -1.25, 0, 2.6, fc='k', ec='k', lw = .5, head_width=0.1, head_length=0.1, overhang = 0.3, length_includes_head= False, clip_on = False)

ax9a.plot([0, -np.sqrt(2)], [0,np.sqrt(2)], color="black", ls='--')
ax9a.scatter([0], [0], color='black')

ax9a.text(1, -0.2, '1', color="black", size=15)
ax9a.text(0.05, 1.05, '1', color="black", size=15)
ax9a.text(-0.15, -0.15, '0', color="black", size=15)

path = matplotlib.path.Path(np.array([np.array([np.cos(theta), np.sin(theta)]) for theta in np.linspace(0, 2.35619449, 100)]), codes=None, _interpolation_steps=1, closed=False, readonly=False)
arc = patches.FancyArrowPatch(path=path, connectionstyle="arc3,rad=0.6", arrowstyle="-|>, head_width=4, head_length=4", color="k")

circle1 = plt.Circle((0, 0), 1, color='grey', fill=False)

ax9a.add_patch(circle1)
ax9a.add_patch(arc)
ax9a.text(1.35, -0.2, 'x', color="black", size=15)
ax9a.text(0.1, 1.35, 'y', color="black", size=15)
fig9a.savefig("fig_trans_9a.pdf",bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_trans_9b

# %%
fig9b = plt.figure(figsize=(4,4))
ax9b = fig9b.add_axes([0,0,1,1])
ax9b.set_xlim(-1.25, 1.25)
ax9b.set_ylim(-1.25, 1.25)

ax9b.set_xticks([])
ax9b.set_yticks([])

ax9b.set_yticks([])
ax9b.set_xticks([])
for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax9b.spines[direction].set_visible(False)
    if direction in ["left", "bottom"]:
        ax9b.spines[direction].set_visible(False)

ax9b.arrow(-1.25, 0, 2.6, 0., fc='k', ec='k', lw = .5, head_width=0.1, head_length=0.1, overhang = 0.3, length_includes_head= False, clip_on = False)
ax9b.arrow(0, -1.25, 0, 2.6, fc='k', ec='k', lw = .5, head_width=0.1, head_length=0.1, overhang = 0.3, length_includes_head= False, clip_on = False)

ax9b.scatter([0], [0], color='black')
ax9b.plot(np.array([np.cos(t) for t in np.linspace(0,2.35619449, 100)]), np.array([np.sin(t) for t in np.linspace(0,2.35619449, 100)]), color='black')

ax9b.text(1, -0.2, '1', color="black", size=15)
ax9b.text(0.05, 1.05, '1', color="black", size=15)
ax9b.text(-0.15, -0.15, '0', color="black", size=15)

path = matplotlib.path.Path(np.array([np.array([np.cos(theta), np.sin(theta)]) for theta in np.linspace(0, 2*np.pi, 100)]), codes=None, _interpolation_steps=1, closed=False, readonly=False)
arc = patches.FancyArrowPatch(path=path, connectionstyle="arc3,rad=0.6", arrowstyle="<|-, head_width=4, head_length=4", color="k")

circle1 = plt.Circle((0, 0), 1, color='grey', fill=False)

ax9b.add_patch(circle1)
ax9b.add_patch(arc)
ax9b.text(1.35, -0.2, 'x', color="black", size=15)
ax9b.text(0.1, 1.35, 'y', color="black", size=15)
fig9b.savefig("fig_trans_9b.pdf",bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_trans_10

# %%
fig10 = plt.figure(figsize=(4,4))
ax10 = fig10.add_axes([0,0,1,1])
ax10.set_xlim(-1.25, 1.25)
ax10.set_ylim(-1.25, 1.25)

ax10.set_yticks([])
ax10.set_xticks([])
for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax10.spines[direction].set_visible(False)
    if direction in ["left", "bottom"]:
        ax10.spines[direction].set_visible(False)
ax10.plot([0, 1.5], [0,0], color="black")
ax10.plot([0, 1.5*np.cos(np.pi/8)], [0, 1.5*np.sin(np.pi/8)], color="black")
ax10.scatter([0, 1, np.cos(np.pi/8)], [0, 0, np.sin(np.pi/8)], color='black', zorder=10)
ax10.plot(np.array([np.cos(t) for t in np.linspace(0,np.pi/8, 100)]), np.array([np.sin(t) for t in np.linspace(0,np.pi/8, 100)]), color='black')

ax10.text(0.7, 0.1, '\u03B8', color="black", size=15)
ax10.text(0.7, -0.2, 'r', color="black", size=15)
ax10.text(1, 0.5, 'P', color="black", size=15)
ax10.text(1, -0.2, 'Q', color="black", size=15)
ax10.text(1.1, 0.2, 's', color="black", size=15)

path = matplotlib.path.Path(np.array([np.array([0.5*np.cos(theta), 0.5*np.sin(theta)]) for theta in np.linspace(0, np.pi/8-0.05, 100)]), codes=None, _interpolation_steps=1, closed=False, readonly=False)
arc = patches.FancyArrowPatch(path=path, connectionstyle="arc3,rad=0.5", arrowstyle="-|>, head_width=2, head_length=2", color="k")

circle1 = plt.Circle((0, 0), 1, color='grey', fill=False)

ax10.add_patch(arc)
ax10.add_patch(circle1)
fig10.savefig("fig_trans_10.pdf",bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_trans_11

# %%
fig11 = plt.figure(figsize=(4,4))
ax11 = fig11.add_axes([0,0,1,1])
ax11.set_xlim(-0.1, 2.6)
ax11.set_ylim(-0.1, 1)

ax11.set_yticks([])
ax11.set_xticks([])
for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax11.spines[direction].set_visible(False)
    if direction in ["left", "bottom"]:
        ax11.spines[direction].set_visible(False)

ax11.plot([0, 2.5, 2.5, 0], [0, 0, 2.5*np.sin(np.pi/8), 0], color="black")

ax11.text(0.7, 0.1, '\u03B8', color="black", size=15)
ax11.text(1, -0.1, 'a', color="black", size=15)
ax11.text(2.6, 0.5, 'b', color="black", size=15)
ax11.text(1, 0.5, 'c', color="black", size=15)

path = matplotlib.path.Path(np.array([np.array([0.5*np.cos(theta), 0.5*np.sin(theta)]) for theta in np.linspace(0, np.pi/8-0.05, 100)]), codes=None, _interpolation_steps=1, closed=False, readonly=False)
arc = patches.FancyArrowPatch(path=path, connectionstyle="arc3,rad=0.5", arrowstyle="<|-|>, head_width=2, head_length=2", color="k")

ax11.add_patch(arc)
fig11.savefig("fig_trans_11.pdf",bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_trans_12

# %%
fig12 = plt.figure(figsize=(4,4))
ax12 = fig12.add_axes([0,0,1,1])
ax12.set_xlim(-1.25, 1.25)
ax12.set_ylim(-1.25, 1.25)

ax12.set_yticks([])
ax12.set_xticks([])
for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax12.spines[direction].set_visible(False)
    if direction in ["left", "bottom"]:
        ax12.spines[direction].set_visible(False)

ax12.arrow(-1.25, 0, 2.6, 0., fc='k', ec='k', lw = .5, head_width=0.1, head_length=0.1, overhang = 0.3, length_includes_head= False, clip_on = False)
ax12.arrow(0, -1.25, 0, 2.6, fc='k', ec='k', lw = .5, head_width=0.1, head_length=0.1, overhang = 0.3, length_includes_head= False, clip_on = False)

ax12.plot([0, 1.5*np.cos(np.pi/8)], [0, 1.5*np.sin(np.pi/8)], color="black")
ax12.scatter([0, np.cos(np.pi/8)], [0, np.sin(np.pi/8)], color='black', zorder=10)
ax12.plot(np.array([np.cos(t) for t in np.linspace(0,np.pi/8, 100)]), np.array([np.sin(t) for t in np.linspace(0,np.pi/8, 100)]), color='black')

ax12.text(1, -0.2, '1', color="black", size=15)
ax12.text(0.05, 1.05, '1', color="black", size=15)
ax12.text(-0.15, -0.15, '0', color="black", size=15)
ax12.text(0.6, 0.05, '\u03B8', color="black", size=15)
ax12.text(1, 0.25, 'P(cos(\u03B8), sin(\u03B8))', color="black", size=10)

path = matplotlib.path.Path(np.array([np.array([0.5*np.cos(theta), 0.5*np.sin(theta)]) for theta in np.linspace(0, np.pi/8-0.05, 100)]), codes=None, _interpolation_steps=1, closed=False, readonly=False)
arc = patches.FancyArrowPatch(path=path, connectionstyle="arc3,rad=0.5", arrowstyle="-|>, head_width=2, head_length=2", color="k")

circle1 = plt.Circle((0, 0), 1, color='grey', fill=False)

ax12.add_patch(circle1)
ax12.add_patch(arc)
ax12.text(1.35, -0.2, 'x', color="black", size=15)
ax12.text(0.1, 1.35, 'y', color="black", size=15)
fig12.savefig("fig_trans_12.pdf",bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_trans_13a

# %%
fig13a = plt.figure(figsize=(4,4))
ax13a = fig13a.add_axes([0,0,1,1])
ax13a.set_xlim(-1.25, 1.25)
ax13a.set_ylim(-1.25, 1.25)

ax13a.set_yticks([])
ax13a.set_xticks([])
for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax13a.spines[direction].set_visible(False)
    if direction in ["left", "bottom"]:
        ax13a.spines[direction].set_visible(False)

ax13a.arrow(-1.25, 0, 2.6, 0., fc='k', ec='k', lw = .5, head_width=0.1, head_length=0.1, overhang = 0.3, length_includes_head= False, clip_on = False)
ax13a.arrow(0, -1.25, 0, 2.6, fc='k', ec='k', lw = .5, head_width=0.1, head_length=0.1, overhang = 0.3, length_includes_head= False, clip_on = False)

ax13a.plot([0, 1.5*np.cos(5*np.pi/6)], [0, 1.5*np.sin(5*np.pi/6)], color="black")
ax13a.scatter([0, np.cos(5*np.pi/6)], [0, np.sin(5*np.pi/6)], color='black', zorder=10)
ax13a.plot(np.array([np.cos(t) for t in np.linspace(0,5*np.pi/6, 100)]), np.array([np.sin(t) for t in np.linspace(0,5*np.pi/6, 100)]), color='black')

ax13a.text(1, -0.2, '1', color="black", size=15)
ax13a.text(0.05, 1.05, '1', color="black", size=15)
ax13a.text(-0.15, -0.15, '0', color="black", size=15)
ax13a.text(0.2, 0.5, '5\u03C0/6', color="black", size=15)
ax13a.text(-1.2, 0.75, 'P(x,y)', color="black", size=13)

path = matplotlib.path.Path(np.array([np.array([0.5*np.cos(theta), 0.5*np.sin(theta)]) for theta in np.linspace(0, 5*np.pi/6, 100)]), codes=None, _interpolation_steps=1, closed=False, readonly=False)
arc = patches.FancyArrowPatch(path=path, connectionstyle="arc3,rad=0.5", arrowstyle="-|>, head_width=2, head_length=2", color="k")

circle1 = plt.Circle((0, 0), 1, color='grey', fill=False)

ax13a.add_patch(circle1)
ax13a.add_patch(arc)
ax13a.text(1.35, -0.2, 'x', color="black", size=15)
ax13a.text(0.1, 1.35, 'y', color="black", size=15)
fig13a.savefig("fig_trans_13a.pdf",bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_trans_13b

# %%
fig13b = plt.figure(figsize=(4,4))
ax13b = fig13b.add_axes([0,0,1,1])
ax13b.set_xlim(-1.25, 1.25)
ax13b.set_ylim(-1.25, 1.25)

ax13b.set_yticks([])
ax13b.set_xticks([])
for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax13b.spines[direction].set_visible(False)
    if direction in ["left", "bottom"]:
        ax13b.spines[direction].set_visible(False)

ax13b.arrow(-1.25, 0, 2.6, 0., fc='k', ec='k', lw = .5, head_width=0.1, head_length=0.1, overhang = 0.3, length_includes_head= False, clip_on = False)
ax13b.arrow(0, -1.25, 0, 2.6, fc='k', ec='k', lw = .5, head_width=0.1, head_length=0.1, overhang = 0.3, length_includes_head= False, clip_on = False)

ax13b.plot([0, 1.5*np.cos(5*np.pi/6)], [0, 1.5*np.sin(5*np.pi/6)], color="black")
ax13b.plot([0, 1.5*np.cos(np.pi/6)], [0, 1.5*np.sin(np.pi/6)], color="black", ls='--')
ax13b.scatter([0, np.cos(5*np.pi/6)], [0, np.sin(5*np.pi/6)], color='black', zorder=10)
ax13b.scatter([0, np.cos(np.pi/6)], [0, np.sin(np.pi/6)], color='black', zorder=10)

ax13b.text(1, -0.2, '1', color="black", size=15)
ax13b.text(0.05, 1.05, '1', color="black", size=15)
ax13b.text(-0.15, -0.15, '0', color="black", size=15)
ax13b.text(0.2, 0.5, '\u03B8=5\u03C0/6', color="black", size=10)
ax13b.text(0.75, 0.2, '\u03C0/6', color="black", size=10)
ax13b.text(-1.8, 0.4, 'P(-$\sqrt{3}$/2,1/2)', color="black", size=10)

path1 = matplotlib.path.Path(np.array([np.array([0.5*np.cos(theta), 0.5*np.sin(theta)]) for theta in np.linspace(0, 5*np.pi/6, 100)]), codes=None, _interpolation_steps=1, closed=False, readonly=False)
path2 = matplotlib.path.Path(np.array([np.array([0.75*np.cos(theta), 0.75*np.sin(theta)]) for theta in np.linspace(0, np.pi/6, 100)]), codes=None, _interpolation_steps=1, closed=False, readonly=False)
arc1 = patches.FancyArrowPatch(path=path1, connectionstyle="arc3,rad=0.5", arrowstyle="-|>, head_width=2, head_length=2", color="k")
arc2 = patches.FancyArrowPatch(path=path2, connectionstyle="arc3,rad=0.5", arrowstyle="-|>, head_width=2, head_length=2", color="k")

circle1 = plt.Circle((0, 0), 1, color='grey', fill=False)

ax13b.add_patch(circle1)
ax13b.add_patch(arc1)
ax13b.add_patch(arc2)
ax13b.text(1.35, -0.2, 'x', color="black", size=15)
ax13b.text(0.1, 1.35, 'y', color="black", size=15)
fig13b.savefig("fig_trans_13b.pdf",bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_trans_14a

# %%
fig14a = plt.figure(figsize=(4,4))
ax14a = fig14a.add_axes([0,0,1,1])
ax14a.set_xlim(-1.25, 1.25)
ax14a.set_ylim(-1.25, 1.25)

ax14a.set_yticks([])
ax14a.set_xticks([])
for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax14a.spines[direction].set_visible(False)
    if direction in ["left", "bottom"]:
        ax14a.spines[direction].set_visible(False)

ax14a.arrow(-1.25, 0, 2.6, 0., fc='k', ec='k', lw = .5, head_width=0.1, head_length=0.1, overhang = 0.3, length_includes_head= False, clip_on = False)
ax14a.arrow(0, -1.25, 0, 2.6, fc='k', ec='k', lw = .5, head_width=0.1, head_length=0.1, overhang = 0.3, length_includes_head= False, clip_on = False)

ax14a.plot([0, 1.5*np.cos(11*np.pi/6)], [0, 1.5*np.sin(11*np.pi/6)], color="black")
ax14a.scatter([0, np.cos(11*np.pi/6)], [0, np.sin(11*np.pi/6)], color='black', zorder=10)
ax14a.scatter([0, np.cos(-np.pi/6)], [0, np.sin(-np.pi/6)], color='black', zorder=10)

ax14a.text(1, -0.2, '1', color="black", size=15)
ax14a.text(0.05, 1.05, '1', color="black", size=15)
ax14a.text(-0.15, -0.15, '0', color="black", size=15)
ax14a.text(0.2, 0.5, '\u03B8=11\u03C0/6', color="black", size=10)
ax14a.text(0.75, -0.2, '\u03C0/6', color="black", size=10)

path1 = matplotlib.path.Path(np.array([np.array([0.5*np.cos(theta), 0.5*np.sin(theta)]) for theta in np.linspace(0, 11*np.pi/6, 100)]), codes=None, _interpolation_steps=1, closed=False, readonly=False)
path2 = matplotlib.path.Path(np.array([np.array([0.75*np.cos(theta), 0.75*np.sin(theta)]) for theta in np.linspace(0, -np.pi/6, 100)]), codes=None, _interpolation_steps=1, closed=False, readonly=False)
arc1 = patches.FancyArrowPatch(path=path1, connectionstyle="arc3,rad=0.5", arrowstyle="-|>, head_width=2, head_length=2", color="k")
arc2 = patches.FancyArrowPatch(path=path2, connectionstyle="arc3,rad=0.5", arrowstyle="<|-|>, head_width=2, head_length=2", color="k")

circle1 = plt.Circle((0, 0), 1, color='grey', fill=False)

ax14a.add_patch(circle1)
ax14a.add_patch(arc1)
ax14a.add_patch(arc2)
ax14a.text(1.35, -0.2, 'x', color="black", size=15)
ax14a.text(0.1, 1.35, 'y', color="black", size=15)
fig14a.savefig("fig_trans_14a.pdf",bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_trans_14b

# %%
fig14b = plt.figure(figsize=(4,4))
ax14b = fig14b.add_axes([0,0,1,1])
ax14b.set_xlim(-1.25, 1.25)
ax14b.set_ylim(-1.25, 1.25)

ax14b.set_yticks([])
ax14b.set_xticks([])
for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax14b.spines[direction].set_visible(False)
    if direction in ["left", "bottom"]:
        ax14b.spines[direction].set_visible(False)

ax14b.arrow(-1.25, 0, 2.6, 0., fc='k', ec='k', lw = .5, head_width=0.1, head_length=0.1, overhang = 0.3, length_includes_head= False, clip_on = False)
ax14b.arrow(0, -1.25, 0, 2.6, fc='k', ec='k', lw = .5, head_width=0.1, head_length=0.1, overhang = 0.3, length_includes_head= False, clip_on = False)

ax14b.plot([0, 1.5*np.cos(-5*np.pi/4)], [0, 1.5*np.sin(-5*np.pi/4)], color="black")
ax14b.scatter([0, np.cos(-5*np.pi/4)], [0, np.sin(-5*np.pi/4)], color='black', zorder=10)

ax14b.text(1, -0.2, '1', color="black", size=15)
ax14b.text(0.05, 1.05, '1', color="black", size=15)
ax14b.text(-0.15, -0.15, '0', color="black", size=15)
ax14b.text(0.3, -0.5, '\u03B8=-5\u03C0/4', color="black", size=10)
ax14b.text(-0.95, 0.2, '\u03C0/4', color="black", size=10)

path1 = matplotlib.path.Path(np.array([np.array([0.5*np.cos(theta), 0.5*np.sin(theta)]) for theta in np.linspace(0, -5*np.pi/4, 100)]), codes=None, _interpolation_steps=1, closed=False, readonly=False)
path2 = matplotlib.path.Path(np.array([np.array([-0.75*np.cos(theta), 0.75*np.sin(theta)]) for theta in np.linspace(0, np.pi/4, 100)]), codes=None, _interpolation_steps=1, closed=False, readonly=False)
arc1 = patches.FancyArrowPatch(path=path1, connectionstyle="arc3,rad=0.5", arrowstyle="-|>, head_width=2, head_length=2", color="k")
arc2 = patches.FancyArrowPatch(path=path2, connectionstyle="arc3,rad=0.5", arrowstyle="<|-|>, head_width=2, head_length=2", color="k")

circle1 = plt.Circle((0, 0), 1, color='grey', fill=False)

ax14b.add_patch(circle1)
ax14b.add_patch(arc1)
ax14b.add_patch(arc2)
ax14b.text(1.35, -0.2, 'x', color="black", size=15)
ax14b.text(0.1, 1.35, 'y', color="black", size=15)
fig14b.savefig("fig_trans_14b.pdf",bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_trans_14c

# %%
fig14c = plt.figure(figsize=(4,4))
ax14c = fig14c.add_axes([0,0,1,1])
ax14c.set_xlim(-1.25, 1.25)
ax14c.set_ylim(-1.25, 1.25)

ax14c.set_yticks([])
ax14c.set_xticks([])
for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax14c.spines[direction].set_visible(False)
    if direction in ["left", "bottom"]:
        ax14c.spines[direction].set_visible(False)
        
ax14c.arrow(-1.25, 0, 2.6, 0., fc='k', ec='k', lw = .5, head_width=0.1, head_length=0.1, overhang = 0.3, length_includes_head= False, clip_on = False)
ax14c.arrow(0, -1.25, 0, 2.6, fc='k', ec='k', lw = .5, head_width=0.1, head_length=0.1, overhang = 0.3, length_includes_head= False, clip_on = False)

ax14c.plot([0, 1.5*np.cos(8*np.pi/6)], [0, 1.5*np.sin(8*np.pi/6)], color="black")
ax14c.scatter([0, np.cos(8*np.pi/6)], [0, np.sin(8*np.pi/6)], color='black', zorder=10)

ax14c.text(1, -0.2, '1', color="black", size=15)
ax14c.text(0.05, 1.05, '1', color="black", size=15)
ax14c.text(0.05, -0.15, '0', color="black", size=15)
ax14c.text(0.3, 0.5, '\u03B8=\u03C0+\u03B1', color="black", size=13)
ax14c.text(-0.8, -0.4, '\u03B1', color="black", size=13)

path1 = matplotlib.path.Path(np.array([np.array([0.5*np.cos(theta), 0.5*np.sin(theta)]) for theta in np.linspace(0, 8*np.pi/6, 100)]), codes=None, _interpolation_steps=1, closed=False, readonly=False)
path2 = matplotlib.path.Path(np.array([np.array([-0.75*np.cos(theta), 0.75*np.sin(theta)]) for theta in np.linspace(0, -np.pi/3, 100)]), codes=None, _interpolation_steps=1, closed=False, readonly=False)
arc1 = patches.FancyArrowPatch(path=path1, connectionstyle="arc3,rad=0.5", arrowstyle="-|>, head_width=2, head_length=2", color="k")
arc2 = patches.FancyArrowPatch(path=path2, connectionstyle="arc3,rad=0.5", arrowstyle="-|>, head_width=2, head_length=2", color="k")

circle1 = plt.Circle((0, 0), 1, color='grey', fill=False)

ax14c.add_patch(circle1)
ax14c.add_patch(arc1)
ax14c.add_patch(arc2)
ax14c.text(1.35, -0.2, 'x', color="black", size=15)
ax14c.text(0.1, 1.35, 'y', color="black", size=15)
fig14c.savefig("fig_trans_14c.pdf",bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_trans_14d

# %%
fig14d = plt.figure(figsize=(4,4))
ax14d = fig14d.add_axes([0,0,1,1])
ax14d.set_xlim(-1.25, 1.25)
ax14d.set_ylim(-1.25, 1.25)

ax14d.set_yticks([])
ax14d.set_xticks([])
for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax14d.spines[direction].set_visible(False)
    if direction in ["left", "bottom"]:
        ax14d.spines[direction].set_visible(False)

ax14d.arrow(-1.25, 0, 2.6, 0., fc='k', ec='k', lw = .5, head_width=0.1, head_length=0.1, overhang = 0.3, length_includes_head= False, clip_on = False)
ax14d.arrow(0, -1.25, 0, 2.6, fc='k', ec='k', lw = .5, head_width=0.1, head_length=0.1, overhang = 0.3, length_includes_head= False, clip_on = False)

ax14d.plot([0, 1.5*np.cos(11*np.pi/6)], [0, 1.5*np.sin(11*np.pi/6)], color="black")
ax14d.scatter([0, np.cos(11*np.pi/6)], [0, np.sin(11*np.pi/6)], color='black', zorder=10)

ax14d.text(1, -0.2, '1', color="black", size=15)
ax14d.text(0.05, 1.05, '1', color="black", size=15)
ax14d.text(-0.15, -0.15, '0', color="black", size=15)
ax14d.text(0.3, 0.5, '\u03B8=2\u03C0-\u03B1', color="black", size=13)
ax14d.text(0.75, -0.2, '\u03B1', color="black", size=13)

path1 = matplotlib.path.Path(np.array([np.array([0.5*np.cos(theta), 0.5*np.sin(theta)]) for theta in np.linspace(0, 11*np.pi/6, 100)]), codes=None, _interpolation_steps=1, closed=False, readonly=False)
path2 = matplotlib.path.Path(np.array([np.array([0.75*np.cos(theta), 0.75*np.sin(theta)]) for theta in np.linspace(0, -np.pi/6, 100)]), codes=None, _interpolation_steps=1, closed=False, readonly=False)
arc1 = patches.FancyArrowPatch(path=path1, connectionstyle="arc3,rad=0.5", arrowstyle="-|>, head_width=2, head_length=2", color="k")
arc2 = patches.FancyArrowPatch(path=path2, connectionstyle="arc3,rad=0.5", arrowstyle="-|>, head_width=2, head_length=2", color="k")

circle1 = plt.Circle((0, 0), 1, color='grey', fill=False)

ax14d.add_patch(circle1)
ax14d.add_patch(arc1)
ax14d.add_patch(arc2)
ax14d.text(1.35, -0.2, 'x', color="black", size=15)
ax14d.text(0.1, 1.35, 'y', color="black", size=15)
fig14d.savefig("fig_trans_14d.pdf",bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_trans_15

# %%
fig15 = plt.figure(figsize=(4,4))
ax15 = fig15.add_axes([0,0,1,1])
ax15.set_xlim(-2.25, 2.25)
ax15.set_ylim(-2.25, 2.25)

ax15.set_yticks([])
ax15.set_xticks([])
for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax15.spines[direction].set_visible(False)
    if direction in ["left", "bottom"]:
        ax15.spines[direction].set_visible(False)

ax15.arrow(-2.25, 0, 4.6, 0., fc='k', ec='k', lw = .5, head_width=0.2, head_length=0.2, overhang = 0.3, length_includes_head= False, clip_on = False)
ax15.arrow(0, -2.25, 0, 4.6, fc='k', ec='k', lw = .5, head_width=0.2, head_length=0.2, overhang = 0.3, length_includes_head= False, clip_on = False)

ax15.plot([0, 2.5*np.cos(np.pi/4)], [0, 2.5*np.sin(np.pi/4)], color="black")
ax15.plot([np.cos(np.pi/4),  np.cos(np.pi/4)], [np.sin(np.pi/4), 0], color="black", ls="--", marker="o")
ax15.plot([2*np.cos(np.pi/4), 2*np.cos(np.pi/4)], [2*np.sin(np.pi/4), 0], color="black", ls="--", marker="o")
ax15.scatter([0], [0], color='black', zorder=10)

ax15.text(1, 0.1, '1', color="black", size=8)
ax15.text(0.05, 1.05, '1', color="black", size=8)
ax15.text(-0.2, -0.2, '0', color="black", size=8)
ax15.text(2, -0.3, 'r', color="black", size=8)
ax15.text(0.05, 2.05, 'r', color="black", size=8)
ax15.text(0.3, 0.1, '\u03B8', color="black", size=8)
ax15.text(0.4, -0.3, 'A($\~x$,0)', color="black", size=8)
ax15.text(0.8, 0.55, 'P($\~x$,$\~y$)', color="black", size=8)
ax15.text(1.6, 1.4, 'Q(x,y)', color="black", size=8)
ax15.text(1.3, -0.3, 'B(x,0)', color="black", size=8)


path = matplotlib.path.Path(np.array([np.array([0.25*np.cos(theta), 0.25*np.sin(theta)]) for theta in np.linspace(0, np.pi/4, 100)]), codes=None, _interpolation_steps=1, closed=False, readonly=False)
arc = patches.FancyArrowPatch(path=path, connectionstyle="arc3,rad=0.5", arrowstyle="-|>, head_width=2, head_length=2", color="k")

circle1 = plt.Circle((0, 0), 1, color='grey', fill=False)
circle2 = plt.Circle((0, 0), 2, color='grey', fill=False)

ax15.add_patch(circle1)
ax15.add_patch(circle2)
ax15.add_patch(arc)
ax15.text(2.35, -0.3, 'x', color="black", size=15)
ax15.text(0.1, 2.4, 'y', color="black", size=15)
fig15.savefig("fig_trans_15.pdf",bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_trans_16

# %%
fig16 = plt.figure(figsize=(4,4))
ax16 = fig16.add_axes([0,0,1,1])
ax16.set_xlim(-1.25, 1.25)
ax16.set_ylim(-1.25, 1.25)

ax16.set_yticks([])
ax16.set_xticks([])
for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax16.spines[direction].set_visible(False)
    if direction in ["left", "bottom"]:
        ax16.spines[direction].set_visible(False)

ax16.arrow(-1.25, 0, 2.6, 0., fc='k', ec='k', lw = .5, head_width=0.1, head_length=0.1, overhang = 0.3, length_includes_head= False, clip_on = False)
ax16.arrow(0, -1.25, 0, 2.6, fc='k', ec='k', lw = .5, head_width=0.1, head_length=0.1, overhang = 0.3, length_includes_head= False, clip_on = False)

ax16.plot([0, 1.5*np.cos(np.pi/3)], [0, 1.5*np.sin(np.pi/3)], color="black")
ax16.scatter([0, np.cos(np.pi/3)], [0, np.sin(np.pi/3)], color='black', zorder=10)
ax16.plot([0, 1.5*np.cos(-np.pi/3)], [0, 1.5*np.sin(-np.pi/3)], color="black")
ax16.scatter([0, np.cos(-np.pi/3)], [0, np.sin(-np.pi/3)], color='black', zorder=10)

ax16.text(1, -0.2, '1', color="black", size=15)
ax16.text(0.05, 1.05, '1', color="black", size=15)
ax16.text(-0.15, -0.15, '0', color="black", size=15)
ax16.text(0.5, 0.2, '\u03C0/3', color="black", size=13)
ax16.text(0.5, -0.2, '\u03C0/3', color="black", size=13)

path1 = matplotlib.path.Path(np.array([np.array([0.5*np.cos(theta), 0.5*np.sin(theta)]) for theta in np.linspace(0, np.pi/3, 100)]), codes=None, _interpolation_steps=1, closed=False, readonly=False)
path2 = matplotlib.path.Path(np.array([np.array([0.5*np.cos(theta), 0.5*np.sin(theta)]) for theta in np.linspace(0, -np.pi/3, 100)]), codes=None, _interpolation_steps=1, closed=False, readonly=False)
arc1 = patches.FancyArrowPatch(path=path1, connectionstyle="arc3,rad=0.5", arrowstyle="<|-|>, head_width=2, head_length=2", color="k")
arc2 = patches.FancyArrowPatch(path=path2, connectionstyle="arc3,rad=0.5", arrowstyle="<|-|>, head_width=2, head_length=2", color="k")

circle1 = plt.Circle((0, 0), 1, color='grey', fill=False)

ax16.add_patch(circle1)
ax16.add_patch(arc1)
ax16.add_patch(arc2)
ax16.text(1.35, -0.2, 'x', color="black", size=15)
ax16.text(0.1, 1.35, 'y', color="black", size=15)
fig16.savefig("fig_trans_16.pdf",bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_trans_16b

# %%
fig16b = plt.figure(figsize=(4,4))
ax16b = fig16b.add_axes([0,0,1,1])
ax16b.set_xlim(-1.25, 1.25)
ax16b.set_ylim(-1.25, 1.25)

ax16b.set_yticks([])
ax16b.set_xticks([])
for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax16b.spines[direction].set_visible(False)
    if direction in ["left", "bottom"]:
        ax16b.spines[direction].set_visible(False)

ax16b.arrow(-1.25, 0, 2.6, 0., fc='k', ec='k', lw = .5, head_width=0.1, head_length=0.1, overhang = 0.3, length_includes_head= False, clip_on = False)
ax16b.arrow(0, -1.25, 0, 2.6, fc='k', ec='k', lw = .5, head_width=0.1, head_length=0.1, overhang = 0.3, length_includes_head= False, clip_on = False)

ax16b.plot([0, np.cos(np.pi/8), np.cos(np.pi/8)], [0, np.sin(np.pi/8), 0], color="black")
ax16b.scatter([np.cos(np.pi/8)], [np.sin(np.pi/8)], color="black", zorder=10)

ax16b.text(0.75, -0.2, 'c=1', color="black", size=13)
ax16b.text(0.05, 0.75, 'c=1', color="black", size=13)
ax16b.text(-0.15, -0.15, '0', color="black", size=15)
ax16b.text(0.5, 0.1, '\u03B8', color="black", size=13)
ax16b.text(1, 0.3, 'P(a,b)', color="black", size=13)

path = matplotlib.path.Path(np.array([np.array([0.5*np.cos(theta), 0.5*np.sin(theta)]) for theta in np.linspace(0, np.pi/8, 100)]), codes=None, _interpolation_steps=1, closed=False, readonly=False)
arc = patches.FancyArrowPatch(path=path, connectionstyle="arc3,rad=0.5", arrowstyle="-|>, head_width=2, head_length=2", color="k")

circle1 = plt.Circle((0, 0), 1, color='grey', fill=False)

ax16b.add_patch(circle1)
ax16b.add_patch(arc)
ax16b.text(1.35, -0.2, 'x', color="black", size=15)
ax16b.text(0.1, 1.35, 'y', color="black", size=15)
fig16b.savefig("fig_trans_16b.pdf",bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_trans_17

# %%
fig17 = plt.figure(figsize=(8,4))
ax17 = fig17.add_axes([0,0,1,1])
ax17.set_xlim(-0.2, 1)
ax17.set_ylim(-0.2, 0.5)

ax17.set_yticks([])
ax17.set_xticks([])
for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax17.spines[direction].set_visible(False)
    if direction in ["left", "bottom"]:
        ax17.spines[direction].set_visible(False)

ax17.plot([0, np.cos(0.523598776), np.cos(0.523598776), 0], [0, np.sin(0.523598776), 0, 0], color="black")
ax17.plot([0.3660264038, 0.8660264038, 0.8660264038, 0.3660264038], [0, 0, 0.5, 0], color="black")

ax17.text(0.25, 0.05, '30$^{\circ}$', color="black", size=13)
ax17.text(0.65, 0.1, '45$^{\circ}$', color="black", size=13)
ax17.text(0.2, -0.05, '20', color="black", size=13)
ax17.text(0.65, -0.05, 'x', color="black", size=13)
ax17.text(0.9, 0.2, 'h', color="black", size=13)

path1 = matplotlib.path.Path(np.array([np.array([0.25*np.cos(theta), 0.25*np.sin(theta)]) for theta in np.linspace(0, 0.523598776, 100)]), codes=None, _interpolation_steps=1, closed=False, readonly=False)
arc1 = patches.FancyArrowPatch(path=path1, connectionstyle="arc3,rad=0.5", arrowstyle="-|>, head_width=2, head_length=2", color="k")
path2 = matplotlib.path.Path(np.array([np.array([0.3660264038+0.25*np.cos(theta), 0.25*np.sin(theta)]) for theta in np.linspace(0, 0.785398163, 100)]), codes=None, _interpolation_steps=1, closed=False, readonly=False)
arc2 = patches.FancyArrowPatch(path=path2, connectionstyle="arc3,rad=0.5", arrowstyle="-|>, head_width=2, head_length=2", color="k")

ax17.add_patch(arc1)
ax17.add_patch(arc2)
fig17.savefig("fig_trans_17.pdf",bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_trans_18

# %%
fig18 = plt.figure(figsize=(4,4))
ax18 = fig18.add_axes([0,0,1,1])
ax18.set_xlim(-1.25, 1.25)
ax18.set_ylim(-1.25, 1.25)

ax18.set_yticks([])
ax18.set_xticks([])
for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax18.spines[direction].set_visible(False)
    if direction in ["left", "bottom"]:
        ax18.spines[direction].set_visible(False)

ax18.arrow(-1.25, 0, 2.6, 0., fc='k', ec='k', lw = .5, head_width=0.1, head_length=0.1, overhang = 0.3, length_includes_head= False, clip_on = False)
ax18.arrow(0, -1.25, 0, 2.6, fc='k', ec='k', lw = .5, head_width=0.1, head_length=0.1, overhang = 0.3, length_includes_head= False, clip_on = False)

ax18.arrow(0, 0, 1.5*np.cos(7*np.pi/8), 1.5*np.sin(7*np.pi/8), fc='k', ec='k', lw = 1.5, head_width=0.1, head_length=0.1, overhang = 0.3, length_includes_head= False, clip_on = False)
ax18.arrow(0, 0, 1.5*np.cos(-7*np.pi/8), 1.5*np.sin(-7*np.pi/8), fc='k', ec='k', lw = 1.5, head_width=0.1, head_length=0.1, overhang = 0.3, length_includes_head= False, clip_on = False)
ax18.scatter([0, np.cos(7*np.pi/8), np.cos(-7*np.pi/8)], [0, np.sin(7*np.pi/8), np.sin(-7*np.pi/8)], color='black', zorder=10)

ax18.text(1, -0.2, '1', color="black", size=15)
ax18.text(0.05, 1.05, '1', color="black", size=15)
ax18.text(0.05, -0.15, '0', color="black", size=15)
ax18.text(0.5, 0.2, '\u03B8', color="black", size=13)
ax18.text(0.5, -0.2, '-\u03B8', color="black", size=13)
ax18.text(-2.05, 0.3, 'P(cos(\u03B8),sin(\u03B8))', color="black", size=10)
ax18.text(-2.2, -0.3, 'Q(cos(-\u03B8),sin(-\u03B8))', color="black", size=10)

path1 = matplotlib.path.Path(np.array([np.array([0.5*np.cos(theta), 0.5*np.sin(theta)]) for theta in np.linspace(0, 7*np.pi/8, 100)]), codes=None, _interpolation_steps=1, closed=False, readonly=False)
path2 = matplotlib.path.Path(np.array([np.array([0.5*np.cos(theta), 0.5*np.sin(theta)]) for theta in np.linspace(0, -7*np.pi/8, 100)]), codes=None, _interpolation_steps=1, closed=False, readonly=False)
arc1 = patches.FancyArrowPatch(path=path1, connectionstyle="arc3,rad=0.5", arrowstyle="-|>, head_width=2, head_length=2", color="k")
arc2 = patches.FancyArrowPatch(path=path2, connectionstyle="arc3,rad=0.5", arrowstyle="-|>, head_width=2, head_length=2", color="k")

circle1 = plt.Circle((0, 0), 1, color='grey', fill=False)

ax18.add_patch(circle1)
ax18.add_patch(arc1)
ax18.add_patch(arc2)
ax18.text(1.35, -0.2, 'x', color="black", size=15)
ax18.text(0.1, 1.35, 'y', color="black", size=15)
fig18.savefig("fig_trans_18.pdf",bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_trans_19

# %%
fig19 = plt.figure(figsize=(8,4))
ax19 = fig19.add_axes([0,0,1,1])
ax19.set_xlim(-0.2, 12)
ax19.set_ylim(-0.2, 6)

ax19.set_yticks([])
ax19.set_xticks([])
for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax19.spines[direction].set_visible(False)
    if direction in ["left", "bottom"]:
        ax19.spines[direction].set_visible(False)

ax19.plot([0, 12, 7, 0], [0, 0, 6, 0], color="black")

path1 = matplotlib.path.Path(np.array([np.array([1+np.cos(theta), np.sin(theta)]) for theta in np.linspace(0, 0.45*np.pi, 100)]), codes=None, _interpolation_steps=1, closed=False, readonly=False)
arc1 = patches.FancyArrowPatch(path=path1, connectionstyle="arc3,rad=0.5", arrowstyle="<|-|>, head_width=2, head_length=2", color="k")
path2 = matplotlib.path.Path(np.array([np.array([11.3-np.cos(theta), np.sin(theta)]) for theta in np.linspace(0, 0.45*np.pi, 100)]), codes=None, _interpolation_steps=1, closed=False, readonly=False)
arc2 = patches.FancyArrowPatch(path=path2, connectionstyle="arc3,rad=0.5", arrowstyle="<|-|>, head_width=2, head_length=2", color="k")
path3 = matplotlib.path.Path(np.array([np.array([7-np.cos(2*theta), 5.1-np.sin(2*theta)]) for theta in np.linspace(0, 0.45*np.pi, 100)]), codes=None, _interpolation_steps=1, closed=False, readonly=False)
arc3 = patches.FancyArrowPatch(path=path3, connectionstyle="arc3,rad=0.5", arrowstyle="<|-|>, head_width=2, head_length=2", color="k")

ax19.text(-0.5, 0, 'A', color="black", size=15)
ax19.text(7, 6.2, 'B', color="black", size=15)
ax19.text(12, 0, 'C', color="black", size=15)
ax19.text(9.6, 3, 'a', color="black", size=15)
ax19.text(7, -0.4, 'b', color="black", size=15)
ax19.text(3, 3, 'c', color="black", size=15)
ax19.text(2, 0.5, '\u03B1', color="black", size=15)
ax19.text(7, 3.5, '\u03B2', color="black", size=15)
ax19.text(10, 1, '\u03B3', color="black", size=15)

ax19.add_patch(arc1)
ax19.add_patch(arc2)
ax19.add_patch(arc3)
fig19.savefig("fig_trans_19.pdf",bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_trans_19a

# %%
fig19a = plt.figure(figsize=(8,4))
ax19a = fig19a.add_axes([0,0,1,1])
ax19a.set_xlim(-1.25, 1.25)
ax19a.set_ylim(-0.05, 1.25)

ax19a.set_yticks([])
ax19a.set_xticks([])
for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax19a.spines[direction].set_visible(False)
    if direction in ["left", "bottom"]:
        ax19a.spines[direction].set_visible(False)

ax19a.arrow(-1.25, 0, 2.6, 0., fc='k', ec='k', lw = .5, head_width=0.1, head_length=0.1, overhang = 0.3, length_includes_head= False, clip_on = False)
ax19a.arrow(0, -0.05, 0, 1.35, fc='k', ec='k', lw = .5, head_width=0.1, head_length=0.1, overhang = 0.3, length_includes_head= False, clip_on = False)

ax19a.plot([np.cos(theta) for theta in np.linspace(0, np.pi, 100)], [np.sin(theta) for theta in np.linspace(0, np.pi, 100)], color='grey')

ax19a.arrow(0, 0, 1.25*np.cos(np.pi/4), 1.25*np.sin(np.pi/4), fc='k', ec='k', lw = 1.5, head_width=0.1, head_length=0.1, overhang = 0.3, length_includes_head= False, clip_on = False)
ax19a.arrow(0, 0, 1.25*np.cos(2*np.pi/3), 1.25*np.sin(2*np.pi/3), fc='k', ec='k', lw = 1.5, head_width=0.1, head_length=0.1, overhang = 0.3, length_includes_head= False, clip_on = False)
ax19a.plot([np.cos(np.pi/4), np.cos(2*np.pi/3)], [np.sin(np.pi/4), np.sin(2*np.pi/3)], color='black', ls='--', marker='o')
ax19a.scatter([0], [0], color='black')

ax19a.text(1, -0.2, '1', color="black", size=15)
ax19a.text(0.05, 1.05, '1', color="black", size=15)
ax19a.text(-0.1, -0.1, '0', color="black", size=15)
ax19a.text(0.2, 0.5, '\u03B1', color="black", size=15)
ax19a.text(0.25, 0.1, '\u03B2', color="black", size=15)
ax19a.text(0.2, 0.65, '\u03B1-\u03B2', color="black", size=15)
ax19a.text(-1.4, 0.9, 'P(cos(\u03B1),sin(\u03B1))', color="black", size=15)
ax19a.text(0.8, 0.7, 'Q(cos(\u03B2),sin(\u03B2))', color="black", size=15)

path1 = matplotlib.path.Path(np.array([np.array([0.25*np.cos(theta), 0.25*np.sin(theta)]) for theta in np.linspace(0, np.pi/4, 100)]), codes=None, _interpolation_steps=1, closed=False, readonly=False)
path2 = matplotlib.path.Path(np.array([np.array([0.5*np.cos(theta), 0.5*np.sin(theta)]) for theta in np.linspace(0, 2*np.pi/3, 100)]), codes=None, _interpolation_steps=1, closed=False, readonly=False)
path3 = matplotlib.path.Path(np.array([np.array([0.65*np.cos(theta), 0.65*np.sin(theta)]) for theta in np.linspace(np.pi/4, 2*np.pi/3, 100)]), codes=None, _interpolation_steps=1, closed=False, readonly=False)
arc1 = patches.FancyArrowPatch(path=path1, connectionstyle="arc3,rad=0.5", arrowstyle="-|>, head_width=2, head_length=2", color="k")
arc2 = patches.FancyArrowPatch(path=path2, connectionstyle="arc3,rad=0.5", arrowstyle="-|>, head_width=2, head_length=2", color="k")
arc3 = patches.FancyArrowPatch(path=path3, connectionstyle="arc3,rad=0.5", arrowstyle="-|>, head_width=2, head_length=2", color="k")

ax19a.add_patch(arc1)
ax19a.add_patch(arc2)
ax19a.add_patch(arc3)
ax19a.text(1.35, -0.2, 'x', color="black", size=15)
ax19a.text(0.1, 1.35, 'y', color="black", size=15)
fig19a.savefig("fig_trans_19a.pdf",bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_trans_19b

# %%
fig19b = plt.figure(figsize=(8,4))
ax19b = fig19b.add_axes([0,0,1,1])
ax19b.set_xlim(-1.25, 1.25)
ax19b.set_ylim(-0.05, 1.25)

ax19b.set_yticks([])
ax19b.set_xticks([])
for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax19b.spines[direction].set_visible(False)
    if direction in ["left", "bottom"]:
        ax19b.spines[direction].set_visible(False)

ax19b.arrow(-1.25, 0, 2.6, 0., fc='k', ec='k', lw = .5, head_width=0.1, head_length=0.1, overhang = 0.3, length_includes_head= False, clip_on = False)
ax19b.arrow(0, -0.05, 0, 1.35, fc='k', ec='k', lw = .5, head_width=0.1, head_length=0.1, overhang = 0.3, length_includes_head= False, clip_on = False)

ax19b.plot([np.cos(theta) for theta in np.linspace(0, np.pi, 100)], [np.sin(theta) for theta in np.linspace(0, np.pi, 100)], color='grey')

ax19b.arrow(0, 0, 1.35*np.cos(75*np.pi/180), 1.35*np.sin(75*np.pi/180), fc='k', ec='k', lw = 1.5, head_width=0.1, head_length=0.1, overhang = 0.3, length_includes_head= False, clip_on = False)
ax19b.plot([np.cos(75*np.pi/180), 1], [np.sin(75*np.pi/180), 0], color='black', ls='--', marker='o')
ax19b.scatter([0], [0], color='black')

ax19b.text(1, -0.2, '1', color="black", size=15)
ax19b.text(0.05, 1.05, '1', color="black", size=15)
ax19b.text(-0.1, -0.1, '0', color="black", size=15)
ax19b.text(0.3, 0.2, '\u03B1-\u03B2', color="black", size=15)
ax19b.text(0.3, 1, 'A(cos(\u03B1-\u03B2),sin(\u03B1-\u03B2))', color="black", size=15)

path = matplotlib.path.Path(np.array([np.array([0.25*np.cos(theta), 0.25*np.sin(theta)]) for theta in np.linspace(0, 75*np.pi/180, 100)]), codes=None, _interpolation_steps=1, closed=False, readonly=False)
arc = patches.FancyArrowPatch(path=path, connectionstyle="arc3,rad=0.5", arrowstyle="-|>, head_width=2, head_length=2", color="k")
ax19b.add_patch(arc)
ax19b.text(1.35, -0.2, 'x', color="black", size=15)
ax19b.text(0.1, 1.35, 'y', color="black", size=15)
fig19b.savefig("fig_trans_19b.pdf",bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_trans_20

# %%
fig20 = plt.figure(figsize=(8,4))
ax20 = fig20.add_axes([0,0,1,1])
ax20.set_xlim(-0.2, 1)
ax20.set_ylim(-0.2, 0.5)

ax20.set_yticks([])
ax20.set_xticks([])
for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax20.spines[direction].set_visible(False)
    if direction in ["left", "bottom"]:
        ax20.spines[direction].set_visible(False)

ax20.plot([0, np.cos(0.523598776), np.cos(0.523598776), 0], [0, np.sin(0.523598776), 0, 0], color="black")
ax20.plot([0.3660264038, 0.8660264038, 0.8660264038, 0.3660264038], [0, 0, 0.5, 0], color="black")

ax20.text(0.15, 0.04, '30$^{\circ}$', color="black", size=15)
ax20.text(0.55, 0.05, '45$^{\circ}$', color="black", size=15)
ax20.text(0.65, -0.15, 'x', color="black", size=15)
ax20.text(0.9, 0.2, 'y', color="black", size=15)
ax20.text(0.5, 0.35, 'c', color="black", size=15)
ax20.text(-0.05, -0.05, 'P', color="black", size=15)
ax20.text(0.85, -0.05, 'C', color="black", size=15)
ax20.text(0.35, -0.05, 'Q', color="black", size=15)
ax20.text(0.8, 0.55, 'schiermonnikoog', color="black", size=15)
ax20.text(0.6, 0.3, '\u03B2$_1$', color="black", size=15)
ax20.text(0.8, 0.3, '\u03B2$_2$', color="black", size=15)
ax20.text(0.4, 0.15, '\u03B3', color="black", size=15)

path1 = matplotlib.path.Path(np.array([np.array([0.15*np.cos(theta), 0.15*np.sin(theta)]) for theta in np.linspace(0, 0.523598776, 100)]), codes=None, _interpolation_steps=1, closed=False, readonly=False)
arc1 = patches.FancyArrowPatch(path=path1, connectionstyle="arc3,rad=0.5", arrowstyle="<|-|>, head_width=2, head_length=2", color="k")
path2 = matplotlib.path.Path(np.array([np.array([0.3660264038+0.15*np.cos(theta), 0.15*np.sin(theta)]) for theta in np.linspace(0, 0.785398163, 100)]), codes=None, _interpolation_steps=1, closed=False, readonly=False)
arc2 = patches.FancyArrowPatch(path=path2, connectionstyle="arc3,rad=0.5", arrowstyle="<|-|>, head_width=2, head_length=2", color="k")
path3 = matplotlib.path.Path(np.array([np.array([0.4-0.1*np.cos(theta), 0.1*np.sin(theta)]) for theta in np.linspace(0, 2, 100)]), codes=None, _interpolation_steps=1, closed=False, readonly=False)
arc3 = patches.FancyArrowPatch(path=path3, connectionstyle="arc3,rad=0.5", arrowstyle="<|-|>, head_width=2, head_length=2", color="k")
path4 = matplotlib.path.Path(np.array([np.array([0.915-0.1*np.cos(2*theta), 0.45-0.1*np.sin(2*theta)]) for theta in np.linspace(0, 0.16*np.pi, 100)]), codes=None, _interpolation_steps=1, closed=False, readonly=False)
arc4 = patches.FancyArrowPatch(path=path4, connectionstyle="arc3,rad=0.5", arrowstyle="<|-|>, head_width=2, head_length=2", color="k")
path5 = matplotlib.path.Path(np.array([np.array([0.75-0.1*np.cos(2*theta), 0.37-0.1*np.sin(2*theta)]) for theta in np.linspace(0, 0.1*np.pi, 100)]), codes=None, _interpolation_steps=1, closed=False, readonly=False)
arc5 = patches.FancyArrowPatch(path=path5, connectionstyle="arc3,rad=0.5", arrowstyle="<|-|>, head_width=2, head_length=2", color="k")
arc6 = patches.FancyArrowPatch((0.35, -0.08), (0.85, -0.08), arrowstyle="<|-|>, head_width=2, head_length=2", color="k")

ax20.add_patch(arc1)
ax20.add_patch(arc2)
ax20.add_patch(arc3)
ax20.add_patch(arc4)
ax20.add_patch(arc5)
ax20.add_patch(arc6)
fig20.savefig("fig_trans_20.pdf",bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_trans_21a

# %%
fig21a = plt.figure(figsize=(6,4))
ax21a = fig21a.add_axes([0,0,1,1])
ax21a.set_xlim(-0.1, 2*np.pi+0.1)
ax21a.set_ylim(-1.1, 1.1)
ax21a.set_yticks([-1, 1])
ax21a.set_xticks([np.pi/4, np.pi/2, 3*np.pi/4, np.pi, 5*np.pi/4, 3*np.pi/2, 7*np.pi/4, 2*np.pi])
labels_x = [item.get_text() for item in ax21a.get_xticklabels()]
labels_x[0] = '\u03C0/4'
labels_x[1] = '\u03C0/2'
labels_x[2] = '3\u03C0/4'
labels_x[3] = '\u03C0'
labels_x[4] = '5\u03C0/4'
labels_x[5] = '3\u03C0/2'
labels_x[6] = '7\u03C0/4'
labels_x[7] = '2\u03C0'
ax21a.set_xticklabels(labels_x)
ax21a.text(-0.2, 0, '0', color="black", size=10)

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax21a.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax21a.spines[direction].set_position('zero')

ax21a.arrow(-0.1, 0, 2*np.pi+0.1, 0., fc='k', ec='k', lw = .5, head_width=0.1, head_length=0.2, overhang = 0.3, length_includes_head= False, clip_on = False)
ax21a.arrow(0, -1.1, 0, 2.3, fc='k', ec='k', lw = .5, head_width=0.2, head_length=0.1, overhang = 0.3, length_includes_head= False, clip_on = False)

x = np.linspace(0, 2*np.pi, 1000)
y = np.cos(x)
ax21a.plot(x, y, color="black")
ax21a.scatter(np.arange(0,2*np.pi+1,np.pi/4), [np.cos(theta) for theta in np.arange(0,2*np.pi+1,np.pi/4)], color='black')

ax21a.text(6.5, 0, 'x', color="black", size=15)
ax21a.text(0.2, 1.3, 'y', color="black", size=15)
fig21a.savefig("fig_trans_21a.pdf",bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_trans_21b

# %%
fig21b = plt.figure(figsize=(6,4))
ax21b = fig21b.add_axes([0,0,1,1])
ax21b.set_xlim(-0.1, 2*np.pi+0.1)
ax21b.set_ylim(-1.1, 1.1)
ax21b.set_yticks([-1, 1])
ax21b.set_xticks([np.pi/4, np.pi/2, 3*np.pi/4, np.pi, 5*np.pi/4, 3*np.pi/2, 7*np.pi/4, 2*np.pi])
labels_x = [item.get_text() for item in ax21b.get_xticklabels()]
labels_x[0] = '\u03C0/4'
labels_x[1] = '\u03C0/2'
labels_x[2] = '3\u03C0/4'
labels_x[3] = '\u03C0'
labels_x[4] = '5\u03C0/4'
labels_x[5] = '3\u03C0/2'
labels_x[6] = '7\u03C0/4'
labels_x[7] = '2\u03C0'
ax21b.set_xticklabels(labels_x)
ax21b.text(-0.2, 0, '0', color="black", size=10)

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax21b.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax21b.spines[direction].set_position('zero')

ax21b.arrow(-0.1, 0, 2*np.pi+0.1, 0., fc='k', ec='k', lw = .5, head_width=0.1, head_length=0.2, overhang = 0.3, length_includes_head= False, clip_on = False)
ax21b.arrow(0, -1.1, 0, 2.3, fc='k', ec='k', lw = .5, head_width=0.2, head_length=0.1, overhang = 0.3, length_includes_head= False, clip_on = False)

x = np.linspace(0, 2*np.pi, 1000)
y = np.sin(x)
ax21b.plot(x, y, color="black")
ax21b.scatter(np.arange(0,2*np.pi+1,np.pi/4), [np.sin(theta) for theta in np.arange(0,2*np.pi+1,np.pi/4)], color='black')

ax21b.text(6.5, 0, 'x', color="black", size=15)
ax21b.text(0.2, 1.3, 'y', color="black", size=15)
fig21b.savefig("fig_trans_21b.pdf",bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_trans_21c

# %%
fig21c = plt.figure(figsize=(8,4))
ax21c = fig21c.add_axes([0,0,1,1])
ax21c.set_xlim(-4*np.pi-0.1, 4*np.pi+0.1)
ax21c.set_ylim(-1.1, 1.1)
ax21c.set_yticks([-1, 1])
ax21c.set_xticks([-10, -5, 5, 10])
ax21c.text(-0.5, -0.1, '0', color="black", size=10)

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax21c.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax21c.spines[direction].set_position('zero')

ax21c.arrow(-4*np.pi, 0, 2*(4*np.pi+0.1), 0., fc='k', ec='k', lw = .5, head_width=0.1, head_length=0.6, overhang = 0.3, length_includes_head= False, clip_on = False)
ax21c.arrow(0, -1.1, 0, 2.3, fc='k', ec='k', lw = .5, head_width=0.4, head_length=0.1, overhang = 0.3, length_includes_head= False, clip_on = False)

x = np.linspace(-4*np.pi, 4*np.pi, 1000)
y = np.cos(x)
ax21c.plot(x, y, color="black")

ax21c.text(13.5, 0, 'x', color="black", size=15)
ax21c.text(0.2, 1.3, 'y', color="black", size=15)
fig21c.savefig("fig_trans_21c.pdf",bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_trans_21d

# %%
fig21d = plt.figure(figsize=(8,4))
ax21d = fig21d.add_axes([0,0,1,1])
ax21d.set_xlim(-4*np.pi-0.1, 4*np.pi+0.1)
ax21d.set_ylim(-1.1, 1.1)
ax21d.set_yticks([-1, 1])
ax21d.set_xticks([-10, -5, 5, 10])
ax21d.text(-0.5, -0.1, '0', color="black", size=10)

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax21d.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax21d.spines[direction].set_position('zero')

ax21d.arrow(-4*np.pi, 0, 2*(4*np.pi)+0.1, 0., fc='k', ec='k', lw = .5, head_width=0.1, head_length=0.3, overhang = 0.3, length_includes_head= False, clip_on = False)
ax21d.arrow(0, -1.1, 0, 2.3, fc='k', ec='k', lw = .5, head_width=0.4, head_length=0.1, overhang = 0.3, length_includes_head= False, clip_on = False)

x = np.linspace(-4*np.pi, 4*np.pi, 1000)
y = np.sin(x)
ax21d.plot(x, y, color="black")

ax21d.text(13, 0, 'x', color="black", size=15)
ax21d.text(0.2, 1.3, 'y', color="black", size=15)
fig21d.savefig("fig_trans_21d.pdf",bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_trans_22a

# %%
fig22a = plt.figure(figsize=(6,4))
ax22a = fig22a.add_axes([0,0,1,1])
ax22a.set_xlim(0, 5.1)
ax22a.set_ylim(-2.1, 4.1)
ax22a.set_yticks([-2, -1, 1, 2, 3, 4])
ax22a.set_xticks([1, 2, 3, 4, 5])
ax22a.text(-0.2, 0, '0', color="black", size=10)

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax22a.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax22a.spines[direction].set_position('zero')

ax22a.arrow(0, 0, 5.1, 0., fc='k', ec='k', lw = .5, head_width=0.3, head_length=0.2, overhang = 0.3, length_includes_head= False, clip_on = False)
ax22a.arrow(0, -2.1, 0, 6.2, fc='k', ec='k', lw = .5, head_width=0.15, head_length=0.3, overhang = 0.3, length_includes_head= False, clip_on = False)

x = np.linspace(1, 5, 1000)
y = 3*np.cos((np.pi*x - np.pi)/2) + 1
ax22a.plot(x, y, color="black")
ax22a.scatter(np.arange(1,6), [3*np.cos((np.pi*theta - np.pi)/2) + 1 for theta in np.arange(1,6)], color='black')

ax22a.text(5.2, -0.4, 'x', color="black", size=15)
ax22a.text(0.2, 4.3, 'y', color="black", size=15)
fig22a.savefig("fig_trans_22a.pdf",bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_trans_22b

# %%
fig22b = plt.figure(figsize=(4,4))
ax22b = fig22b.add_axes([0,0,1,1])
ax22b.set_xlim(-np.pi/2-0.1, np.pi/2+0.1)
ax22b.set_ylim(0, 2.1)
ax22b.set_yticks([1, 2])
ax22b.set_xticks([-np.pi/2, -np.pi/4, 0, np.pi/4, np.pi/2])
labels_x = [item.get_text() for item in ax22b.get_xticklabels()]
labels_x[0] = '-\u03C0/2'
labels_x[1] = '-\u03C0/4'
labels_x[2] = '0'
labels_x[3] = '\u03C0/4'
labels_x[4] = '\u03C0/2'
ax22b.set_xticklabels(labels_x)

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax22b.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax22b.spines[direction].set_position('zero')

ax22b.arrow(-np.pi/2-0.1, 0, 2*(np.pi/2+0.1)+0.1, 0., fc='k', ec='k', lw = .5, head_width=0.1, head_length=0.2, overhang = 0.3, length_includes_head= False, clip_on = False)
ax22b.arrow(0, 0, 0, 2.2, fc='k', ec='k', lw = .5, head_width=0.15, head_length=0.1, overhang = 0.3, length_includes_head= False, clip_on = False)

x = np.linspace(-np.pi/2, np.pi/2, 1000)
y = 1/2*np.sin(np.pi - 2*x)+3/2
ax22b.plot(x, y, color="black")
ax22b.scatter(np.arange(-np.pi/2, np.pi/2+1, np.pi/4), [1/2*np.sin(np.pi-2*theta)+3/2 for theta in np.arange(-np.pi/2, np.pi/2+1, np.pi/4)], color='black')

ax22b.text(2, -0.4, 'x', color="black", size=15)
ax22b.text(0.1, 2.3, 'y', color="black", size=15)
fig22b.savefig("fig_trans_22b.pdf",bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_trans_23a

# %%
fig23a = plt.figure(figsize=(6,4))
ax23a = fig23a.add_axes([0,0,1,1])
ax23a.set_xlim(-0.1, 2*np.pi+0.1)
ax23a.set_ylim(-4, 4)
ax23a.set_yticks([-3, -2, -1, 1, 2, 3])
ax23a.set_xticks([np.pi/4, np.pi/2, 3*np.pi/4, np.pi, 5*np.pi/4, 3*np.pi/2, 7*np.pi/4, 2*np.pi])
labels_x = [item.get_text() for item in ax23a.get_xticklabels()]
labels_x[0] = '\u03C0/4'
labels_x[1] = '\u03C0/2'
labels_x[2] = '3\u03C0/4'
labels_x[3] = '\u03C0'
labels_x[4] = '5\u03C0/4'
labels_x[5] = '3\u03C0/2'
labels_x[6] = '7\u03C0/4'
labels_x[7] = '2\u03C0'
ax23a.set_xticklabels(labels_x)
ax23a.text(-0.2, 0, '0', color="black", size=10)

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax23a.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax23a.spines[direction].set_position('zero')

ax23a.arrow(-0.1, 0, 2*np.pi+0.1, 0., fc='k', ec='k', lw = .5, head_width=0.3, head_length=0.2, overhang = 0.3, length_includes_head= False, clip_on = False)
ax23a.arrow(0, -4, 0, 8.1, fc='k', ec='k', lw = .5, head_width=0.15, head_length=0.3, overhang = 0.3, length_includes_head= False, clip_on = False)

x = np.linspace(0, 2*np.pi, 1000)
x1 = np.linspace(0, np.pi/2, 1000)
x2 = np.linspace(np.pi/2+0.001, 3*np.pi/2, 1000)
x3 = np.linspace(3*np.pi/2+0.001, 2*np.pi, 1000)

ax23a.plot(x1, 1/np.cos(x1), color="black")
ax23a.plot(x2, 1/np.cos(x2), color="black")
ax23a.plot(x3, 1/np.cos(x3), color="black")
ax23a.plot(x, np.cos(x), color="black", ls='--')
ax23a.plot([np.pi/2, np.pi/2], [-4, 4], color="black", ls='--')
ax23a.plot([3*np.pi/2, 3*np.pi/2], [-4, 4], color="black", ls='--')
ax23a.scatter(np.arange(0,2*np.pi+1,np.pi/4), [1/np.cos(theta) for theta in np.arange(0,2*np.pi+1,np.pi/4)], color='black')

ax23a.text(6.5, 0, 'x', color="black", size=15)
ax23a.text(0.2, 4.3, 'y', color="black", size=15)
fig23a.savefig("fig_trans_23a.pdf",bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_trans_23b

# %%
fig23b = plt.figure(figsize=(6,4))
ax23b = fig23b.add_axes([0,0,1,1])
ax23b.set_xlim(-0.1, 2*np.pi+0.1)
ax23b.set_ylim(-4, 4)
ax23b.set_yticks([-3, -2, -1, 1, 2, 3])
ax23b.set_xticks([np.pi/4, np.pi/2, 3*np.pi/4, np.pi, 5*np.pi/4, 3*np.pi/2, 7*np.pi/4, 2*np.pi])
labels_x = [item.get_text() for item in ax23b.get_xticklabels()]
labels_x[0] = '\u03C0/4'
labels_x[1] = '\u03C0/2'
labels_x[2] = '3\u03C0/4'
labels_x[3] = '\u03C0'
labels_x[4] = '5\u03C0/4'
labels_x[5] = '3\u03C0/2'
labels_x[6] = '7\u03C0/4'
labels_x[7] = '2\u03C0'
ax23b.set_xticklabels(labels_x)
ax23b.text(-0.2, 0, '0', color="black", size=10)

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax23b.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax23b.spines[direction].set_position('zero')

ax23b.arrow(-0.1, 0, 2*np.pi+0.1, 0., fc='k', ec='k', lw = .5, head_width=0.3, head_length=0.2, overhang = 0.3, length_includes_head= False, clip_on = False)
ax23b.arrow(0, -4, 0, 8.1, fc='k', ec='k', lw = .5, head_width=0.15, head_length=0.3, overhang = 0.3, length_includes_head= False, clip_on = False)

x = np.linspace(0, 2*np.pi, 1000)
x1 = np.linspace(0.001, np.pi, 1000)
x2 = np.linspace(np.pi+0.001, 2*np.pi, 1000)

ax23b.plot(x1, 1/np.sin(x1), color="black")
ax23b.plot(x2, 1/np.sin(x2), color="black")
ax23b.plot(x, np.sin(x), color="black", ls='--')
ax23b.plot([np.pi, np.pi], [-4, 4], color="black", ls='--')
ax23b.plot([2*np.pi, 2*np.pi], [-4, 4], color="black", ls='--')
ax23b.scatter(np.arange(0,2*np.pi+1,np.pi/4), [1/np.sin(theta) for theta in np.arange(0,2*np.pi+1,np.pi/4)], color='black')

ax23b.text(6.5, 0, 'x', color="black", size=15)
ax23b.text(0.2, 4.3, 'y', color="black", size=15)
fig23b.savefig("fig_trans_23b.pdf",bbox_inches='tight')
plt.show()
# Out:
# <ipython-input-44-d9a9f9723fca>:37: RuntimeWarning: divide by zero encountered in double_scalars
#   ax23b.scatter(np.arange(0,2*np.pi+1,np.pi/4), [1/np.sin(theta) for theta in np.arange(0,2*np.pi+1,np.pi/4)], color='black')

# %% [markdown]
# ### fig_trans_23c

# %%
fig23c = plt.figure(figsize=(8,4))
ax23c = fig23c.add_axes([0,0,1,1])
ax23c.set_xlim(-4*np.pi-0.1, 4*np.pi+0.1)
ax23c.set_ylim(-3, 3)
ax23c.set_yticks([-2, -1, 1, 2])
ax23c.set_xticks([-10, -5, 5, 10])
ax23c.text(-0.5, -0.3, '0', color="black", size=10)

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax23c.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax23c.spines[direction].set_position('zero')

ax23c.arrow(-4*np.pi, 0, 2*(4*np.pi)+0.1, 0., fc='k', ec='k', lw = .5, head_width=0.2, head_length=0.4, overhang = 0.3, length_includes_head= False, clip_on = False)
ax23c.arrow(0, -3, 0, 6.1, fc='k', ec='k', lw = .5, head_width=0.4, head_length=0.2, overhang = 0.4, length_includes_head= False, clip_on = False)

for i in [j for j in np.arange(-4*np.pi, 4*np.pi+1, np.pi/2)]:
    x = np.linspace(i+0.001, i+np.pi/2-0.001, 100)
    ax23c.plot(x, 1/np.cos(x), color="black")

x = np.linspace(-4*np.pi, 4*np.pi, 100)
ax23c.plot(x, np.cos(x), color="black", ls='--')

ax23c.text(13.5, 0, 'x', color="black", size=15)
ax23c.text(0.2, 3.3, 'y', color="black", size=15)
fig23c.savefig("fig_trans_23c.pdf",bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_trans_23d

# %%
fig23d = plt.figure(figsize=(8,4))
ax23d = fig23d.add_axes([0,0,1,1])
ax23d.set_xlim(-4*np.pi-0.1, 4*np.pi+0.1)
ax23d.set_ylim(-3, 3)
ax23d.set_yticks([-2, -1, 1, 2])
ax23d.set_xticks([-10, -5, 5, 10])
ax23d.text(-0.5, -0.3, '0', color="black", size=10)

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax23d.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax23d.spines[direction].set_position('zero')

ax23d.arrow(-4*np.pi, 0, 2*(4*np.pi)+0.1, 0., fc='k', ec='k', lw = .5, head_width=0.2, head_length=0.4, overhang = 0.3, length_includes_head= False, clip_on = False)
ax23d.arrow(0, -3, 0, 6.1, fc='k', ec='k', lw = .5, head_width=0.4, head_length=0.2, overhang = 0.4, length_includes_head= False, clip_on = False)

for i in [j for j in np.arange(-4*np.pi, 4*np.pi+1, np.pi)]:
    x = np.linspace(i+0.001, i+np.pi-0.001, 100)
    ax23d.plot(x, 1/np.sin(x), color="black")

x = np.linspace(-4*np.pi, 4*np.pi, 100)
ax23d.plot(x, np.sin(x), color="black", ls='--')

ax23d.text(13.5, 0, 'x', color="black", size=15)
ax23d.text(0.2, 3.3, 'y', color="black", size=15)
fig23d.savefig("fig_trans_23d.pdf",bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_trans_24a

# %%
fig24a = plt.figure(figsize=(4,4))
ax24a = fig24a.add_axes([0,0,1,1])
ax24a.set_xlim(-np.pi/2-0.1, np.pi/2+0.1)
ax24a.set_ylim(-4, 4)
ax24a.set_yticks([-1, 1])
ax24a.set_xticks([-np.pi/2, -np.pi/4, np.pi/4, np.pi/2])
labels_x = [item.get_text() for item in ax24a.get_xticklabels()]
labels_x[0] = '-\u03C0/2'
labels_x[1] = '-\u03C0/4'
labels_x[2] = '\u03C0/4'
labels_x[3] = '\u03C0/2'
ax24a.set_xticklabels(labels_x)
ax24a.text(-0.1, 0.1, '0', color="black", size=10)

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax24a.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax24a.spines[direction].set_position('zero')

ax24a.arrow(-np.pi/2, 0, np.pi+0.1, 0., fc='k', ec='k', lw = .5, head_width=0.3, head_length=0.1, overhang = 0.3, length_includes_head= False, clip_on = False)
ax24a.arrow(0, -4, 0, 8.1, fc='k', ec='k', lw = .5, head_width=0.1, head_length=0.3, overhang = 0.3, length_includes_head= False, clip_on = False)

x = np.linspace(-np.pi/2+0.001, np.pi/2, 1000)
ax24a.plot(x, np.tan(x), color="black")
ax24a.plot([np.pi/2, np.pi/2], [-4, 4], color="black", ls='--')
ax24a.plot([-np.pi/2, -np.pi/2], [-4, 4], color="black", ls='--')
ax24a.scatter(np.arange(-np.pi/4,np.pi/4+1,np.pi/4), [np.tan(theta) for theta in np.arange(-np.pi/4,np.pi/4+1,np.pi/4)], color='black')

ax24a.text(1.8, 0, 'x', color="black", size=15)
ax24a.text(0.1, 4.3, 'y', color="black", size=15)
fig24a.savefig("fig_trans_24a.pdf",bbox_inches='tight')
fig24a.savefig("fig_trans_31a.pdf",bbox_inches='tight')
fig24a.savefig("fig_trans_35a.pdf",bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_trans_24b

# %%
fig24b = plt.figure(figsize=(4,4))
ax24b = fig24b.add_axes([0,0,1,1])
ax24b.set_xlim(0, np.pi+0.1)
ax24b.set_ylim(-4, 4)
ax24b.set_yticks([-1, 1])
ax24b.set_xticks([np.pi/4, np.pi/2, 3*np.pi/4, np.pi])
labels_x = [item.get_text() for item in ax24b.get_xticklabels()]
labels_x[0] = '\u03C0/4'
labels_x[1] = '\u03C0/2'
labels_x[2] = '3\u03C0/4'
labels_x[3] = '\u03C0'
ax24b.set_xticklabels(labels_x)
ax24b.text(-0.1, 0.1, '0', color="black", size=10)

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax24b.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax24b.spines[direction].set_position('zero')

ax24b.arrow(0, 0, np.pi+0.1, 0., fc='k', ec='k', lw = .5, head_width=0.3, head_length=0.1, overhang = 0.3, length_includes_head= False, clip_on = False)
ax24b.arrow(0, -4, 0, 8.1, fc='k', ec='k', lw = .5, head_width=0.1, head_length=0.3, overhang = 0.3, length_includes_head= False, clip_on = False)

x = np.linspace(0.001, np.pi, 1000)
ax24b.plot(x, 1/np.tan(x), color="black")
ax24b.plot([np.pi, np.pi], [-4, 4], color="black", ls='--')
ax24b.scatter(np.arange(np.pi/4,3*np.pi/4+1,np.pi/4), [1/np.tan(theta) for theta in np.arange(np.pi/4,3*np.pi/4+1,np.pi/4)], color='black')

ax24b.text(3.4, 0, 'x', color="black", size=15)
ax24b.text(0.1, 4.3, 'y', color="black", size=15)
fig24b.savefig("fig_trans_24b.pdf",bbox_inches='tight')
fig24b.savefig("fig_trans_32a.pdf",bbox_inches='tight')
fig24b.savefig("fig_trans_36a.pdf",bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_trans_24c

# %%
fig24c = plt.figure(figsize=(8,4))
ax24c = fig24c.add_axes([0,0,1,1])
ax24c.set_xlim(-4*np.pi-0.1, 4*np.pi+0.1)
ax24c.set_ylim(-3, 3)
ax24c.set_yticks([-2, -1, 1, 2])
ax24c.set_xticks([-10, -5, 5, 10])
ax24c.text(-0.5, -0.3, '0', color="black", size=10)

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax24c.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax24c.spines[direction].set_position('zero')

ax24c.arrow(-4*np.pi, 0, 2*(4*np.pi)+0.1, 0., fc='k', ec='k', lw = .5, head_width=0.2, head_length=0.4, overhang = 0.3, length_includes_head= False, clip_on = False)
ax24c.arrow(0, -3, 0, 6.1, fc='k', ec='k', lw = .5, head_width=0.4, head_length=0.2, overhang = 0.4, length_includes_head= False, clip_on = False)

for i in [j for j in np.arange(-4*np.pi, 4*np.pi+1, np.pi/2)]:
    x = np.linspace(i+0.001, i+np.pi/2-0.001, 100)
    ax24c.plot(x, np.tan(x), color="black")

ax24c.text(13.5, 0, 'x', color="black", size=15)
ax24c.text(0.2, 3.3, 'y', color="black", size=15)
fig24c.savefig("fig_trans_24c.pdf",bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_trans_24d

# %%
fig24d = plt.figure(figsize=(8,4))
ax24d = fig24d.add_axes([0,0,1,1])
ax24d.set_xlim(-4*np.pi-0.1, 4*np.pi+0.1)
ax24d.set_ylim(-3, 3)
ax24d.set_yticks([-2, -1, 1, 2])
ax24d.set_xticks([-10, -5, 5, 10])
ax24d.text(-0.5, -0.3, '0', color="black", size=10)

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax24d.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax24d.spines[direction].set_position('zero')

ax24d.arrow(-4*np.pi, 0, 2*(4*np.pi)+0.1, 0., fc='k', ec='k', lw = .5, head_width=0.2, head_length=0.4, overhang = 0.3, length_includes_head= False, clip_on = False)
ax24d.arrow(0, -3, 0, 6.1, fc='k', ec='k', lw = .5, head_width=0.4, head_length=0.2, overhang = 0.4, length_includes_head= False, clip_on = False)

for i in [j for j in np.arange(-4*np.pi, 4*np.pi+1, np.pi)]:
    x = np.linspace(i+0.001, i+np.pi-0.001, 100)
    ax24d.plot(x, 1/np.tan(x), color="black")

ax24d.text(13.5, 0, 'x', color="black", size=15)
ax24d.text(0.2, 3.3, 'y', color="black", size=15)
fig24d.savefig("fig_trans_24d.pdf",bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_trans_25a

# %%
fig25a = plt.figure(figsize=(6,4))
ax25a = fig25a.add_axes([0,0,1,1])
ax25a.set_xlim(-0.1, np.pi+0.1)
ax25a.set_ylim(-4, 6)
ax25a.set_yticks([-3, -2, -1, 1, 2, 3, 4, 5])
ax25a.set_xticks([np.pi/4, np.pi/2, 3*np.pi/4, np.pi])
labels_x = [item.get_text() for item in ax25a.get_xticklabels()]
labels_x[0] = '\u03C0/4'
labels_x[1] = '\u03C0/2'
labels_x[2] = '3\u03C0/4'
labels_x[3] = '\u03C0'
ax25a.set_xticklabels(labels_x)
ax25a.text(-0.2, 0, '0', color="black", size=10)

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax25a.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax25a.spines[direction].set_position('zero')

ax25a.arrow(-0.1, 0, np.pi+0.1, 0., fc='k', ec='k', lw = .5, head_width=0.4, head_length=0.1, overhang = 0.3, length_includes_head= False, clip_on = False)
ax25a.arrow(0, -4, 0, 10.1, fc='k', ec='k', lw = .5, head_width=0.1, head_length=0.4, overhang = 0.3, length_includes_head= False, clip_on = False)

x = np.linspace(0, np.pi, 1000)
x1 = np.linspace(0, np.pi/4, 1000)
x2 = np.linspace(np.pi/4+0.001, 3*np.pi/4, 1000)
x3 = np.linspace(3*np.pi/4+0.001, np.pi, 1000)

ax25a.plot(x1, 1 - 2/np.cos(2*x1), color="black")
ax25a.plot(x2, 1 - 2/np.cos(2*x2), color="black")
ax25a.plot(x3, 1 - 2/np.cos(2*x3), color="black")
ax25a.plot(x, 1 - 2*np.cos(2*x), color="black", ls='--')
ax25a.plot([np.pi/4, np.pi/4], [-4, 6], color="black", ls='--')
ax25a.plot([3*np.pi/4, 3*np.pi/4], [-4, 6], color="black", ls='--')
ax25a.scatter(np.arange(0,np.pi+1,np.pi/2), [1 - 2*np.cos(2*theta) for theta in np.arange(0,np.pi+1,np.pi/2)], color='black')

ax25a.text(3.4, 0, 'x', color="black", size=15)
ax25a.text(0.2, 6.1, 'y', color="black", size=15)
fig25a.savefig("fig_trans_25a.pdf",bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_trans_25b

# %%
fig25b = plt.figure(figsize=(6,6))
ax25b = fig25b.add_axes([0,0,1,1])
ax25b.set_xlim(-2.1, 0)
ax25b.set_ylim(-3, 4)
ax25b.set_yticks([-1, 1, 2, 3])
ax25b.set_xticks([-2, -1])
ax25b.text(0.02, 0.1, '0', color="black", size=10)

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax25b.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax25b.spines[direction].set_position('zero')

ax25b.arrow(-2.1, 0, 2.2, 0., fc='k', ec='k', lw = .5, head_width=0.2, head_length=0.1, overhang = 0.3, length_includes_head= False, clip_on = False)
ax25b.arrow(0, -3, 0, 7.1, fc='k', ec='k', lw = .5, head_width=0.075, head_length=0.25, overhang = 0.3, length_includes_head= False, clip_on = False)

x = np.linspace(-1.999, 0, 1000)
ax25b.plot(x, 2/np.tan(np.pi/2*x + np.pi) + 1, color="black")
ax25b.plot([-2, -2], [-3, 4], color="black", ls='--')
ax25b.plot([3*np.pi/4, 3*np.pi/4], [-4, 6], color="black", ls='--')
ax25b.scatter([-1, -3/2, -1/2], [1, 3, -1], color='black')

ax25b.text(0.21, 0, 'x', color="black", size=15)
ax25b.text(0.1, 4.1, 'y', color="black", size=15)
fig25b.savefig("fig_trans_25b.pdf",bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_trans_27

# %%
fig27 = plt.figure(figsize=(6,4))
ax27 = fig27.add_axes([0,0,1,1])
ax27.set_xlim(0, 13)
ax27.set_ylim(0, 23)
ax27.set_yticks([5, 10, 15, 20])
ax27.set_xticks([0, 2, 4, 6, 8, 10, 12])

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax27.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax27.spines[direction].set_position('zero')

ax27.arrow(0, 0, 13.1, 0., fc='k', ec='k', lw = .5, head_width=0.6, head_length=0.3, overhang = 0.3, length_includes_head= False, clip_on = False)
ax27.arrow(0, 0, 0, 23.1, fc='k', ec='k', lw = .5, head_width=0.3, head_length=0.6, overhang = 0.3, length_includes_head= False, clip_on = False)

ax27.scatter([np.arange(1, 13, 1)], [5.8, 9.3, 12.4, 15.9, 19.4, 21.8, 19.4, 15.6, 12.4, 9.1, 5.6, 3.3], color='black')

ax27.text(13.2, -1.5, 't (months)', color="black", size=15)
ax27.text(0.3, 23.1, 'H (hours)', color="black", size=15)
fig27.savefig("fig_trans_27.pdf",bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_trans_28

# %%
fig28 = plt.figure(figsize=(6,4))
ax28 = fig28.add_axes([0,0,1,1])
ax28.set_xlim(0, 13)
ax28.set_ylim(0, 23)
ax28.set_yticks([5, 10, 15, 20])
ax28.set_xticks([0, 2, 4, 6, 8, 10, 12])

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax28.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax28.spines[direction].set_position('zero')

ax28.arrow(0, 0, 13.1, 0., fc='k', ec='k', lw = .5, head_width=0.6, head_length=0.3, overhang = 0.3, length_includes_head= False, clip_on = False)
ax28.arrow(0, 0, 0, 23.1, fc='k', ec='k', lw = .5, head_width=0.3, head_length=0.6, overhang = 0.3, length_includes_head= False, clip_on = False)

x = np.linspace(0, 12, 100)
ax28.plot(x, 9.25*np.sin(np.pi/6*x - np.pi/2) + 12.55, color='black')
ax28.scatter([np.arange(1, 13, 1)], [5.8, 9.3, 12.4, 15.9, 19.4, 21.8, 19.4, 15.6, 12.4, 9.1, 5.6, 3.3], color='black')

ax28.text(13.2, -1.5, 't (months)', color="black", size=15)
ax28.text(0.3, 23.1, 'H (hours)', color="black", size=15)
fig28.savefig("fig_trans_28.pdf",bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Inverse goniometrische functies

# %% [markdown]
# ### fig_trans_29

# %%
fig29 = plt.figure(figsize=(6,6))
ax29 = fig29.add_axes([0,0,1,1])
ax29.set_xlim(-1.1, 4)
ax29.set_ylim(-1.1, 4)
ax29.set_yticks([-1, 1, np.pi/2, np.pi])
ax29.set_xticks([-1, 1, np.pi/2, np.pi])
ax29.text(0.02, 0.1, '0', color="black", size=10)
labels_x = [item.get_text() for item in ax29.get_xticklabels()]
labels_x[0] = '-1'
labels_x[1] = '1'
labels_x[2] = '\u03C0/2'
labels_x[3] = '\u03C0'
ax29.set_xticklabels(labels_x)
labels_y = [item.get_text() for item in ax29.get_yticklabels()]
labels_y[0] = '-1'
labels_y[1] = '1'
labels_y[2] = '\u03C0/2'
labels_y[3] = '\u03C0'
ax29.set_yticklabels(labels_y)

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax29.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax29.spines[direction].set_position('zero')

ax29.arrow(-1.1, 0, 5.2, 0., fc='k', ec='k', lw = .5, head_width=0.15, head_length=0.15, overhang = 0.3, length_includes_head= False, clip_on = False)
ax29.arrow(0, -1.1, 0, 5.2, fc='k', ec='k', lw = .5, head_width=0.15, head_length=0.15, overhang = 0.3, length_includes_head= False, clip_on = False)

x1 = np.linspace(0, np.pi, 1000)
x2 = np.linspace(-1, 1, 1000)
ax29.plot(x1, np.cos(x1), color="grey", ls='--')
ax29.plot(x2, np.arccos(x2), color="black")
ax29.plot(np.linspace(-1.1, 4, 1000), np.linspace(-1.1, 4, 1000), color='black', ls=':')
ax29.scatter([-1, 0, 1], [np.pi, np.pi/2, 0], color='black')
ax29.scatter([0, np.pi/2, np.pi], [1, 0, -1], color='grey', zorder=10)

ax29.text(4.4, 0, 'x', color="black", size=15)
ax29.text(0.1, 4.1, 'y', color="black", size=15)
fig29.savefig("fig_trans_29.pdf",bbox_inches='tight')
fig29.savefig("fig_trans_33.pdf",bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_trans_29a

# %%
fig29a = plt.figure(figsize=(8,4))
ax29a = fig29a.add_axes([0,0,1,1])
ax29a.set_xlim(-4*np.pi-0.1, 4*np.pi+0.1)
ax29a.set_ylim(-4, 3)
ax29a.set_yticks([-4, -2, 2])
ax29a.set_xticks([-4*np.pi, -3*np.pi, -2*np.pi, -np.pi, np.pi, 2*np.pi, 3*np.pi, 4*np.pi])
ax29a.text(-0.5, -0.3, '0', color="black", size=10)
labels_x = [item.get_text() for item in ax29a.get_xticklabels()]
labels_x[0] = '-4\u03C0'
labels_x[1] = '-3\u03C0'
labels_x[2] = '-2\u03C0'
labels_x[3] = '-\u03C0'
labels_x[4] = '\u03C0'
labels_x[5] = '2\u03C0'
labels_x[6] = '3\u03C0'
labels_x[7] = '4\u03C0'
ax29a.set_xticklabels(labels_x)

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax29a.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax29a.spines[direction].set_position('zero')

ax29a.arrow(-4*np.pi, 0, 2*(4*np.pi)+0.1, 0., fc='k', ec='k', lw = .5, head_width=0.2, head_length=0.4, overhang = 0.3, length_includes_head= False, clip_on = False)
ax29a.arrow(0, -4, 0, 7.1, fc='k', ec='k', lw = .5, head_width=0.4, head_length=0.2, overhang = 0.4, length_includes_head= False, clip_on = False)

for i in [j for j in np.arange(-4*np.pi, 4*np.pi+1, np.pi/2)]:
    x = np.linspace(i+0.001, i+np.pi/2-0.001, 100)
    ax29a.plot(x, 1/np.cos(x), color="black")

for i in [j for j in np.arange(0, 3*np.pi/2+1, np.pi/2)]:
    x = np.linspace(i+0.001, i+np.pi/2-0.001, 100)
    ax29a.plot(x, 1/np.cos(x), color="black", lw=3)

x = np.linspace(-4*np.pi, 4*np.pi, 100)
ax29a.plot(x, np.cos(x), color="black", ls='--')
ax29a.scatter([0, np.pi, 2*np.pi], [1, -1, 1], color="black")

ax29a.text(13.5, 0, 'x', color="black", size=15)
ax29a.text(0.2, 3.3, 'y', color="black", size=15)
fig29a.savefig("fig_trans_29a.pdf",bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_trans_29b

# %%
fig29b = plt.figure(figsize=(8,4))
ax29b = fig29b.add_axes([0,0,1,1])
ax29b.set_xlim(-4*np.pi-0.1, 4*np.pi+0.1)
ax29b.set_ylim(-4, 3)
ax29b.set_yticks([-4, -2, 2])
ax29b.set_xticks([-4*np.pi, -3*np.pi, -2*np.pi, -np.pi, np.pi, 2*np.pi, 3*np.pi, 4*np.pi])
ax29b.text(-0.5, -0.3, '0', color="black", size=10)
labels_x = [item.get_text() for item in ax29b.get_xticklabels()]
labels_x[0] = '-4\u03C0'
labels_x[1] = '-3\u03C0'
labels_x[2] = '-2\u03C0'
labels_x[3] = '-\u03C0'
labels_x[4] = '\u03C0'
labels_x[5] = '2\u03C0'
labels_x[6] = '3\u03C0'
labels_x[7] = '4\u03C0'
ax29b.set_xticklabels(labels_x)

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax29b.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax29b.spines[direction].set_position('zero')

ax29b.arrow(-4*np.pi, 0, 2*(4*np.pi)+0.1, 0., fc='k', ec='k', lw = .5, head_width=0.2, head_length=0.4, overhang = 0.3, length_includes_head= False, clip_on = False)
ax29b.arrow(0, -4, 0, 7.1, fc='k', ec='k', lw = .5, head_width=0.4, head_length=0.2, overhang = 0.4, length_includes_head= False, clip_on = False)

for i in [j for j in np.arange(-4*np.pi, 4*np.pi+1, np.pi)]:
    x = np.linspace(i+0.001, i+np.pi-0.001, 100)
    ax29b.plot(x, 1/np.sin(x), color="black")
for i in [j for j in np.arange(0, 3*np.pi/2+1, np.pi/2)]:
    x = np.linspace(i+0.001, i+np.pi/2-0.001, 100)
    ax29b.plot(x, 1/np.sin(x), color="black", lw=3)

x = np.linspace(-4*np.pi, 4*np.pi, 100)
ax29b.plot(x, np.sin(x), color="black", ls='--')
ax29b.scatter([np.pi/2, 3*np.pi/2], [1, -1], color="black")

ax29b.text(13.5, 0, 'x', color="black", size=15)
ax29b.text(0.2, 3.3, 'y', color="black", size=15)
fig29b.savefig("fig_trans_29b.pdf",bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_trans_30

# %%
fig30 = plt.figure(figsize=(6,6))
ax30 = fig30.add_axes([0,0,1,1])
ax30.set_xlim(-np.pi/2-0.1, np.pi/2+0.1)
ax30.set_ylim(-np.pi/2-0.1, np.pi/2+0.1)
ax30.set_yticks([-np.pi/2, -1, 1, np.pi/2])
ax30.set_xticks([-np.pi/2, -1, 1, np.pi/2])
ax30.text(0.02, 0.1, '0', color="black", size=10)
labels_x = [item.get_text() for item in ax30.get_xticklabels()]
labels_x[0] = '-\u03C0/2'
labels_x[1] = '-1'
labels_x[2] = '1'
labels_x[3] = '\u03C0/2'
ax30.set_xticklabels(labels_x)
labels_y = [item.get_text() for item in ax30.get_yticklabels()]
labels_y[0] = '-\u03C0/2'
labels_y[1] = '-1'
labels_y[2] = '1'
labels_y[3] = '\u03C0/2'
ax30.set_yticklabels(labels_y)

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax30.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax30.spines[direction].set_position('zero')

ax30.arrow(-np.pi/2-0.1, 0, np.pi+0.2, 0., fc='k', ec='k', lw = .5, head_width=0.1, head_length=0.1, overhang = 0.3, length_includes_head= False, clip_on = False)
ax30.arrow(0, -np.pi/2-0.1, 0, np.pi+0.2, fc='k', ec='k', lw = .5, head_width=0.1, head_length=0.1, overhang = 0.3, length_includes_head= False, clip_on = False)

x1 = np.linspace(-np.pi/2, np.pi/2, 1000)
x2 = np.linspace(-1, 1, 1000)
ax30.plot(x1, np.sin(x1), color="grey", ls='--')
ax30.plot(x2, np.arcsin(x2), color="black")
ax30.plot(np.linspace(-1.1, 4, 1000), np.linspace(-1.1, 4, 1000), color='black', ls=':')
ax30.scatter([-1, 0, 1], [-np.pi/2, 0, np.pi/2], color='black', zorder=11)
ax30.scatter([-np.pi/2, 0, np.pi/2], [-1, 0, 1], color='grey', zorder=10)

ax30.text(1.8, 0, 'x', color="black", size=15)
ax30.text(0.1, 1.7, 'y', color="black", size=15)
fig30.savefig("fig_trans_30.pdf",bbox_inches='tight')
fig30.savefig("fig_trans_34.pdf",bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_trans_30a

# %%
fig30a = plt.figure(figsize=(6,6))
ax30a = fig30a.add_axes([0,0,1,1])
ax30a.set_xlim(-0.1, np.pi+0.1)
ax30a.set_ylim(-3, 3)
ax30a.set_yticks([-1, 1])
ax30a.set_xticks([np.pi/2, np.pi])
ax30a.text(0.02, 0.1, '0', color="black", size=10)
labels_x = [item.get_text() for item in ax30a.get_xticklabels()]
labels_x[0] = '\u03C0/2'
labels_x[1] = '\u03C0'
ax30a.set_xticklabels(labels_x)

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax30a.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax30a.spines[direction].set_position('zero')

ax30a.arrow(-0.1, 0, np.pi+0.1, 0., fc='k', ec='k', lw = .5, head_width=0.2, head_length=0.1, overhang = 0.3, length_includes_head= False, clip_on = False)
ax30a.arrow(0, -3, 0, 6.1, fc='k', ec='k', lw = .5, head_width=0.1, head_length=0.2, overhang = 0.3, length_includes_head= False, clip_on = False)

x1 = np.linspace(0, np.pi/2, 1000)
x2 = np.linspace(np.pi/2+0.001, np.pi, 1000)
ax30a.plot(x1, 1/np.cos(x1), color="black")
ax30a.plot(x2, 1/np.cos(x2), color="black")
ax30a.plot([np.pi/2, np.pi/2], [-3, 3], color='black', ls='--')
ax30a.scatter([0, np.pi], [1, -1], color='black')

ax30a.text(3.3, 0, 'x', color="black", size=15)
ax30a.text(0.1, 3.1, 'y', color="black", size=15)
fig30a.savefig("fig_trans_30a.pdf",bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_trans_30b

# %%
fig30b = plt.figure(figsize=(6,6))
ax30b = fig30b.add_axes([0,0,1,1])
ax30b.set_xlim(-3, 3)
ax30b.set_ylim(-0.1, np.pi+0.1)
ax30b.set_yticks([np.pi/2, np.pi])
ax30b.set_xticks([-1, 1])
ax30b.text(0.02, 0.1, '0', color="black", size=10)
labels_y = [item.get_text() for item in ax30b.get_yticklabels()]
labels_y[0] = '\u03C0/2'
labels_y[1] = '\u03C0'
ax30b.set_yticklabels(labels_y)

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax30b.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax30b.spines[direction].set_position('zero')

ax30b.arrow(-3, 0, 6.1, 0., fc='k', ec='k', lw = .5, head_width=0.1, head_length=0.2, overhang = 0.3, length_includes_head= False, clip_on = False)
ax30b.arrow(0, -0.1, 0, np.pi+0.1, fc='k', ec='k', lw = .5, head_width=0.2, head_length=0.1, overhang = 0.3, length_includes_head= False, clip_on = False)

x1 = np.linspace(-3, -1, 1000)
x2 = np.linspace(1, 3, 1000)
ax30b.plot(x1, np.arccos(1/x1), color="black")
ax30b.plot(x2, np.arccos(1/x2), color="black")
ax30b.plot([-3, 3], [np.pi/2, np.pi/2], color='black', ls='--')
ax30b.scatter([-1, 1], [np.pi, 0], color='black')

ax30b.text(3.3, 0, 'x', color="black", size=15)
ax30b.text(0.1, 3.3, 'y', color="black", size=15)
fig30b.savefig("fig_trans_30b.pdf",bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_trans_30c

# %%
fig30c = plt.figure(figsize=(6,6))
ax30c = fig30c.add_axes([0,0,1,1])
ax30c.set_xlim(-np.pi/2-0.1, np.pi/2+0.1)
ax30c.set_ylim(-3, 3)
ax30c.set_yticks([-1, 1])
ax30c.set_xticks([-np.pi/2, np.pi/2])
ax30c.text(0.02, 0.1, '0', color="black", size=10)
labels_x = [item.get_text() for item in ax30c.get_xticklabels()]
labels_x[0] = '-\u03C0/2'
labels_x[1] = '\u03C0/2'
ax30c.set_xticklabels(labels_x)

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax30c.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax30c.spines[direction].set_position('zero')

ax30c.arrow(-np.pi/2-0.1, 0, 2*(np.pi/2)+0.3, 0., fc='k', ec='k', lw = .5, head_width=0.2, head_length=0.1, overhang = 0.3, length_includes_head= False, clip_on = False)
ax30c.arrow(0, -3, 0, 6.1, fc='k', ec='k', lw = .5, head_width=0.1, head_length=0.2, overhang = 0.3, length_includes_head= False, clip_on = False)

x1 = np.linspace(-np.pi/2, -0.001, 1000)
x2 = np.linspace(0.001, np.pi/2, 1000)
ax30c.plot(x1, 1/np.sin(x1), color="black")
ax30c.plot(x2, 1/np.sin(x2), color="black")
ax30c.scatter([-np.pi/2, np.pi/2], [-1, 1], color='black')

ax30c.text(1.9, 0, 'x', color="black", size=15)
ax30c.text(0.1, 3.1, 'y', color="black", size=15)
fig30c.savefig("fig_trans_30c.pdf",bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_trans_30d

# %%
fig30d = plt.figure(figsize=(6,6))
ax30d = fig30d.add_axes([0,0,1,1])
ax30d.set_xlim(-3, 3)
ax30d.set_ylim(-np.pi/2-0.1, np.pi/2+0.1)
ax30d.set_yticks([-np.pi/2, np.pi/2])
ax30d.set_xticks([-1, 1])
ax30d.text(0.02, 0.05, '0', color="black", size=10)
labels_y = [item.get_text() for item in ax30d.get_yticklabels()]
labels_y[0] = '-\u03C0/2'
labels_y[1] = '\u03C0/2'
ax30d.set_yticklabels(labels_y)

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax30d.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax30d.spines[direction].set_position('zero')

ax30d.arrow(-3, 0, 6.1, 0., fc='k', ec='k', lw = .5, head_width=0.1, head_length=0.2, overhang = 0.3, length_includes_head= False, clip_on = False)
ax30d.arrow(0, -np.pi/2-0.1, 0, 2*(np.pi/2)+0.3, fc='k', ec='k', lw = .5, head_width=0.2, head_length=0.1, overhang = 0.3, length_includes_head= False, clip_on = False)

x1 = np.linspace(-3, -1, 1000)
x2 = np.linspace(1, 3, 1000)
ax30d.plot(x1, np.arcsin(1/x1), color="black")
ax30d.plot(x2, np.arcsin(1/x2), color="black")
ax30d.scatter([-1, 1], [-np.pi/2, np.pi/2], color='black')

ax30d.text(3.3, 0, 'x', color="black", size=15)
ax30d.text(0.2, 1.8, 'y', color="black", size=15)
fig30d.savefig("fig_trans_30d.pdf",bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_trans_31a(tbc)

# %%
fig31atbc = plt.figure(figsize=(6,6))
ax31atbc = fig31atbc.add_axes([0,0,1,1])
ax31atbc.set_xlim(-0.1, 2*np.pi+0.1)
ax31atbc.set_ylim(-3, 3)
ax31atbc.set_yticks([-1, 1])
ax31atbc.set_xticks([np.pi/2, np.pi, 3*np.pi/2, 2*np.pi])
ax31atbc.text(0.02, 0.1, '0', color="black", size=10)
labels_x = [item.get_text() for item in ax31atbc.get_xticklabels()]
labels_x[0] = '\u03C0/2'
labels_x[1] = '\u03C0'
labels_x[2] = '3\u03C0/2'
labels_x[3] = '2\u03C0'
ax31atbc.set_xticklabels(labels_x)

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax31atbc.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax31atbc.spines[direction].set_position('zero')

ax31atbc.arrow(-0.1, 0, 2*np.pi+0.1, 0., fc='k', ec='k', lw = .5, head_width=0.2, head_length=0.2, overhang = 0.3, length_includes_head= False, clip_on = False)
ax31atbc.arrow(0, -3, 0, 6.1, fc='k', ec='k', lw = .5, head_width=0.2, head_length=0.2, overhang = 0.3, length_includes_head= False, clip_on = False)

x1 = np.linspace(0, np.pi/2, 1000)
x2 = np.linspace(np.pi, 3*np.pi/2, 1000)
ax31atbc.plot(x1, 1/np.cos(x1), color="black")
ax31atbc.plot(x2, 1/np.cos(x2), color="black")
ax31atbc.plot([np.pi/2, np.pi/2], [-3, 3], color='black', ls='--')
ax31atbc.plot([3*np.pi/2, 3*np.pi/2], [-3, 3], color='black', ls='--')
ax31atbc.scatter([0, np.pi], [1, -1], color='black')

ax31atbc.text(6.5, 0, 'x', color="black", size=15)
ax31atbc.text(0.1, 3.1, 'y', color="black", size=15)
fig31atbc.savefig("fig_trans_31a(tbc).pdf",bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_trans_31b

# %%
fig31b = plt.figure(figsize=(4,4))
ax31b = fig31b.add_axes([0,0,1,1])
ax31b.set_xlim(-4, 4)
ax31b.set_ylim(-np.pi/2-0.1, np.pi/2+0.1)
ax31b.set_yticks([-np.pi/2, -np.pi/4, np.pi/4, np.pi/2])
ax31b.set_xticks([-1, 1])
labels_y = [item.get_text() for item in ax31b.get_yticklabels()]
labels_y[0] = '-\u03C0/2'
labels_y[1] = '-\u03C0/4'
labels_y[2] = '\u03C0/4'
labels_y[3] = '\u03C0/2'
ax31b.set_yticklabels(labels_y)
ax31b.text(-0.3, 0.1, '0', color="black", size=10)

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax31b.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax31b.spines[direction].set_position('zero')

ax31b.arrow(-4, 0, 8.1, 0., fc='k', ec='k', lw = .5, head_width=0.2, head_length=0.3, overhang = 0.3, length_includes_head= False, clip_on = False)
ax31b.arrow(0, -np.pi/2, 0, np.pi+0.1, fc='k', ec='k', lw = .5, head_width=0.3, head_length=0.2, overhang = 0.3, length_includes_head= False, clip_on = False)

x = np.linspace(-4, 4, 1000)
ax31b.plot(x, np.arctan(x), color="black")
ax31b.plot([-4, 4], [np.pi/2, np.pi/2], color="black", ls='--')
ax31b.plot([-4, 4], [-np.pi/2, -np.pi/2], color="black", ls='--')
ax31b.scatter([-1, 0, 1], [-np.pi/4, 0, np.pi/4], color='black')

ax31b.text(4.5, 0, 'x', color="black", size=15)
ax31b.text(0.1, 1.8, 'y', color="black", size=15)
fig31b.savefig("fig_trans_31b.pdf",bbox_inches='tight')
fig31b.savefig("fig_trans_35b.pdf",bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_trans_31b(tbc)

# %%
fig31btbc = plt.figure(figsize=(6,6))
ax31btbc = fig31btbc.add_axes([0,0,1,1])
ax31btbc.set_xlim(-3, 3)
ax31btbc.set_ylim(-0.1, 2*np.pi+0.1)
ax31btbc.set_yticks([np.pi/2, np.pi, 3*np.pi/2, 2*np.pi])
ax31btbc.set_xticks([-1, 1])
ax31btbc.text(0.02, 0.1, '0', color="black", size=10)
labels_y = [item.get_text() for item in ax31btbc.get_yticklabels()]
labels_y[0] = '\u03C0/2'
labels_y[1] = '\u03C0'
labels_y[2] = '3\u03C0/2'
labels_y[3] = '2\u03C0'
ax31btbc.set_yticklabels(labels_y)

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax31btbc.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax31btbc.spines[direction].set_position('zero')

ax31btbc.arrow(-3, 0, 6.1, 0., fc='k', ec='k', lw = .5, head_width=0.2, head_length=0.1, overhang = 0.3, length_includes_head= False, clip_on = False)
ax31btbc.arrow(0, -0.1, 0, 2*np.pi+0.3, fc='k', ec='k', lw = .5, head_width=0.1, head_length=0.2, overhang = 0.3, length_includes_head= False, clip_on = False)

x1 = np.linspace(-4, -1, 1000)
x2 = np.linspace(1, 4, 1000)
ax31btbc.plot(x1, 4*np.pi/2 -np.arccos(1/x1), color="black")
ax31btbc.plot(x2, np.arccos(1/x2), color="black")
ax31btbc.plot([-3, 3], [np.pi/2, np.pi/2], color='black', ls='--')
ax31btbc.plot([-3, 3], [3*np.pi/2, 3*np.pi/2], color='black', ls='--')
ax31btbc.scatter([1, -1], [0, np.pi], color='black')

ax31btbc.text(3.4, 0, 'x', color="black", size=15)
ax31btbc.text(0.1, 6.5, 'y', color="black", size=15)
fig31btbc.savefig("fig_trans_31b(tbc).pdf",bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_trans_31c

# %%
fig31c = plt.figure(figsize=(6,6))
ax31c = fig31c.add_axes([0,0,1,1])
ax31c.set_xlim(-0.1, 2*np.pi+0.1)
ax31c.set_ylim(-3, 3)
ax31c.set_yticks([-1, 1])
ax31c.set_xticks([np.pi/2, np.pi, 3*np.pi/2, 2*np.pi])
ax31c.text(0.02, 0.1, '0', color="black", size=10)
labels_x = [item.get_text() for item in ax31c.get_xticklabels()]
labels_x[0] = '\u03C0/2'
labels_x[1] = '\u03C0'
labels_x[2] = '3\u03C0/2'
labels_x[3] = '2\u03C0'
ax31c.set_xticklabels(labels_x)

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax31c.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax31c.spines[direction].set_position('zero')

ax31c.arrow(-0.1, 0, 2*np.pi+0.1, 0., fc='k', ec='k', lw = .5, head_width=0.2, head_length=0.2, overhang = 0.3, length_includes_head= False, clip_on = False)
ax31c.arrow(0, -3, 0, 6.1, fc='k', ec='k', lw = .5, head_width=0.2, head_length=0.2, overhang = 0.3, length_includes_head= False, clip_on = False)

x1 = np.linspace(0.001, np.pi/2, 1000)
x2 = np.linspace(np.pi+0.001, 3*np.pi/2, 1000)
ax31c.plot(x1, 1/np.sin(x1), color="black")
ax31c.plot(x2, 1/np.sin(x2), color="black")
ax31c.plot([np.pi, np.pi], [-3, 3], color='black', ls='--')
ax31c.scatter([np.pi/2, 3*np.pi/2], [1, -1], color='black')

ax31c.text(6.5, 0, 'x', color="black", size=15)
ax31c.text(0.1, 3.1, 'y', color="black", size=15)
fig31c.savefig("fig_trans_31c.pdf",bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_trans_31d

# %%
fig31d = plt.figure(figsize=(4,4))
ax31d = fig31d.add_axes([0,0,1,1])
ax31d.set_xlim(-4, 4)
ax31d.set_ylim(-0.1, 3*np.pi/2+0.1)
ax31d.set_yticks([np.pi/2, 3*np.pi/2])
ax31d.set_xticks([-1, 1])
labels_y = [item.get_text() for item in ax31d.get_yticklabels()]
labels_y[0] = '\u03C0/2'
labels_y[1] = '3\u03C0/2'
ax31d.set_yticklabels(labels_y)
ax31d.text(-0.3, 0.1, '0', color="black", size=10)

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax31d.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax31d.spines[direction].set_position('zero')

ax31d.arrow(-4, 0, 8.1, 0., fc='k', ec='k', lw = .5, head_width=0.2, head_length=0.3, overhang = 0.3, length_includes_head= False, clip_on = False)
ax31d.arrow(0, -0.1, 0, 3*np.pi/2+0.3, fc='k', ec='k', lw = .5, head_width=0.3, head_length=0.2, overhang = 0.3, length_includes_head= False, clip_on = False)

x1 = np.linspace(1, 4, 1000)
x2 = np.linspace(-4, -1, 1000)
ax31d.plot(x1, np.arcsin(1/x1), color="black")
ax31d.plot(x2, np.pi-np.arcsin(1/x2), color="black")
ax31d.plot([-4, 4], [np.pi, np.pi], color="black", ls='--')
ax31d.scatter([1, -1], [np.pi/2, 3*np.pi/2], color='black')

ax31d.text(4.5, 0, 'x', color="black", size=15)
ax31d.text(0.1, 5.2, 'y', color="black", size=15)
fig31d.savefig("fig_trans_31d.pdf",bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_trans_32b

# %%
fig32b = plt.figure(figsize=(4,4))
ax32b = fig32b.add_axes([0,0,1,1])
ax32b.set_xlim(-4, 4)
ax32b.set_ylim(0, np.pi+0.1)
ax32b.set_yticks([np.pi/4, np.pi/2, 3*np.pi/4, np.pi])
ax32b.set_xticks([-1, 0, 1])
labels_y = [item.get_text() for item in ax32b.get_yticklabels()]
labels_y[0] = '\u03C0/4'
labels_y[1] = '\u03C0/2'
labels_y[2] = '3\u03C0/4'
labels_y[3] = '\u03C0'
ax32b.set_yticklabels(labels_x)

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax32b.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax32b.spines[direction].set_position('zero')

ax32b.arrow(-4, 0, 8.1, 0., fc='k', ec='k', lw = .5, head_width=0.2, head_length=0.3, overhang = 0.3, length_includes_head= False, clip_on = False)
ax32b.arrow(0, 0, 0, np.pi+0.1, fc='k', ec='k', lw = .5, head_width=0.3, head_length=0.2, overhang = 0.3, length_includes_head= False, clip_on = False)

x1 = np.linspace(0.001, 4, 1000)
x2 = np.linspace(-4, -0.001, 1000)
ax32b.plot(x1, np.arctan(1/x1), color="black")
ax32b.plot(x2, np.arctan(1/x2)+np.pi, color="black")
ax32b.plot([-4, 4], [np.pi, np.pi], color="black", ls='--')
ax32b.scatter([-1, 0, 1], [3*np.pi/4, np.pi/2, np.pi/4], color='black')

ax32b.text(4.4, 0, 'x', color="black", size=15)
ax32b.text(0.2, 3.3, 'y', color="black", size=15)
fig32b.savefig("fig_trans_32b.pdf",bbox_inches='tight')
fig32b.savefig("fig_trans_36b.pdf",bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_trans_36e(tbc)

# %%
fig36etbc = plt.figure(figsize=(4,4))
ax36etbc = fig36etbc.add_axes([0,0,1,1])
ax36etbc.set_xlim(0, 3)
ax36etbc.set_ylim(0, 3)
ax36etbc.set_yticks([0.5, 1, 1.5, 2, 2.5])
ax36etbc.set_xticks([0, 0.5, 1, 1.5, 2, 2.5])

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax36etbc.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax36etbc.spines[direction].set_position('zero')

ax36etbc.arrow(0, 0, 3.1, 0., fc='k', ec='k', lw = .5, head_width=0.1, head_length=0.1, overhang = 0.3, length_includes_head= False, clip_on = False)
ax36etbc.arrow(0, 0, 0, 3.1, fc='k', ec='k', lw = .5, head_width=0.1, head_length=0.1, overhang = 0.3, length_includes_head= False, clip_on = False)

x1 = np.linspace(0, 4, 1000)
x2 = np.linspace(0.001, 1, 1000)
ax36etbc.plot(x1, 1/np.cosh(x1), color="black", ls='--')
ax36etbc.plot(x2, np.arccosh(1/x2), color="black")

ax36etbc.text(3.3, 0, 'x', color="black", size=15)
ax36etbc.text(0.1, 3.1, 'y', color="black", size=15)
fig36etbc.savefig("fig_trans_36e(tbc).pdf",bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_trans_36f(tbc)

# %%
fig36ftbc = plt.figure(figsize=(4,4))
ax36ftbc = fig36ftbc.add_axes([0,0,1,1])
ax36ftbc.set_xlim(-4, 4)
ax36ftbc.set_ylim(-4, 4)
ax36ftbc.set_yticks([-4, -2, 2, 4])
ax36ftbc.set_xticks([-4, -2, 2, 4])
ax36ftbc.text(-0.3, 0.1, '0', color="black", size=10)

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax36ftbc.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax36ftbc.spines[direction].set_position('zero')

ax36ftbc.arrow(-4, 0, 8.1, 0., fc='k', ec='k', lw = .5, head_width=0.4, head_length=0.4, overhang = 0.3, length_includes_head= False, clip_on = False)
ax36ftbc.arrow(0, -4, 0, 8.1, fc='k', ec='k', lw = .5, head_width=0.4, head_length=0.4, overhang = 0.3, length_includes_head= False, clip_on = False)

x1 = np.linspace(-4, -0.001, 1000)
x2 = np.linspace(0.001, 4, 1000)
x3 = np.linspace(-4, -1.001, 1000)
x4 = np.linspace(1.001, 4, 1000)
ax36ftbc.plot(x1, 1/np.tanh(x1), color="black", ls='--')
ax36ftbc.plot(x2, 1/np.tanh(x2), color="black", ls='--')
ax36ftbc.plot(x3, np.arctanh(1/x3), color="black")
ax36ftbc.plot(x4, np.arctanh(1/x4), color="black")

ax36ftbc.text(4.7, 0, 'x', color="black", size=15)
ax36ftbc.text(0.4, 4.3, 'y', color="black", size=15)
fig36ftbc.savefig("fig_trans_36f(tbc).pdf",bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_trans_37a

# %%
fig37a = plt.figure(figsize=(4,4))
ax37a = fig37a.add_axes([0,0,1,1])
ax37a.set_xlim(-1.25, 1.25)
ax37a.set_ylim(-1.25, 1.25)

ax37a.set_xticks([])
ax37a.set_yticks([])

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax37a.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax37a.spines[direction].set_position('zero')

ax37a.arrow(-1.25, 0, 2.6, 0., fc='k', ec='k', lw = .5, head_width=0.1, head_length=0.1, overhang = 0.3, length_includes_head= False, clip_on = False)
ax37a.arrow(0, -1.25, 0, 2.6, fc='k', ec='k', lw = .5, head_width=0.1, head_length=0.1, overhang = 0.3, length_includes_head= False, clip_on = False)

ax37a.plot([0, 2.5*np.cos(np.arcsin(1/3))], [0, 2.5*np.sin(np.arcsin(1/3))], color="black")
ax37a.plot([0, 2.5*np.cos(np.pi-np.arcsin(1/3))], [0, 2.5*np.sin(np.pi-np.arcsin(1/3))], color="black")
ax37a.plot([np.cos(np.arcsin(1/3)), np.cos(np.pi-np.arcsin(1/3))], [np.sin(np.arcsin(1/3)), np.sin(np.pi-np.arcsin(1/3))], color="black", ls='--')

ax37a.text(1, -0.2, '1', color="black", size=15)
ax37a.text(0.05, 1.05, '1', color="black", size=15)
ax37a.text(-0.15, -0.15, '0', color="black", size=15)
ax37a.text(0.55, 0.05, 'x=arcsin(1/3)', color="black", size=10)
ax37a.text(0.5, 0.6, 'x=\u03C0-arcsin(1/3)', color="black", size=10)

path1 = matplotlib.path.Path(np.array([np.array([0.5*np.cos(theta), 0.5*np.sin(theta)]) for theta in np.linspace(0, np.arcsin(1/3), 100)]), codes=None, _interpolation_steps=1, closed=False, readonly=False)
arc1 = patches.FancyArrowPatch(path=path1, connectionstyle="arc3,rad=0.5", arrowstyle="-|>, head_width=2, head_length=2", color="k")
path2 = matplotlib.path.Path(np.array([np.array([0.75*np.cos(theta), 0.75*np.sin(theta)]) for theta in np.linspace(0, np.pi-np.arcsin(1/3), 100)]), codes=None, _interpolation_steps=1, closed=False, readonly=False)
arc2 = patches.FancyArrowPatch(path=path2, connectionstyle="arc3,rad=0.5", arrowstyle="-|>, head_width=2, head_length=2", color="k")

circle1 = plt.Circle((0, 0), 1, color='grey', fill=False)

ax37a.add_patch(circle1)
ax37a.add_patch(arc1)
ax37a.add_patch(arc2)
ax37a.text(1.35, -0.2, 'x', color="black", size=15)
ax37a.text(0.1, 1.35, 'y', color="black", size=15)
fig37a.savefig("fig_trans_37a.pdf",bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_trans_37b

# %%
fig37b = plt.figure(figsize=(4,4))
ax37b = fig37b.add_axes([0,0,1,1])
ax37b.set_xlim(-1.25, 1.25)
ax37b.set_ylim(-1.25, 1.25)

ax37b.set_xticks([])
ax37b.set_yticks([])

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax37b.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax37b.spines[direction].set_position('zero')

ax37b.arrow(-1.25, 0, 2.6, 0., fc='k', ec='k', lw = .5, head_width=0.1, head_length=0.1, overhang = 0.3, length_includes_head= False, clip_on = False)
ax37b.arrow(0, -1.25, 0, 2.6, fc='k', ec='k', lw = .5, head_width=0.1, head_length=0.1, overhang = 0.3, length_includes_head= False, clip_on = False)

ax37b.plot([0, 2.5*np.cos(np.arctan(-2))], [0, 2.5*np.sin(np.arctan(-2))], color="black")
ax37b.plot([0, 2.5*np.cos(np.pi-np.arctan(-2))], [0, 2.5*np.sin(np.pi+np.arctan(-2))], color="black")

ax37b.text(1, -0.2, '1', color="black", size=15)
ax37b.text(0.05, 1.05, '1', color="black", size=15)
ax37b.text(-0.15, -0.15, '0', color="black", size=15)
ax37b.text(0.4, -0.4, 'x=arctan(-2)', color="black", size=10)
ax37b.text(0.5, 0.6, '\u03C0', color="black", size=10)

path1 = matplotlib.path.Path(np.array([np.array([0.5*np.cos(theta), 0.5*np.sin(theta)]) for theta in np.linspace(0, np.arctan(-2), 100)]), codes=None, _interpolation_steps=1, closed=False, readonly=False)
arc1 = patches.FancyArrowPatch(path=path1, connectionstyle="arc3,rad=0.5", arrowstyle="-|>, head_width=2, head_length=2", color="k")
path2 = matplotlib.path.Path(np.array([np.array([0.75*np.cos(theta), 0.75*np.sin(theta)]) for theta in np.linspace(np.arctan(-2), np.pi+np.arctan(-2), 100)]), codes=None, _interpolation_steps=1, closed=False, readonly=False)
arc2 = patches.FancyArrowPatch(path=path2, connectionstyle="arc3,rad=0.5", arrowstyle="<|-|>, head_width=2, head_length=2", color="k")

circle1 = plt.Circle((0, 0), 1, color='grey', fill=False)

ax37b.add_patch(circle1)
ax37b.add_patch(arc1)
ax37b.add_patch(arc2)
ax37b.text(1.35, -0.2, 'x', color="black", size=15)
ax37b.text(0.1, 1.35, 'y', color="black", size=15)
fig37b.savefig("fig_trans_37b.pdf",bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Hyperbolische functies

# %% [markdown]
# ### fig_trans_38a

# %%
fig38a = plt.figure(figsize=(4,4))
ax38a = fig38a.add_axes([0,0,1,1])
ax38a.set_xlim(-1.25, 1.25)
ax38a.set_ylim(-1.25, 1.25)

ax38a.set_xticks([])
ax38a.set_yticks([])

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax38a.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax38a.spines[direction].set_position('zero')

ax38a.arrow(-1.25, 0, 2.6, 0., fc='k', ec='k', lw = .5, head_width=0.1, head_length=0.1, overhang = 0.3, length_includes_head= False, clip_on = False)
ax38a.arrow(0, -1.25, 0, 2.6, fc='k', ec='k', lw = .5, head_width=0.1, head_length=0.1, overhang = 0.3, length_includes_head= False, clip_on = False)

ax38a.plot([0, 2.5*np.cos(np.pi/8)], [0, 2.5*np.sin(np.pi/8)], color="black")
ax38a.scatter([np.cos(np.pi/8)], [np.sin(np.pi/8)], color="black")
x = [np.cos(theta) for theta in np.linspace(0, np.pi/8, 100)]
y = [np.sin(theta) for theta in np.linspace(0, np.pi/8, 100)]
x.extend([i for i in np.linspace(0, np.cos(np.pi/8), 100)])
y.extend([i for i in np.linspace(0, np.sin(np.pi/8), 100)])
ax38a.plot(x, y, color='black')
ax38a.fill_between(x, y, step="pre", alpha=0.4, color='grey')

ax38a.text(1, -0.2, '1', color="black", size=15)
ax38a.text(0.05, 1.05, '1', color="black", size=15)
ax38a.text(-0.15, -0.15, '0', color="black", size=15)
ax38a.text(0.5, 0.1, '\u03B8', color="black", size=13)
ax38a.text(1, 0.3, 'P(cos(\u03B8),sin(\u03B8))', color="black", size=13)

path = matplotlib.path.Path(np.array([np.array([0.5*np.cos(theta), 0.5*np.sin(theta)]) for theta in np.linspace(0, np.pi/8, 100)]), codes=None, _interpolation_steps=1, closed=False, readonly=False)
arc = patches.FancyArrowPatch(path=path, connectionstyle="arc3,rad=0.5", arrowstyle="-|>, head_width=2, head_length=2", edgecolor="black", facecolor='grey')

circle1 = plt.Circle((0, 0), 1, color='grey', fill=False)
ax38a.add_patch(circle1)
ax38a.add_patch(arc)
ax38a.text(1.35, -0.2, 'x', color="black", size=15)
ax38a.text(0.1, 1.35, 'y', color="black", size=15)
fig38a.savefig("fig_trans_38a.pdf",bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_trans_38b

# %%
fig38b = plt.figure(figsize=(4,4))
ax38b = fig38b.add_axes([0,0,1,1])
ax38b.set_xlim(-3, 3)
ax38b.set_ylim(-3, 3)
ax38b.set_yticks([-2, -1, 1, 2])
ax38b.set_xticks([-2, -1, 1, 2])
ax38b.text(-0.3, 0.1, '0', color="black", size=10)

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax38b.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax38b.spines[direction].set_position('zero')

ax38b.arrow(-3, 0, 6.1, 0., fc='k', ec='k', lw = .5, head_width=0.2, head_length=0.2, overhang = 0.3, length_includes_head= False, clip_on = False)
ax38b.arrow(0, -3, 0, 6.1, fc='k', ec='k', lw = .5, head_width=0.2, head_length=0.2, overhang = 0.3, length_includes_head= False, clip_on = False)

delta = 0.025
x, y = np.meshgrid(np.linspace(-3.0, 3.0, 100), np.linspace(-3.0, 3.0, 100))
F = x**2 - y**2 - 1
ax38b.contour(x, y, F, [0], colors='black')
x1 = np.linspace(0,5/2,100)
y1 = np.sqrt(21)/5 * x1
ax38b.plot(x1, y1, color='black')
x2 = np.linspace(1.001,5/2,100)
y2 = np.sqrt(x2**2-1)
ax38b.scatter([5/2], [np.sqrt(21)/2], color='black')
ax38b.fill(np.append(x1, x2[::-1]), np.append(y1, y2[::-1]), 'lightgrey')

ax38b.text(2.8, 2, 'P(cosh(\u03B8),sinh(\u03B8))', color="black", size=13)

ax38b.text(3.7, 0, 'x', color="black", size=15)
ax38b.text(0.4, 3.3, 'y', color="black", size=15)
fig38b.savefig("fig_trans_38b.pdf",bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_trans_39a

# %%
fig39a = plt.figure(figsize=(4,4))
ax39a = fig39a.add_axes([0,0,1,1])
ax39a.set_xlim(-2, 2)
ax39a.set_ylim(0, 3)
ax39a.set_yticks([1, 2, 3])
ax39a.set_xticks([-2, -1, 0, 1, 2])

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax39a.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax39a.spines[direction].set_position('zero')

ax39a.arrow(-2, 0, 4.1, 0., fc='k', ec='k', lw = .5, head_width=0.15, head_length=0.15, overhang = 0.3, length_includes_head= False, clip_on = False)
ax39a.arrow(0, 0, 0, 3.1, fc='k', ec='k', lw = .5, head_width=0.15, head_length=0.15, overhang = 0.3, length_includes_head= False, clip_on = False)

x = np.linspace(-2, 2, 100)
ax39a.plot(x, np.cosh(x), color='black')
ax39a.plot(x, np.exp(-x)/2, color='grey', ls='--')
ax39a.plot(x, np.exp(x)/2, color='grey', ls='--')

ax39a.text(0.2, 2.5, 'y=cosh(x)', color="black", size=13)
ax39a.text(-1.5, 1, 'y=$\\frac{e^{-x}}{2}$', color="grey", size=13)
ax39a.text(1, 1, 'y=$\\frac{e^{x}}{2}$', color="grey", size=13)


ax39a.text(2.3, 0, 'x', color="black", size=15)
ax39a.text(0.1, 3.2, 'y', color="black", size=15)
fig39a.savefig("fig_trans_39a.pdf",bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_trans_39b

# %%
fig39b = plt.figure(figsize=(4,4))
ax39b = fig39b.add_axes([0,0,1,1])
ax39b.set_xlim(-2, 2)
ax39b.set_ylim(-3, 3)
ax39b.set_yticks([-3, -2, -1, 1, 2, 3])
ax39b.set_xticks([-2, -1, 1, 2])
ax39b.text(-0.3, 0.1, '0', color="black", size=10)

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax39b.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax39b.spines[direction].set_position('zero')

ax39b.arrow(-2, 0, 4.1, 0., fc='k', ec='k', lw = .5, head_width=0.2, head_length=0.2, overhang = 0.3, length_includes_head= False, clip_on = False)
ax39b.arrow(0, -3, 0, 6.1, fc='k', ec='k', lw = .5, head_width=0.2, head_length=0.2, overhang = 0.3, length_includes_head= False, clip_on = False)

x = np.linspace(-2, 2, 100)
ax39b.plot(x, np.sinh(x), color='black')
ax39b.plot(x, -np.exp(-x)/2, color='grey', ls='--')
ax39b.plot(x, np.exp(x)/2, color='grey', ls='--')

ax39b.text(2, 2.5, 'y=sinh(x)', color="black", size=13)
ax39b.text(0.5, -1, 'y=-$\\frac{e^{-x}}{2}$', color="grey", size=13)
ax39b.text(-1.2, 1, 'y=$\\frac{e^{x}}{2}$', color="grey", size=13)

ax39b.text(2.4, 0, 'x', color="black", size=15)
ax39b.text(0.2, 3.3, 'y', color="black", size=15)
fig39b.savefig("fig_trans_39b.pdf",bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_trans_40a

# %%
fig40a = plt.figure(figsize=(4,4))
ax40a = fig40a.add_axes([0,0,1,1])
ax40a.set_xlim(-3, 3)
ax40a.set_ylim(-1, 1)
ax40a.set_yticks([-1, -0.5, 0.5, 1])
ax40a.set_xticks([-3, -2, -1, 1, 2, 3])
ax40a.text(-0.3, 0.1, '0', color="black", size=10)

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax40a.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax40a.spines[direction].set_position('zero')

ax40a.arrow(-3, 0, 6.1, 0., fc='k', ec='k', lw = .5, head_width=0.2, head_length=0.4, overhang = 0.3, length_includes_head= False, clip_on = False)
ax40a.arrow(0, -1, 0, 2.1, fc='k', ec='k', lw = .5, head_width=0.4, head_length=0.2, overhang = 0.3, length_includes_head= False, clip_on = False)

x = np.linspace(-3, 3, 1000)
ax40a.plot(x, np.tanh(x), color="black")
ax40a.plot([-3, 3], [1, 1], color="black", ls='--')
ax40a.plot([-3, 3], [-1, -1], color="black", ls='--')

ax40a.text(3.7, 0, 'x', color="black", size=15)
ax40a.text(0.4, 1.3, 'y', color="black", size=15)
fig40a.savefig("fig_trans_40a.pdf",bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_trans_40b

# %%
fig40b = plt.figure(figsize=(4,4))
ax40b = fig40b.add_axes([0,0,1,1])
ax40b.set_xlim(-3, 3)
ax40b.set_ylim(-4, 4)
ax40b.set_yticks([-4, -2, 2, 4])
ax40b.set_xticks([-3, -2, -1, 1, 2, 3])
ax40b.text(-0.3, 0.1, '0', color="black", size=10)

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax40b.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax40b.spines[direction].set_position('zero')

ax40b.arrow(-3, 0, 6.1, 0., fc='k', ec='k', lw = .5, head_width=0.3, head_length=0.3, overhang = 0.3, length_includes_head= False, clip_on = False)
ax40b.arrow(0, -4, 0, 8.1, fc='k', ec='k', lw = .5, head_width=0.3, head_length=0.3, overhang = 0.3, length_includes_head= False, clip_on = False)

x = np.linspace(-3, -0.001, 1000)
ax40b.plot(x, 1/np.tanh(x), color="black")
x = np.linspace(0.001, 3, 1000)
ax40b.plot(x, 1/np.tanh(x), color="black")
ax40b.plot([-3, 3], [1, 1], color="black", ls='--')
ax40b.plot([-3, 3], [-1, -1], color="black", ls='--')

ax40b.text(3.7, 0, 'x', color="black", size=15)
ax40b.text(0.4, 4.3, 'y', color="black", size=15)
fig40b.savefig("fig_trans_40b.pdf",bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_trans_40c

# %%
fig40c = plt.figure(figsize=(4,4))
ax40c = fig40c.add_axes([0,0,1,1])
ax40c.set_xlim(-3, 3)
ax40c.set_ylim(0, 1.5)
ax40c.set_yticks([0.5, 1, 1.5])
ax40c.set_xticks([-3, -2, -1, 0, 1, 2, 3])

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax40c.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax40c.spines[direction].set_position('zero')

ax40c.arrow(-3, 0, 6.1, 0., fc='k', ec='k', lw = .5, head_width=0.05, head_length=0.2, overhang = 0.3, length_includes_head= False, clip_on = False)
ax40c.arrow(0, 0, 0, 1.6, fc='k', ec='k', lw = .5, head_width=0.2, head_length=0.05, overhang = 0.3, length_includes_head= False, clip_on = False)

x = np.linspace(-3, 3, 1000)
ax40c.plot(x, 1/np.cosh(x), color="black")

ax40c.text(3.4, 0, 'x', color="black", size=15)
ax40c.text(0.2, 1.6, 'y', color="black", size=15)
fig40c.savefig("fig_trans_40c.pdf",bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_trans_40d

# %%
fig40b = plt.figure(figsize=(4,4))
ax40b = fig40b.add_axes([0,0,1,1])
ax40b.set_xlim(-3, 3)
ax40b.set_ylim(-3, 3)
ax40b.set_yticks([-3, -2, -1, 1, 2, 3])
ax40b.set_xticks([-3, -2, -1, 1, 2, 3])
ax40b.text(-0.3, 0.1, '0', color="black", size=10)

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax40b.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax40b.spines[direction].set_position('zero')

ax40b.arrow(-3, 0, 6.1, 0., fc='k', ec='k', lw = .5, head_width=0.2, head_length=0.2, overhang = 0.3, length_includes_head= False, clip_on = False)
ax40b.arrow(0, -3, 0, 6.1, fc='k', ec='k', lw = .5, head_width=0.2, head_length=0.2, overhang = 0.3, length_includes_head= False, clip_on = False)

x = np.linspace(-3, -0.001, 1000)
ax40b.plot(x, 1/np.sinh(x), color="black")
x = np.linspace(0.001, 3, 1000)
ax40b.plot(x, 1/np.sinh(x), color="black")

ax40b.text(3.4, 0, 'x', color="black", size=15)
ax40b.text(0.2, 3.3, 'y', color="black", size=15)
fig40b.savefig("fig_trans_40d.pdf",bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_trans_42a

# %%
fig42a = plt.figure(figsize=(4,4))
ax42a = fig42a.add_axes([0,0,1,1])
ax42a.set_xlim(0, 3)
ax42a.set_ylim(0, 10)
ax42a.set_yticks([2, 4, 6, 8, 10])
ax42a.set_xticks([0, 1, 2, 3])

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax42a.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax42a.spines[direction].set_position('zero')

ax42a.arrow(0, 0, 3.1, 0., fc='k', ec='k', lw = .5, head_width=0.4, head_length=0.1, overhang = 0.3, length_includes_head= False, clip_on = False)
ax42a.arrow(0, 0, 0, 10.1, fc='k', ec='k', lw = .5, head_width=0.1, head_length=0.4, overhang = 0.3, length_includes_head= False, clip_on = False)

x = np.linspace(0, 3, 1000)
ax42a.plot(x, np.cosh(x), color="grey", ls='--')
x = np.linspace(1, 3, 1000)
ax42a.plot(x, np.arccosh(x), color="black")

ax42a.text(3.3, 0, 'x', color="black", size=15)
ax42a.text(0.1, 10.3, 'y', color="black", size=15)
fig42a.savefig("fig_trans_42a.pdf",bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_trans_42b

# %%
fig42b = plt.figure(figsize=(4,4))
ax42b = fig42b.add_axes([0,0,1,1])
ax42b.set_xlim(-3, 3)
ax42b.set_ylim(-10, 10)
ax42b.set_yticks([-10, -5, 5, 10])
ax42b.set_xticks([-3, -2, -1, 1, 2, 3])
ax42b.text(-0.3, 0.1, '0', color="black", size=10)

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax42b.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax42b.spines[direction].set_position('zero')

ax42b.arrow(-3, 0, 6.1, 0., fc='k', ec='k', lw = .5, head_width=0.8, head_length=0.2, overhang = 0.3, length_includes_head= False, clip_on = False)
ax42b.arrow(0, -10, 0, 20.1, fc='k', ec='k', lw = .5, head_width=0.2, head_length=0.8, overhang = 0.3, length_includes_head= False, clip_on = False)

x = np.linspace(-3, 3, 1000)
ax42b.plot(x, np.sinh(x), color="grey", ls='--')
ax42b.plot(x, np.arcsinh(x), color="black")

ax42b.text(3.5, 0, 'x', color="black", size=15)
ax42b.text(0.2, 10.3, 'y', color="black", size=15)
fig42b.savefig("fig_trans_42b.pdf",bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_trans_42c

# %%
fig42c = plt.figure(figsize=(4,4))
ax42c = fig42c.add_axes([0,0,1,1])
ax42c.set_xlim(-3, 3)
ax42c.set_ylim(-4, 4)
ax42c.set_yticks([-4, -2, 2, 4])
ax42c.set_xticks([-3, -2, -1, 1, 2, 3])
ax42c.text(-0.3, 0.1, '0', color="black", size=10)

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax42c.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax42c.spines[direction].set_position('zero')

ax42c.arrow(-3, 0, 6.1, 0., fc='k', ec='k', lw = .5, head_width=0.4, head_length=0.2, overhang = 0.3, length_includes_head= False, clip_on = False)
ax42c.arrow(0, -4, 0, 8.1, fc='k', ec='k', lw = .5, head_width=0.2, head_length=0.4, overhang = 0.3, length_includes_head= False, clip_on = False)

x = np.linspace(-3, 3, 1000)
ax42c.plot(x, np.tanh(x), color="grey", ls='--')
x = np.linspace(-0.999, 0.999, 1000)
ax42c.plot(x, np.arctanh(x), color="black")

ax42c.text(3.5, 0, 'x', color="black", size=15)
ax42c.text(0.4, 4.3, 'y', color="black", size=15)
fig42c.savefig("fig_trans_42c.pdf",bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_trans_42d

# %%
fig42d = plt.figure(figsize=(4,4))
ax42d = fig42d.add_axes([0,0,1,1])
ax42d.set_xlim(-3, 3)
ax42d.set_ylim(-4, 4)
ax42d.set_yticks([-4, -2, 2, 4])
ax42d.set_xticks([-3, -2, -1, 1, 2, 3])
ax42d.text(-0.3, 0.1, '0', color="black", size=10)

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax42d.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax42d.spines[direction].set_position('zero')

ax42d.arrow(-3, 0, 6.1, 0., fc='k', ec='k', lw = .5, head_width=0.4, head_length=0.2, overhang = 0.3, length_includes_head= False, clip_on = False)
ax42d.arrow(0, -4, 0, 8.1, fc='k', ec='k', lw = .5, head_width=0.2, head_length=0.4, overhang = 0.3, length_includes_head= False, clip_on = False)

x = np.linspace(-3, -0.001, 1000)
ax42d.plot(x, 1/np.tanh(x), color="grey", ls='--')
x = np.linspace(0.001, 3, 1000)
ax42d.plot(x, 1/np.tanh(x), color="grey", ls='--')
x = np.linspace(-3, -1.001, 1000)
ax42d.plot(x, np.arctanh(1/x), color="black")
x = np.linspace(1.001, 3, 1000)
ax42d.plot(x, np.arctanh(1/x), color="black")

ax42d.text(3.5, 0, 'x', color="black", size=15)
ax42d.text(0.4, 4.3, 'y', color="black", size=15)
fig42d.savefig("fig_trans_42d.pdf",bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Reductie van kegelsneden

# %% [markdown]
# ### fig_trans_43

# %%
fig43 = plt.figure(figsize=(4,4))
ax43 = fig43.add_axes([0,0,1,1])
ax43.set_xlim(-0.5, 3)
ax43.set_ylim(-0.5, 3)
ax43.set_yticks([1])
ax43.set_xticks([1])
labels_x = [item.get_text() for item in ax43.get_xticklabels()]
ax43.set_xticklabels(labels_x)
labels_y = [item.get_text() for item in ax43.get_yticklabels()]
ax43.set_yticklabels(labels_y)

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax43.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax43.spines[direction].set_position('zero')

ax43.arrow(-0.5, 0, 3.6, 0., fc='k', ec='k', lw = .5, head_width=0.2, head_length=0.1, overhang = 0.3, length_includes_head= False, clip_on = False)
ax43.arrow(0, -0.5, 0, 3.6, fc='k', ec='k', lw = .5, head_width=0.1, head_length=0.2, overhang = 0.3, length_includes_head= False, clip_on = False)
ax43.arrow(1, 1, 3.6, 0., fc='k', ec='k', lw = .5, head_width=0.2, head_length=0.1, overhang = 0.3, length_includes_head= False, clip_on = False)
ax43.arrow(1, 1, 0, 3.6, fc='k', ec='k', lw = .5, head_width=0.1, head_length=0.2, overhang = 0.3, length_includes_head= False, clip_on = False)

ax43.plot([0, 1], [1, 1], color='black', ls='--')
ax43.plot([1, 1], [0, 1], color='black', ls='--')

ax43.text(0.9, -0.2, 'x$_0$', color="black", size=15)
ax43.text(-0.3, 0.9, 'y$_0$', color="black", size=15)

ax43.text(3.4, 0, 'x', color="black", size=15)
ax43.text(0.2, 3.3, 'y', color="black", size=15)
ax43.text(-0.3, -0.3, '0', color="black", size=15)

ax43.text(4.9, 1, '$\~x$', color="black", size=15)
ax43.text(1.2, 4.5, '$\~y$', color="black", size=15)
ax43.text(0.7, 0.7, '$\~0$', color="black", size=15)

fig43.savefig("fig_trans_43.pdf",bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_trans_44

# %%
fig44 = plt.figure(figsize=(4,4))
ax44 = fig44.add_axes([0,0,1,1])
ax44.set_xlim(-8, 2)
ax44.set_ylim(-8, 2)
ax44.set_yticks([-6, -4, -2])
ax44.set_xticks([-6, -4, -2])

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax44.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax44.spines[direction].set_position('zero')

ax44.arrow(-8, 0, 10.1, 0., fc='k', ec='k', lw = .5, head_width=0.4, head_length=0.2, overhang = 0.3, length_includes_head= False, clip_on = False)
ax44.arrow(0, -8, 0, 10.1, fc='k', ec='k', lw = .5, head_width=0.2, head_length=0.4, overhang = 0.3, length_includes_head= False, clip_on = False)
ax44.arrow(-2*np.sqrt(2), -2*np.sqrt(2), 5.1, 0., fc='grey', ec='grey', lw = .5, head_width=0.4, head_length=0.2, overhang = 0.3, length_includes_head= False, clip_on = False)
ax44.arrow(-2*np.sqrt(2), -2*np.sqrt(2), 0, 5.1, fc='grey', ec='grey', lw = .5, head_width=0.2, head_length=0.4, overhang = 0.3, length_includes_head= False, clip_on = False)

x = np.linspace(-4.3, 4.3, 100)
ax44.plot(x-2*np.sqrt(2), np.sqrt((1+3*x**2/2)*2/7)-2*np.sqrt(2), color='black')
ax44.plot(x-2*np.sqrt(2), -np.sqrt((1+3*x**2/2)*2/7)-2*np.sqrt(2), color='black')

ax44.text(3.4, 0, 'x', color="black", size=15)
ax44.text(0.2, 2.8, 'y', color="black", size=15)
ax44.text(-0.4, -0.5, '0', color="black", size=8)

ax44.text(2.5, -3, '$\~x$', color="grey", size=15)
ax44.text(-2.7, 2.8, '$\~y$', color="grey", size=15)
ax44.text(-3.2, -3, '$\~0$', color="grey", size=8)

fig44.savefig("fig_trans_44.pdf",bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_trans_45a

# %%
fig45a = plt.figure(figsize=(4,4))
ax45a = fig45a.add_axes([0,0,1,1])
ax45a.set_xlim(-0.5, 3)
ax45a.set_ylim(-0.5, 3)

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax45a.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax45a.spines[direction].set_position('zero')

ax45a.arrow(-0.5, 0, 3.6, 0., fc='k', ec='k', lw = .5, head_width=0.2, head_length=0.2, overhang = 0.3, length_includes_head= False, clip_on = False)
ax45a.arrow(0, -0.5, 0, 3.6, fc='k', ec='k', lw = .5, head_width=0.2, head_length=0.2, overhang = 0.3, length_includes_head= False, clip_on = False)
ax45a.arrow(-0.5*np.cos(-np.pi/4), 0.5*np.sin(-np.pi/4), 3.6*np.cos(-np.pi/4), -3.6*np.sin(-np.pi/4), fc='grey', ec='grey', lw = .5, head_width=0.2, head_length=0.2, overhang = 0.3, length_includes_head= False, clip_on = False)
ax45a.arrow(-0.5*np.sin(-np.pi/4), -0.5*np.cos(-np.pi/4), 3.6*np.sin(-np.pi/4), 3.6*np.cos(-np.pi/4), fc='grey', ec='grey', lw = .5, head_width=0.2, head_length=0.2, overhang = 0.3, length_includes_head= False, clip_on = False)

path = matplotlib.path.Path(np.array([np.array([0.5*np.cos(theta), 0.5*np.sin(theta)]) for theta in np.linspace(0, np.pi/4, 100)]), codes=None, _interpolation_steps=1, closed=False, readonly=False)
arc = patches.FancyArrowPatch(path=path, connectionstyle="arc3,rad=-0.5", arrowstyle="<|-|>, head_width=2, head_length=2", color="k")

ax45a.scatter([1], [2], color='black')
ax45a.plot([0, 1], [2, 2], color='black', ls='--')
ax45a.plot([1, 1], [0, 2], color='black', ls='--')

x_new, y_new = np.cos(np.pi/4) + 2*np.sin(np.pi/4), -np.sin(np.pi/4) + 2*np.cos(np.pi/4)
ax45a.plot([x_new*np.cos(-np.pi/4), 1], [-x_new*np.sin(-np.pi/4), 2], color='grey', ls='--')
ax45a.plot([y_new*np.sin(-np.pi/4), 1], [y_new*np.cos(-np.pi/4), 2], color='grey', ls='--')

ax45a.text(0.7, 0.2, '\u03B8', color="black", size=15)
ax45a.text(1, 2.1, 'P', color="black", size=15)

ax45a.text(3.4, 0, 'x', color="black", size=15)
ax45a.text(0.2, 3.3, 'y', color="black", size=15)
ax45a.text(0.9, -0.4, 'x', color="black", size=15)
ax45a.text(-0.5, 1.9, 'y', color="black", size=15)
ax45a.text(-0.3, -0.3, '0', color="black", size=15)

ax45a.text(2.5, 2.2, '$\~x$', color="grey", size=15)
ax45a.text(-2.2, 2.5, '$\~y$', color="grey", size=15)
ax45a.text(1.5, 1.2, '$\~x$', color="grey", size=15)
ax45a.text(-0.7, 0.2, '$\~y$', color="grey", size=15)

ax45a.add_patch(arc)
fig45a.savefig("fig_trans_45a.pdf",bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_trans_45b

# %%
fig45b = plt.figure(figsize=(4,4))
ax45b = fig45b.add_axes([0,0,1,1])
ax45b.set_xlim(-0.5, 3)
ax45b.set_ylim(-0.5, 3)

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax45b.spines[direction].set_color('none')
    if direction in ["left", "bottom"]:
        ax45b.spines[direction].set_position('zero')

ax45b.arrow(-0.5, 0, 3.6, 0., fc='k', ec='k', lw = .5, head_width=0.2, head_length=0.2, overhang = 0.3, length_includes_head= False, clip_on = False)
ax45b.arrow(0, -0.5, 0, 3.6, fc='k', ec='k', lw = .5, head_width=0.2, head_length=0.2, overhang = 0.3, length_includes_head= False, clip_on = False)
ax45b.arrow(-0.5*np.cos(-np.pi/4), 0.5*np.sin(-np.pi/4), 3.6*np.cos(-np.pi/4), -3.6*np.sin(-np.pi/4), fc='grey', ec='grey', lw = .5, head_width=0.2, head_length=0.2, overhang = 0.3, length_includes_head= False, clip_on = False)
ax45b.arrow(-0.5*np.sin(-np.pi/4), -0.5*np.cos(-np.pi/4), 3.6*np.sin(-np.pi/4), 3.6*np.cos(-np.pi/4), fc='grey', ec='grey', lw = .5, head_width=0.2, head_length=0.2, overhang = 0.3, length_includes_head= False, clip_on = False)

path = matplotlib.path.Path(np.array([np.array([0.5*np.cos(theta), 0.5*np.sin(theta)]) for theta in np.linspace(0, np.pi/4, 100)]), codes=None, _interpolation_steps=1, closed=False, readonly=False)
arc = patches.FancyArrowPatch(path=path, connectionstyle="arc3,rad=-0.5", arrowstyle="<|-|>, head_width=2, head_length=2", color="k")

ax45b.scatter([1], [2], color='black')
ax45b.plot([1, 1], [0, 2], color='black', ls='--')

x_new, y_new = np.cos(np.pi/4) + 2*np.sin(np.pi/4), -np.sin(np.pi/4) + 2*np.cos(np.pi/4)
ax45b.plot([x_new*np.cos(-np.pi/4), 1], [-x_new*np.sin(-np.pi/4), 2], color='grey', ls='--')
ax45b.plot([0, 1], [0, 2], color='grey')

ax45b.text(0.7, 0.2, '\u03B8', color="black", size=15)
ax45b.text(1, 2.1, 'P', color="black", size=15)

ax45b.text(3.4, 0, 'x', color="black", size=15)
ax45b.text(0.2, 3.3, 'y', color="black", size=15)
ax45b.text(0.9, -0.4, 'x', color="black", size=15)
ax45b.text(-0.3, -0.3, '0', color="black", size=15)

ax45b.text(2.5, 2.2, '$\~x$', color="grey", size=15)
ax45b.text(-2.2, 2.5, '$\~y$', color="grey", size=15)
ax45b.text(1.5, 1.2, '$\~x$', color="grey", size=15)
ax45b.text(0.5, 0.8, '\u03C6', color="grey", size=15)
ax45b.text(0.4, 1.3, 'r', color="black", size=15)

ax45b.add_patch(arc)
fig45b.savefig("fig_trans_45b.pdf",bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_trans_46

# %%
fig46 = plt.figure(figsize=(4,4))
ax46 = fig46.add_axes([0,0,1,1])

ax46.set_yticks([])
ax46.set_xticks([])

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax46.spines[direction].set_visible(False)
    if direction in ["left", "bottom"]:
        ax46.spines[direction].set_visible(False)

ax46.plot([0, 7, 7, 0], [0, 0, np.tan(np.pi/4)*7, 0], color="black")

path = matplotlib.path.Path(np.array([np.array([np.cos(theta), np.sin(theta)]) for theta in np.linspace(0, np.pi/4, 100)]), codes=None, _interpolation_steps=1, closed=False, readonly=False)
arc = patches.FancyArrowPatch(path=path, arrowstyle="<|-|>, head_width=2, head_length=2", color="k")

ax46.text(4, -1, '7', color="black", size=15)
ax46.text(7.1, 2, '24', color="black", size=15)
ax46.text(2, 3, '25', color="black", size=15)
ax46.text(1, 0.5, '2\u03B8', color="black", size=15)

ax46.add_patch(arc)
fig46.savefig("fig_trans_46.pdf",bbox_inches='tight')
plt.show()

# %% [markdown]
# ### fig_trans_47

# %%
fig47 = plt.figure(figsize=(4,4))
ax47 = fig47.add_axes([0,0,1,1])

ax47.set_yticks([])
ax47.set_xticks([])

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax47.spines[direction].set_visible(False)
    if direction in ["left", "bottom"]:
        ax47.spines[direction].set_visible(False)

ax47.arrow(-0.5, 0, 8.6, 0., fc='k', ec='k', lw = .5, head_width=0.4, head_length=0.4, overhang = 0.3, length_includes_head= False, clip_on = False)
ax47.arrow(0, -0.5, 0, 8.6, fc='k', ec='k', lw = .5, head_width=0.4, head_length=0.4, overhang = 0.3, length_includes_head= False, clip_on = False)
ax47.arrow(-0.5*np.cos(-np.pi/4), 0.5*np.sin(-np.pi/4), 8.6*np.cos(-np.pi/4), -8.6*np.sin(-np.pi/4), fc='grey', ec='grey', lw = .5, head_width=0.4, head_length=0.4, overhang = 0.3, length_includes_head= False, clip_on = False)
ax47.arrow(-0.5*np.sin(-np.pi/4), -0.5*np.cos(-np.pi/4), 8.6*np.sin(-np.pi/4), 8.6*np.cos(-np.pi/4), fc='grey', ec='grey', lw = .5, head_width=0.4, head_length=0.4, overhang = 0.3, length_includes_head= False, clip_on = False)

x, y = np.meshgrid(np.linspace(-10.0, 5, 100), np.linspace(-2, 10.0, 100))
F = 37*x**2 + 72*x*y + 52*y**2 + 30*x - 40*y - 75
ax47.contour(x, y, F, [0], colors='grey')

ax47.text(0.7, 0.2, '\u03B8', color="black", size=15)

ax47.text(9, 0, 'x', color="black", size=15)
ax47.text(0.2, 9, 'y', color="black", size=15)

ax47.text(6.5, 6, '$\~x$', color="grey", size=15)
ax47.text(-5.2, 6, '$\~y$', color="grey", size=15)

fig47.savefig("fig_trans_47.pdf",bbox_inches='tight')
plt.show()
